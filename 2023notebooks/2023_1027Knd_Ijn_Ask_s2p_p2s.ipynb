# %% [markdown]
# <a href="https://colab.research.google.com/github/komazawa-deep-learning/komazawa-deep-learning.github.io/blob/master/2023notebooks/2023_1027Knd_Ijn_Ask_s2p_p2s.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %config InlineBackend.figure_format = 'retina'

# %% [markdown]
# * date: 2023_1027
# * author: 浅川伸一
# * filename: 2023_1027Knd_Ijn_Ask_s2p_p2s.ipynb
#
# # 符号化器‐復号化器 (encoder-decoder a.k.a seq2seq) モデルによる，単語復唱，単語産出，および単語理解処理過程の実装
#
#
# <center>
# <img src="https://raw.githubusercontent.com/ShinAsakawa/ShinAsakawa.github.io/master/assets/2004Harm_Seidenberg_fig4c.svg"><br/>
# <img src="https://raw.githubusercontent.com/ShinAsakawa/ShinAsakawa.github.io/master/assets/2004Harm_Seidenberg_fig4d.svg"><br/> -->
# <img src="2004Harm_Seidenberg_fig4ab.svg"><br/>
# <!--<img src="2004Harm_Seidenberg_fig4c.svg">
# <img src="2004Harm_Seidenberg_fig4d.svg"><br/>-->
# `2004Harm&Seidenberg2004`, Figure 4 c, and d
# </center>
#
# <center>
# <img src="2015Loung_fig1.svg" width="24%"><br/>
# ニューラル翻訳モデル。
# 青色がソース言語モデル，赤がターゲット言語モデルである。
# ソース言語モデルの，最終時刻の中間層状態を，ターゲット言語モデルの開始時の中間層状態として用いる。
# Loung+2015 Fig.1 より。
# </center>
#
#
# * 文献
#     * Harm & Seidenberg (2004) Computing the Meanings of Words in Reading: Cooperative Division of Labor Between Visual and Phonological Processes, Psychological Review, DOI:10.1037/0033-295X.111.3.662
#     * Seq2seq 翻訳モデル: Sutskever+ (2014) Sequence to Sequence Learning with Neural Networks, [arXiv:1409.3215](https://arxiv.org/abs/1409.3215)
#     * 注意つき符号化器‐復号化器モデル: Bahdanau, Cho, & Bengio (2015) NEURAL MACHINE TRANSLATION BY JOINTLY LEARNING TO ALIGN AND TRANSLATE, [arXiv:1409.0473](https://arxiv.org/abs/1409.0473)
#     * もう一つの注意つき符号化器‐復号化器モデル Luong+ (2015) Effective Approaches to Attention-based Neural Machine Translation, [arXiv:1508.04025](https://arxiv.org/abs/1508.04025)

# %% [markdown]
# # 0 準備
# ## 0.1 Colab 用 MeCab コンパイル&インストール等

# %%
# %%time
# %config InlineBackend.figure_format = 'retina'
# このセルの実行には 15 分程度かかります。
import torch
device = 'cuda' if torch.cuda.is_available() else 'cpu'

import IPython
isColab = 'google.colab' in str(IPython.get_ipython())

import sys
import os
import numpy as np
from tqdm.notebook import tqdm
import time
import datetime
import matplotlib.pyplot as plt

# ローカルと colab との相違を吸収するために必要となるライブラリをインストール
try:
    import jaconv
except ImportError:
    # !pip install jaconv

try:
    import japanize_matplotlib
except ImportError:
    # !pip install japanize_matplotlib
    import japanize_matplotlib

if isColab:
    # !pip install --upgrade termcolor==1.1
from termcolor import colored

# MeCab, fugashi, ipadic のインストール
if isColab:
    # !apt install aptitude swig > /dev/null 2>&1
    # !aptitude install mecab libmecab-dev mecab-ipadic-utf8 git make curl xz-utils file -y > /dev/null 2>&1
    # !pip install mecab-python3==0.7 > /dev/null 2>&1
    # !pip install --upgrade ipadic > /dev/null 2>&1
    # !git clone --depth 1 https://github.com/neologd/mecab-ipadic-neologd.git > /dev/null 2>&1
    # !echo yes | mecab-ipadic-neologd/bin/install-mecab-ipadic-neologd -n -a > /dev/null 2>&1

    import subprocess
    cmd='echo `mecab-config --dicdir`\"/mecab-ipadic-neologd\"'
    path_neologd = (subprocess.Popen(cmd, stdout=subprocess.PIPE,
                                     shell=True).communicate()[0]).decode('utf-8')

    # !pip install 'fugashi[unidic]' > /dev/null 2>&1
    # !python -m unidic download > /dev/null 2>&1
    # !pip install ipadic > /dev/null 2>&1
    # !pip install 'konoha[mecab]'


# 以下は，開発したライブラリを GitHub より取得してインストール
try:
    import ccap
except ImportError:
    # !git clone https://github.com/ShinAsakawa/ccap.git
    import ccap

try:
    import RAM
except ImportError:
    # !git clone https://github.com/ShinAsakawa/RAM.git
    import RAM

# 近藤先生との議論から音韻情報の代替案として，ローマ字表記を採用することとした。
# このとき，訓令式の表記にすることとした。ヘボン式，パスポート式ではないことに注意
try:
    from kunrei import kunrei
except ImportError:
    # !wget https://shinasakawa.github.io/2023notebooks/kunrei.py -O kunrei.py
    from kunrei import kunrei
# Out:
# Collecting jaconv
#   Downloading jaconv-0.3.4.tar.gz (16 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: jaconv
#   Building wheel for jaconv (setup.py) ... done
#   Created wheel for jaconv: filename=jaconv-0.3.4-py3-none-any.whl size=16416 sha256=a5a21f5b1024ff3c7aef51c17cf7c19a5d2a02abf61d7d1430e0bcbaeab27fbd
#   Stored in directory: /root/.cache/pip/wheels/46/8f/2e/a730bf1fca05b33e532d5d91dabdf406c9b718ec85b01b1b54
# Successfully built jaconv
# Installing collected packages: jaconv
# Successfully installed jaconv-0.3.4
# Collecting japanize_matplotlib
#   Downloading japanize-matplotlib-1.1.3.tar.gz (4.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.1/4.1 MB 47.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from japanize_matplotlib) (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->japanize_matplotlib) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->japanize_matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->japanize_matplotlib) (4.43.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->japanize_matplotlib) (1.4.5)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from matplotlib->japanize_matplotlib) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->japanize_matplotlib) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->japanize_matplotlib) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->japanize_matplotlib) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->japanize_matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->japanize_matplotlib) (1.16.0)
# Building wheels for collected packages: japanize_matplotlib
#   Building wheel for japanize_matplotlib (setup.py) ... done
#   Created wheel for japanize_matplotlib: filename=japanize_matplotlib-1.1.3-py3-none-any.whl size=4120257 sha256=cab5cdd08f77dba3794f1f4ea90996ae7b110d36270f0d5719916c833e5af123
#   Stored in directory: /root/.cache/pip/wheels/61/7a/6b/df1f79be9c59862525070e157e62b08eab8ece27c1b68fbb94
# Successfully built japanize_matplotlib
# Installing collected packages: japanize_matplotlib
# Successfully installed japanize_matplotlib-1.1.3
# Collecting termcolor==1.1
#   Downloading termcolor-1.1.0.tar.gz (3.9 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: termcolor
#   Building wheel for termcolor (setup.py) ... done
#   Created wheel for termcolor: filename=termcolor-1.1.0-py3-none-any.whl size=4832 sha256=f84687eee40a321366dca6e47231dbb24e54f677d2b55b43479719c96dbb37a1
#   Stored in directory: /root/.cache/pip/wheels/a1/49/46/1b13a65d8da11238af9616b00fdde6d45b0f95d9291bac8452
# Successfully built termcolor
# Installing collected packages: termcolor
#   Attempting uninstall: termcolor
#     Found existing installation: termcolor 2.3.0
#     Uninstalling termcolor-2.3.0:
#       Successfully uninstalled termcolor-2.3.0
# Successfully installed termcolor-1.1.0
# Collecting konoha[mecab]
#   Downloading konoha-5.4.0-py3-none-any.whl (17 kB)
# Requirement already satisfied: importlib-metadata<7.0.0,>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from konoha[mecab]) (6.8.0)
# Collecting overrides<4.0.0,>=3.0.0 (from konoha[mecab])
#   Downloading overrides-3.1.0.tar.gz (11 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: requests<3.0.0,>=2.26.0 in /usr/local/lib/python3.10/dist-packages (from konoha[mecab]) (2.31.0)
# Collecting natto-py<2.0.0,>=1.0.0 (from konoha[mecab])
#   Downloading natto-py-1.0.1.tar.gz (36 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata<7.0.0,>=4.0.0->konoha[mecab]) (3.17.0)
# Requirement already satisfied: cffi in /usr/local/lib/python3.10/dist-packages (from natto-py<2.0.0,>=1.0.0->konoha[mecab]) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.26.0->konoha[mecab]) (3.3.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.26.0->konoha[mecab]) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.26.0->konoha[mecab]) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.26.0->konoha[mecab]) (2023.7.22)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi->natto-py<2.0.0,>=1.0.0->konoha[mecab]) (2.21)
# Building wheels for collected packages: natto-py, overrides
#   Building wheel for natto-py (setup.py) ... done
#   Created wheel for natto-py: filename=natto_py-1.0.1-py3-none-any.whl size=44821 sha256=dbb680480b63613b7b3a37c76bf1d07151340af5c75772090dc831be90fa4009
#   Stored in directory: /root/.cache/pip/wheels/0d/47/6f/c481360dc8e1445c947007ec8ccb5dc123776e3236b635d892
#   Building wheel for overrides (setup.py) ... done
#   Created wheel for overrides: filename=overrides-3.1.0-py3-none-any.whl size=10173 sha256=b1c536d70317bf557f3209a5bd7daa4da3c340ad2fa8eb6f4bf494fea4c4202c
#   Stored in directory: /root/.cache/pip/wheels/bd/23/63/4d5849844f8f9d32be09e1b9b278e80de2d8314fbf1e28068b
# Successfully built natto-py overrides
# Installing collected packages: overrides, natto-py, konoha
# Successfully installed konoha-5.4.0 natto-py-1.0.1 overrides-3.1.0
# Cloning into 'ccap'...
# remote: Enumerating objects: 847, done.
# remote: Counting objects: 100% (267/267), done.
# remote: Compressing objects: 100% (119/119), done.
# remote: Total 847 (delta 143), reused 253 (delta 138), pack-reused 580
# Receiving objects: 100% (847/847), 38.43 MiB | 20.94 MiB/s, done.
# Resolving deltas: 100% (169/169), done.
# Cloning into 'RAM'...
# remote: Enumerating objects: 93, done.
# remote: Counting objects: 100% (42/42), done.
# remote: Compressing objects: 100% (42/42), done.
# remote: Total 93 (delta 15), reused 0 (delta 0), pack-reused 51
# Receiving objects: 100% (93/93), 130.05 MiB | 15.35 MiB/s, done.
# Resolving deltas: 100% (38/38), done.
# --2023-10-29 21:05:34--  https://shinasakawa.github.io/2023notebooks/kunrei.py
# Resolving shinasakawa.github.io (shinasakawa.github.io)... 185.199.111.153, 185.199.109.153, 185.199.108.153, ...
# Connecting to shinasakawa.github.io (shinasakawa.github.io)|185.199.111.153|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 21158 (21K) [application/octet-stream]
# Saving to: ‘kunrei.py’
#
# kunrei.py           100%[===================>]  20.66K  --.-KB/s    in 0.001s
#
# 2023-10-29 21:05:35 (23.2 MB/s) - ‘kunrei.py’ saved [21158/21158]
#
# CPU times: user 7.36 s, sys: 1.17 s, total: 8.53 s
# Wall time: 13min 34s

# %% [markdown]
# ## 0.2 意味表現として word2vec による意味埋め込みベクトルを使う

# %%
# %%time
# word2vec を読み込む。このセルの実行には 1, 2 分を要します。
from ccap import ccap_w2v
w2v = ccap_w2v().w2v
#w2v = ccap_w2v(isColab=False).w2v

# MeCab による yomi を輸入
from ccap.mecab_settings import yomi
#import MeCab
# Out:
# CPU times: user 28.9 s, sys: 5.07 s, total: 34 s
# Wall time: 1min 11s

# %% [markdown]
# ## 0.3 データセット Psylex71_Dataset の読み込み

# %%
# データセットとしての Psylex71_Dataset の読み込み
from RAM import Psylex71_Dataset

psylex71_ds = Psylex71_Dataset(max_words=30000)
print(f'psylex71_ds の単語数:{psylex71_ds.__len__()}')
# Out:
# psylex71_ds の単語数:30000

# %% [markdown]
# ### データセットのヒストグラム描画

# %%
from RAM import draw_word_char_histgram

draw_word_char_histgram(_dict=psylex71_ds.data_dict, key='phon', title='音韻', figsize2=(8,3))

# %% [markdown]
# ## 0.4 psylex71_ds に存在する全単語を word2vec の埋め込みベクトル行列にする

# %%
# psylex71_ds データから word2vec の埋め込みベクトル行列を得る
_words = [dct['orth'] for dct in psylex71_ds.data_dict.values()]

# gensim() の `vectors_for_all()` 関数を持ちて，望む語彙で構成される word2vec 単語埋め込みモデルを作成
w2v_psylex71 = w2v.vectors_for_all(_words)

# NaN データが入っている可能性がるので変換
w2v_psylex71.vectors = np.nan_to_num(w2v_psylex71.vectors)
print(f'w2v_psylex71.vectors.shape:{w2v_psylex71.vectors.shape}')
words = w2v_psylex71.index_to_key
#len(words)
# Out:
# w2v_psylex71.vectors.shape:(26877, 200)

# %% [markdown]
# ## 0.5 psylex71 データセット中の単語における w2v の表示テスト

# %%
Wrd = input('単語を入力してください:')
color = 'blue'
while (Wrd != ""):
    if Wrd in w2v_psylex71:
        Idx = w2v_psylex71.key_to_index[Wrd]
        print(f'入力単語 Wrd:{colored(Wrd, color, attrs=["bold"])},',
              f'対応する単語番号 Idx:{colored(Idx, color, attrs=["bold"])},',
              f'w2v_psylex71.get_index({Wrd}):{colored(w2v_psylex71.get_index(Wrd), color, attrs=["bold"])}')
    else:
        print(colored(f'{Wrd} という単語はありません。','red', attrs=['bold']))
    Wrd = input('単語を入力してください (終了するには改行のみを入力):')
# Out:
# 単語を入力してください:表示
# 入力単語 Wrd:表示, 対応する単語番号 Idx:1798, w2v_psylex71.get_index(表示):1798
# 単語を入力してください (終了するには改行のみを入力):

# %% [markdown]
# ## 0.6 書記素リストの作成

# %%
import RAM

def _grapheme(words=words):
    """必要と思われる書記素リストを返す"""

    num_alpha='０１２３４５６７８９ＡＢＣＤＥＦＧＨＩＪＫＬＭＮＯＰＱＲＳＴＵＶＷＸＹＺａｂｃｄｅｆｇｈｉｊｋｌｍｎｏｐｑｒｓｔｕｖｗｘｙｚ'
    hira = 'あいうえおかがきぎくぐけげこごさざしじすずせぜそぞただちぢつづてでとどなにぬねのはばぱひびぴふぶぷへべぺほぼぽまみむめもやゆよらりるれろわゐゑをんぁぃぅぇっゃゅょゎ'+'ゔ'
    kata = 'アイウエオカガキギクグケゲコゴサザシジスズセゼソゾタダチヂツヅテデトドナニヌネノハバパヒビピフブプヘベペホボポマミムメモヤユヨラリルレロワヰヱヲン'+'ヴヷヸヹヺァィゥヵヶェォッャョュヮ'
    symbols='、。，．・：；？！゛゜´｀¨＾‾＿ヽヾゝゞ〃仝々〆〇ー—‐／＼〜‖｜…‥‘’“”（）〔〕［］｛｝〈〉《》「」『』【】＋−±×÷＝≠＜＞≦≧∞∴♂♀°′″℃¥＄¢£％＃＆＊＠§☆★○●◎◇' + '◆□■△▲▽▼※〒→←↑↓〓∈∋⊆⊇⊂⊃∪∩∧∨¬⇒⇔∀∃∠⊥⌒∂∇≡≒≪≫√∽∝∵∫∬Å‰♯♭♪†‡¶◯'
    #greek='ΑΒΓΔΕΖΗΘΙΚΛΜΝΞΟΠΡΣΤΥΦΧΨΩαβγδεζηθικλμνξοπρστυφχψω'
    #rosian='АБВГДЕЁЖЗИЙКЛМНОПРСТУФХЦЧШЩЪЫЬЭЮЯабвгдеёжзийклмнопрстуфхцчшщъыьэюя'
    #digit_symbols='①②③④⑤⑥⑦⑧⑨⑩⑪⑫⑬⑭⑮⑯⑰⑱⑲⑳⑴⑵⑶⑷⑸⑹⑺⑻⑼⑽⑾⑿⒀⒁⒂⒃⒄⒅⒆⒇❶❷❸❹❺❻❼❽❾⒈⒉⒊⒋⒌⒍⒎⒏⒐'
    #alpha_symbols='ⅠⅡⅢⅣⅤⅥⅦⅧⅨⅩⅪⅫⅰⅱⅲⅳⅴⅵⅶⅷⅸⅹⅺⅻ⒜⒝⒞⒟⒠⒡⒢⒣⒤⒥⒦⒧⒨⒩⒪⒫⒬⒭⒮⒯⒰⒱⒲⒳⒴⒵'
    #units='㎜㎟㎝㎠㎤㎡㎥㎞㎢㎎㎏㏄㎖㎗ℓ㎘㎳㎲㎱㎰℉㏔㏋㎐㎅㎆㎇№㏍℡'
    #suits='♤♧♡♢♠♣♥♦〠☎〄☞☜☝☟⇆⇄⇅⇨⇦⇧⇩'
    #etc='①②③④⑤⑥⑦⑧⑨⑩⑪⑫⑬⑭⑮⑯⑰⑱⑲⑳ⅠⅡⅢⅣⅤⅥⅦⅧⅨⅩ㍉㌔㌢㍍㌘㌧㌃㌶㍑㍗㌍㌦㌣㌫㍊㌻㎜㎝㎞㎎㎏㏄㎡㍻〝〟№㏍℡㊤㊥㊦㊧㊨㈱㈲㈹㍾㍽㍼≒≡∫∮∑√⊥∠∟⊿∵∩∪㊙'
    #etc2='㍉㌢㍍㌔㌖㌅㌳㍎㌃㌶㌘㌕㌧㍑㍊㌹㍗㌍㍂㌣㌦㌻㌫㌀㌞㌪㌱㍇㍾㍽㍼㍻㍿∮∟⊿〝'

    # RAM で作成済の常用漢字リストを用いて単漢字リストを作成
    # 平成 22 年の改定により常用漢字は 2136 文字ある
    chars_list = [ch for ch in num_alpha+hira+kata+symbols]+ RAM.chars_joyo().char_list
    not_chars_list = []
    for wrd in tqdm(words):
        for ch in wrd:
            if (ch not in chars_list) and (ch not in not_chars_list):
                not_chars_list.append(ch)
    not_chars_list = sorted(not_chars_list)
    grapheme = chars_list + not_chars_list
    # 上記の処理により grapheme には 2768 文字である。
    # これに特殊トークン 4 つ ['<PAD>', '<SOW>', '<EOW>', '<UNK>'] を加えたリストを返す

    return ['<PAD>', '<SOW>', '<EOW>', '<UNK>'] + grapheme

grapheme = _grapheme()
# Out:
#   0%|          | 0/26877 [00:00<?, ?it/s]

# %% [markdown]
# ## 0.7 PyTorch 用のデータセット定義

# %%
from torch.utils.data import Dataset
import gensim

class psylex71_w2v_Dataset(Dataset):
    def __init__(self,
                 direction='s2p',  # ['s2p', 'p2s']
                 source='seme',    # エンコーダ用 入力データ, ['orth', seme', 'phon'] のいずれか一つ
                 target='phon',    # デコーダ用 出力データ ,  ['orth', seme', 'phon'] のいずれか一つ
                 w2v:gensim.models.keyedvectors.KeyedVectors=w2v_psylex71,
                 old_ds:RAM.dataset.Psylex71_Dataset=psylex71_ds,
                 mecab_yomi=yomi,
                 grapheme:list=grapheme,
                ):

        super().__init__()

        self.direction = 's2p' if direction == 's2p' else direction
        self.w2v = w2v
        self.old_ds = old_ds
        self.mecab_yomi = yomi         # 未知の単語が入力された場合 MeCab を使って読みをえるため
        self.grapheme = grapheme

        self.words = w2v.index_to_key  # gensim の KeyedVectors を利用して単語リストとする
        self.W = w2v.vectors

        # 訓令式に従った日本語ローマ字表記 `kurei.py` 参照
        self.phoneme = ['<PAD>', '<SOW>', '<EOW>', '<UNK>', # 特殊トークン，純に，埋め草，語頭，語末，未知
                        'a', 'i', 'u', 'e', 'o',            # 母音
                        'a:', 'i:', 'u:', 'e:', 'o:',       # 長母音
                        'N', 'Q',                           # 撥音，拗音
                        'b', 'by', 'ch', 'd', 'dy', 'f', 'g', 'gy', 'h', 'hy', # 子音
                        'j', 'k', 'ky', 'm', 'my', 'n', 'ny',  'p', 'py', 'r', # 子音
                        'ry', 's', 'sy', 't', 'ty', 'w', 'y', 'z', 'zy']       # 子音

        self.source, self.target = source, target


    def __getitem__(self,
                    idx:int):
        wrd = self.words[idx]

        if self.source == 'phon':
            src = torch.LongTensor(self.wrd2phon_ids(wrd))
        elif self.source == 'seme':
            src = torch.tensor(self.w2v.get_vector(idx))
        elif self.source == 'orth':
            src = torch.LongTensor(self.wrd2wrd_ids(wrd))
        else:
            src = None

        if self.target == 'phon':
            tgt = torch.LongTensor(self.wrd2phon_ids(wrd))
        elif self.target == 'seme':
            tgt = torch.tensor(self.w2v.get_vector(idx))
        elif self.target == 'orth':
            tgt = torch.LongTensor(self.wrd2wrd_ids(wrd))
        else:
            tgt = None

        return src, tgt

    def __getitem__saved(self,  # 旧バージョン
                    idx:int,
                    direction:str=None):
        wrd = self.words[idx]
        if direction == None:
            direction = self.direction
        if direction == 'p2s':
            X = torch.LongTensor(self.wrd2phon_ids(wrd))
            y = torch.tensor(self.w2v.get_vector(idx))
        else:
            y = torch.LongTensor(self.wrd2phon_ids(wrd))
            X = torch.tensor(self.w2v.get_vector(idx))

        return X, y


    def __len__(self):
        return len(self.w2v)

    def getitem(self,
                idx:int):
        wrd = self.words[idx]
        _yomi = self.wrd2yomi(wrd)
        _yomi = kunrei(_yomi).split(' ')
        phon_ids = [self.phoneme.index(idx) for idx in _yomi]
        orth_ids = [self.grapheme.index(idx) for idx in wrd]
        return wrd, _yomi, phon_ids, orth_ids

    def wrd2orth_ids(self, wrd:str)->list:
        ids = [self.grapheme.index(ch) for ch in wrd]
        return ids

    def wrd2phon_ids(self, wrd:str)->list:
        _yomi = self.wrd2yomi(wrd)
        _yomi = kunrei(_yomi).split(' ')
        ids = [self.phoneme.index(idx) for idx in _yomi]
        ids = [self.phoneme.index('<SOW>')] + ids + [self.phoneme.index('<EOW>')]
        return ids

    def get_wrdidx_from_word(self, wrd:str):
        if wrd in self.words:
            wrd_idx = self.w2v.get_index(wrd)
        else:
            wrd_idx = -1
        return wrd_idx

    def wrd2emb(self, wrd:str)->np.ndarray:
        if wrd in self.words:
            return self.w2v.get_vector(wrd)
        else:
            return None

    def wrd2wrd_idx(self, wrd:str)->int:
        if wrd in self.words:
            return self.words.index(wrd)
        else:
            return None

    def wrd_idx2wrd(self, idx:int)->str:
        if 0 <= idx and idx < len(self.words):
            return self.words[idx]
        else:
            return None

    def wrd2onehot(self, wrd:str)->np.ndarray:
        ret = np.zeros((self.W.shape[0],), dtype=np.int32)
        if wrd in self.words:
            ret[self.w2v.get_index(wrd)] = 1
            return ret
        else:
            return None

    def phon_ids2phn(self, ids:list):
        return "".join([self.phoneme[idx] for idx in ids])

    def wrd2yomi(self, wrd:str)->list:
        if wrd in self.words:
            _yomi = self.old_ds.orth2info_dict[wrd]['ヨミ']
        else:
            _yomi = self.mecab_yomi(wrd).strip().split()[0]
        return _yomi

    def wrd2info(self, wrd:str)->dict:
        if wrd in self.words:
            return self.old_ds.orth2info_dict[wrd]
        else:
            return None


_psylex71_ds = psylex71_w2v_Dataset(source='seme', target='phon')

# 全部で 9 通りのデータセットを定義
_psylex71_ds_s2p = psylex71_w2v_Dataset(source='seme', target='phon')
_psylex71_ds_s2o = psylex71_w2v_Dataset(source='seme', target='orth')
_psylex71_ds_s2s = psylex71_w2v_Dataset(source='seme', target='seme')

_psylex71_ds_p2s = psylex71_w2v_Dataset(source='phon', target='seme')
_psylex71_ds_p2o = psylex71_w2v_Dataset(source='phon', target='orth')
_psylex71_ds_p2p = psylex71_w2v_Dataset(source='phon', target='phon')

_psylex71_ds_o2p = psylex71_w2v_Dataset(source='orth', target='phon')
_psylex71_ds_o2s = psylex71_w2v_Dataset(source='orth', target='seme')
_psylex71_ds_o2o = psylex71_w2v_Dataset(source='orth', target='orth')


# 以下確認作業
N = np.random.randint(_psylex71_ds.__len__())
wrd = _psylex71_ds.wrd_idx2wrd(N)
print(f'_Wrd:{wrd}\n',
      f'_psylex71_ds.wrd2phon_ids({wrd}):{_psylex71_ds.wrd2phon_ids(wrd)}\n',
      f'_psylex71_ds.phon_ids2phn(_psylex71_ds.wrd2phon_ids({wrd})):{_psylex71_ds.phon_ids2phn(_psylex71_ds.wrd2phon_ids(wrd))}\n',
      f'_psylex71_ds.wrd2yomi({wrd}): {_psylex71_ds.wrd2yomi(wrd)}\n',
      f'_psylex71_ds.wrd2wrd_idx({wrd}): {_psylex71_ds.wrd2wrd_idx(wrd)}\n',
      f'_psylex71_ds.wrd2orth_idx({wrd}): {_psylex71_ds.wrd2orth_ids(wrd)}\n',
      f'_psylex71_ds.wrd2info({wrd}): {_psylex71_ds.wrd2info(wrd)}')
# Out:
# _Wrd:コンセプト
#  _psylex71_ds.wrd2phon_ids(コンセプト):[1, 27, 8, 14, 37, 7, 33, 6, 39, 8, 2]
#  _psylex71_ds.phon_ids2phn(_psylex71_ds.wrd2phon_ids(コンセプト)):<SOW>koNseputo<EOW>
#  _psylex71_ds.wrd2yomi(コンセプト): コンセプト
#  _psylex71_ds.wrd2wrd_idx(コンセプト): 20654
#  _psylex71_ds.wrd2orth_idx(コンセプト): [162, 221, 170, 197, 182]
#  _psylex71_ds.wrd2info(コンセプト): {'orth': 'コンセプト', '品詞': '普名', '頻度': 397, 'ヨミ': 'コンセプト', 'phon': ['k', 'o', 'N', 's', 'e', 'p', 'u', 't', 'o']}

# %% [markdown]
# ## 0.8 DataLoader の定義

# %%
from torch.utils.data import Dataset, DataLoader
#import numpy as np

def _collate_fn(batch):
    inps, tgts = list(zip(*batch))
    inps = list(inps)
    tgts = list(tgts)
    return inps, tgts

batch_size = 1024
dataloader = DataLoader(dataset=_psylex71_ds,
                        batch_size=batch_size,
                        shuffle=True,
                        num_workers=0,
                        collate_fn=_collate_fn)

# %%
# このセルは現在未使用。
# 全データを，ランダムに訓練データと検証データとに分割し，訓練データで訓練しつつ，検証データた汎化性能を測るため。
# 現時点では，全データを学習させていてる
N_train = int(_psylex71_ds.__len__() * 0.9)
N_test  = _psylex71_ds.__len__() - N_train
train_dataset, val_dataset = torch.utils.data.random_split(dataset=_psylex71_ds, lengths=(N_train, N_test))

# %% [markdown]
# # 1 復唱モデル
#
# <div style="font-family:serif;font-size:14pt;color:purple;font-weight:900">
#
# PyTorch RNN モデルの実装に対する注意メモ
#
# * Encoder 側のデータと Decoder 側のデータそれぞれに対して Padding の処理を行う。
# * Encoder 側のデータには Padding 値として `0` で埋める。
# * Decoder 側のデータをモデルの forward で使う場合には、Padding 値は `0` を埋める。
# * ただし，Decoder 側のデータを教師データとして使う場合には，Padding 値には -1 を用いて，埋めることに注意。
# * `nn.Embedding()` のオプションに `padding_idx=O` を付け，`CrosEntropyLoss` のオプションに `ignore_index=-1` を付ける。
#
# </div>

# %% [markdown]
# ## 1.1 モデルの定義

# %%
# Define model
import torch.nn as nn
import torch.nn.functional as F
#import torch.optim as optim
#from torch.utils.data import Dataset, DataLoader

class EncDec_w_Att(nn.Module):
    """ 注意つき符号化器‐復号化器モデル
    Bahdanau, Cho, & Bengio (2015) NEURAL MACHINE TRANSLATION BY JOINTLY LEARNING TO ALIGN AND TRANSLATE, arXiv:1409.0473
    """
    def __init__(self,
                 enc_vocab_size:int,
                 dec_vocab_size:int,
                 n_hid:int,
                 n_layers:int=2,
                 bidirectional:bool=False):
        super().__init__()

        # Encoder 側の入力トークン id を多次元ベクトルに変換
        self.encoder_emb = nn.Embedding(num_embeddings=enc_vocab_size,
                                        embedding_dim=n_hid,
                                        padding_idx=0)

        # Decoder 側の入力トークン id を多次元ベクトルに変換
        self.decoder_emb = nn.Embedding(num_embeddings=dec_vocab_size,
                                        embedding_dim=n_hid,
                                        padding_idx=0)

        # Encoder LSTM 本体
        self.encoder = nn.LSTM(input_size=n_hid,
                               hidden_size=n_hid,
                               num_layers=n_layers,
                               batch_first=True,
                               bidirectional=bidirectional)

        # Decoder LSTM 本体
        self.decoder = nn.LSTM(input_size=n_hid,
                               hidden_size=n_hid,
                               num_layers=n_layers,
                               batch_first=True,
                               bidirectional=bidirectional)

        # 文脈ベクトルと出力ベクトルの合成を合成する層
        bi_fact = 2 if bidirectional else 1
        self.combine_layer = nn.Linear(bi_fact * 2 * n_hid, n_hid)

        # 最終出力層
        self.out_layer = nn.Linear(n_hid, dec_vocab_size)

    def forward(self, enc_inp, dec_inp):

        enc_emb = self.encoder_emb(enc_inp)
        enc_out, (hnx, cnx) = self.encoder(enc_emb)

        dec_emb = self.decoder_emb(dec_inp)
        dec_out, (hny, cny) = self.decoder(dec_emb,(hnx, cnx))

        # enc_out は (バッチサイズ，ソースの単語数，中間層の次元数)
        # ソース側 (enc_out) の各単語とターゲット側 (dec_out) の各単語との類似度を測定するため
        # 両テンソルの内積をとるため ソース側 (enc_out) の軸を入れ替え
        enc_outP = enc_out.permute(0,2,1)

        # sim の形状は (バッチサイズ, 中間層の次元数，ソースの単語数)
        sim = torch.bmm(dec_out, enc_outP)

        # sim の各次元のサイズを記録
        batch_size, dec_word_size, enc_word_size = sim.shape

        # sim に対して，ソフトマックスを行うため形状を変更
        simP = sim.reshape(batch_size * dec_word_size, enc_word_size)

        # simP のソフトマックスを用いて注意の重み alpha を算出
        alpha = F.softmax(simP,dim=1).reshape(batch_size, dec_word_size, enc_word_size)

        # 注意の重み alpha に encoder の出力を乗じて，文脈ベクトル c_t とする
        c_t = torch.bmm(alpha, enc_out)

        # torch.cat だから c_t と dec_out とで合成
        dec_out_ = torch.cat([c_t, dec_out], dim=2)
        #print(f'c_t.size():{c_t.size()}, dec_out.size():{dec_out.size()}')
        #print(f'dec_out_.size():{dec_out.size()}')
        dec_out_ = self.combine_layer(dec_out_)
        return self.out_layer(dec_out_)


# 以下確認作業
n_hid = 64
n_layers = 1
bidirectional=True
# 直下行で，enc_vocab_size と dec_vocab_size を phoneme にしているので，音韻複勝課題に相当する
enc_dec = EncDec_w_Att(enc_vocab_size=len(_psylex71_ds.phoneme),
                       dec_vocab_size=len(_psylex71_ds.phoneme),
                       n_layers=n_layers,
                       bidirectional=bidirectional,
                       n_hid=n_hid).to(device)
print(enc_dec.eval())
# _init = enc_dec.encoder_emb.weight
# print(_init)
#
# for x, y in dataloader:
#     print(x[0].size(), y[0].size())
#     break
# Out:
# EncDec_w_Att(
#   (encoder_emb): Embedding(45, 64, padding_idx=0)
#   (decoder_emb): Embedding(45, 64, padding_idx=0)
#   (encoder): LSTM(64, 64, batch_first=True, bidirectional=True)
#   (decoder): LSTM(64, 64, batch_first=True, bidirectional=True)
#   (combine_layer): Linear(in_features=256, out_features=64, bias=True)
#   (out_layer): Linear(in_features=64, out_features=45, bias=True)
# )

# %% [markdown]
# ## 1.2 訓練の実施

# %%
import torch.optim as optim
from torch.nn.utils.rnn import pad_sequence

start_time = time.time()   # 開始時刻の保存
# ハイパーパラメータの設定
n_hid = 64
n_layers = 1
epochs = 10
bidirectional=True

# モデルの定義
model = EncDec_w_Att(enc_vocab_size=len(_psylex71_ds.phoneme),
                     dec_vocab_size=len(_psylex71_ds.phoneme),
                     n_layers=n_layers,
                     bidirectional=bidirectional,
                     n_hid=n_hid).to(device)

# データローダの定義
batch_size = 1024
dataloader = DataLoader(dataset=_psylex71_ds_s2p,
#dataloader = DataLoader(dataset=_psylex71_ds,
                        batch_size=batch_size,
                        shuffle=True,
                        num_workers=0,
                        collate_fn=_collate_fn)

# 最適化関数の定義
optimizer = optim.Adam(model.parameters(),lr=0.001)
# 損失関数
criterion = nn.CrossEntropyLoss(ignore_index=-1)

# 訓練ループ
model.train()
interval = int(_psylex71_ds.__len__()/batch_size) >> 2
losses = []
for epoch in range(epochs):
    i = 0
    for x, y in dataloader:
        enc_inp = pad_sequence(y, batch_first=True).to(device)
        dec_inp = pad_sequence(y, batch_first=True).to(device)[:,:]
        tch = pad_sequence(y, batch_first=True, padding_value=-1.0).to(device)
        out = model(enc_inp, dec_inp)
        loss = criterion(out[0], tch[0])
        for h in range(1,len(tch)):
            loss += criterion(out[h], tch[h])
        losses.append(loss.item()/len(x))

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        i += 1
        if (i % interval) == 0:
            print(f'epoch:{epoch:2d}, batch:{i:2d}, loss:{loss.item()/len(x):.3f}')

end_time = time.time()
total_time = end_time - start_time
total_time_str = str(datetime.timedelta(seconds=int(total_time)))
print(f'Training time {total_time_str}')

plt.plot(losses)
plt.title(f'epochs:{epochs}, batch_size:{batch_size}, n_hid:{n_hid}, n_layers:{n_layers}, time collapsed:{total_time_str}')
plt.show()
# Out:
# epoch: 0, batch: 6, loss:3.601
# epoch: 0, batch:12, loss:3.230
# epoch: 0, batch:18, loss:2.613
# epoch: 0, batch:24, loss:2.123
# epoch: 1, batch: 6, loss:1.514
# epoch: 1, batch:12, loss:1.175
# epoch: 1, batch:18, loss:0.914
# epoch: 1, batch:24, loss:0.699
# epoch: 2, batch: 6, loss:0.523
# epoch: 2, batch:12, loss:0.416
# epoch: 2, batch:18, loss:0.361
# epoch: 2, batch:24, loss:0.285
# epoch: 3, batch: 6, loss:0.201
# epoch: 3, batch:12, loss:0.163
# epoch: 3, batch:18, loss:0.135
# epoch: 3, batch:24, loss:0.098
# epoch: 4, batch: 6, loss:0.069
# epoch: 4, batch:12, loss:0.060
# epoch: 4, batch:18, loss:0.043
# epoch: 4, batch:24, loss:0.040
# epoch: 5, batch: 6, loss:0.036
# epoch: 5, batch:12, loss:0.031
# epoch: 5, batch:18, loss:0.022
# epoch: 5, batch:24, loss:0.023
# epoch: 6, batch: 6, loss:0.020
# epoch: 6, batch:12, loss:0.017
# epoch: 6, batch:18, loss:0.017
# epoch: 6, batch:24, loss:0.015
# epoch: 7, batch: 6, loss:0.012
# epoch: 7, batch:12, loss:0.011
# epoch: 7, batch:18, loss:0.012
# epoch: 7, batch:24, loss:0.011
# epoch: 8, batch: 6, loss:0.012
# epoch: 8, batch:12, loss:0.009
# epoch: 8, batch:18, loss:0.007
# epoch: 8, batch:24, loss:0.007
# epoch: 9, batch: 6, loss:0.006
# epoch: 9, batch:12, loss:0.006
# epoch: 9, batch:18, loss:0.007
# epoch: 9, batch:24, loss:0.005
# Training time 0:04:02

# %% [markdown]
# ## 1.3 結果の検証

# %%
isPrint = True # True/False を指定することで結果を印字
errors = []
model.eval()
for N in tqdm(range(_psylex71_ds.__len__())):
    x =_psylex71_ds.__getitem__(N)[1].to(device)

    enc_inp, dec_inp = x[1:].unsqueeze(0), x[:-1].unsqueeze(0)
    y = model(enc_inp, dec_inp).to('cpu')
    y_ids = np.argmax(y.squeeze(0).detach().numpy(), axis=1)[1:]
    y_phon = _psylex71_ds.phon_ids2phn(y_ids)
    grand_truth = _psylex71_ds.getitem(N)

    n_correct = np.array((y_ids == grand_truth[2]).sum())
    isOK = n_correct == len(grand_truth[2])

    if not isOK:
        errors.append((N,y_ids))
        if isPrint:
            color = 'grey' if isOK else 'red'
            print(colored((f'idx:{N:5d}',
                           f'出力:{y_phon}',
                           f'正解:{_psylex71_ds.phon_ids2phn(grand_truth[2])}',
                           f'単語:{grand_truth[0]}',
                          ), color, attrs=['bold']))

cr = len(errors) / N
#cr = len(errors) / _psylex71_ds.__len__()
print(f'総エラー数:{len(errors)}',
      f'正解率:{(1.-cr)*100:.3f}%')
# Out:
#   0%|          | 0/26877 [00:00<?, ?it/s]
# ('idx:   30', '出力:ooumei', '正解:hyoumei', '単語:表明')
# ('idx:   53', '出力:niNdou', '正解:niNgyou', '単語:人形')
# ('idx:   63', '出力:doukaku', '正解:doumyaku', '単語:動脈')
# ('idx:   80', '出力:oousi', '正解:hyousi', '単語:表紙')
# ('idx:  101', '出力:jumou', '正解:jumyou', '単語:寿命')
# ('idx:  113', '出力:kegaaa', '正解:kegawa', '単語:毛皮')
# ('idx:  147', '出力:p<EOW>seNto', '正解:pa:seNto', '単語:％')
# ('idx:  159', '出力:aa', '正解:wa', '単語:わ')
# ('idx:  176', '出力:daitou<EOW>ou', '正解:daitouryou', '単語:大統領')
# ('idx:  179', '出力:aatasi', '正解:watasi', '単語:私')
# ('idx:  182', '出力:kidou', '正解:kigyou', '単語:企業')
# ('idx:  202', '出力:haQoou', '正解:haQpyou', '単語:発表')
# ('idx:  209', '出力:sousa', '正解:chousa', '単語:調査')
# ('idx:  210', '出力:daioou', '正解:daihyou', '単語:代表')
# ('idx:  241', '出力:kyou<EOW>oku', '正解:kyouryoku', '単語:協力')
# ('idx:  308', '出力:NouiN', '正解:byouiN', '単語:病院')
# ('idx:  328', '出力:jidou', '正解:jigyou', '単語:事業')
# ('idx:  330', '出力:aakaru', '正解:wakaru', '単語:わかる')
# ('idx:  344', '出力:gurdpu', '正解:guru:pu', '単語:グループ')
# ('idx:  371', '出力:kaaaru', '正解:kawaru', '単語:変わる')
# ('idx:  406', '出力:douuuu', '正解:dounyuu', '単語:導入')
# ('idx:  408', '出力:oouka', '正解:hyouka', '単語:評価')
# ('idx:  413', '出力:yuuuu', '正解:yunyuu', '単語:輸入')
# ('idx:  427', '出力:doukai', '正解:gyoukai', '単語:業界')
# ('idx:  459', '出力:m<SOW>k<EOW>', '正解:me:ka:', '単語:メーカー')
# ('idx:  497', '出力:do<EOW>oku', '正解:doryoku', '単語:努力')
# ('idx:  517', '出力:seNt<EOW>', '正解:seNta:', '単語:センター')
# ('idx:  519', '出力:aakaru', '正解:wakaru', '単語:分かる')
# ('idx:  567', '出力:saNdou', '正解:saNgyou', '単語:産業')
# ('idx:  578', '出力:mokuoou', '正解:mokuhyou', '単語:目標')
# ('idx:  595', '出力:i<EOW>ou', '正解:iryou', '単語:医療')
# ('idx:  621', '出力:ukykku', '正解:nyu:yo:ku', '単語:ニューヨーク')
# ('idx:  639', '出力:ttmu', '正解:ti:mu', '単語:チーム')
# ('idx:  677', '出力:dousei', '正解:gyousei', '単語:行政')
# ('idx:  684', '出力:aaaseru', '正解:awaseru', '単語:合わせる')
# ('idx:  693', '出力:touoou', '正解:touhyou', '単語:投票')
# ('idx:  698', '出力:aasiNtoN', '正解:wasiNtoN', '単語:ワシントン')
# ('idx:  743', '出力:yakuaari', '正解:yakuwari', '単語:役割')
# ('idx:  755', '出力:s<EOW>bisu', '正解:sa:bisu', '単語:サービス')
# ('idx:  769', '出力:okinaaa', '正解:okinawa', '単語:沖縄')
# ('idx:  783', '出力:syokioou', '正解:syokichou', '単語:書記長')
# ('idx:  790', '出力:sei<EOW>oku', '正解:seiryoku', '単語:勢力')
# ('idx:  800', '出力:uaamaaaru', '正解:uwamawaru', '単語:上回る')
# ('idx:  802', '出力:taiaaN', '正解:taiwaN', '単語:台湾')
# ('idx:  805', '出力:miyazaaa', '正解:miyazawa', '単語:宮沢')
# ('idx:  807', '出力:si<EOW>ou', '正解:siryou', '単語:資料')
# ('idx:  811', '出力:kaku<EOW>ou', '正解:kakuryou', '単語:閣僚')
# ('idx:  845', '出力:eougeN', '正解:hyougeN', '単語:表現')
# ('idx:  861', '出力:eidou', '正解:eigyou', '単語:営業')
# ('idx:  878', '出力:t<SOW>ma', '正解:te:ma', '単語:テーマ')
# ('idx:  879', '出力:kou<EOW>uu', '正解:kouryuu', '単語:交流')
# ('idx:  880', '出力:aatanabe', '正解:watanabe', '単語:渡辺')
# ('idx:  896', '出力:aakai', '正解:wakai', '単語:若い')
# ('idx:  908', '出力:kozaaa', '正解:kozawa', '単語:小沢')
# ('idx:  921', '出力:toiaaase', '正解:toiawase', '単語:問い合わせ')
# ('idx:  942', '出力:aatasitati', '正解:watasitati', '単語:私たち')
# ('idx:  969', '出力:kouuuu', '正解:kounyuu', '単語:購入')
# ('idx:  979', '出力:k<SOW>su', '正解:ke:su', '単語:ケース')
# ('idx: 1008', '出力:koNodta:', '正解:koNpyu:ta:', '単語:コンピューター')
# ('idx: 1031', '出力:kuaaaaru', '正解:kuwawaru', '単語:加わる')
# ('idx: 1037', '出力:meNbm', '正解:meNba:', '単語:メンバー')
# ('idx: 1049', '出力:aakamono', '正解:wakamono', '単語:若者')
# ('idx: 1050', '出力:kouoou', '正解:kouhyou', '単語:公表')
# ('idx: 1077', '出力:<EOW>okou', '正解:ryokou', '単語:旅行')
# ('idx: 1091', '出力:seN<EOW>aku', '正解:seNryaku', '単語:戦略')
# ('idx: 1102', '出力:syuuuuu', '正解:syuunyuu', '単語:収入')
# ('idx: 1144', '出力:hai<EOW>o', '正解:hairyo', '単語:配慮')
# ('idx: 1150', '出力:oou', '正解:hyou', '単語:票')
# ('idx: 1167', '出力:aazuka', '正解:wazuka', '単語:わずか')
# ('idx: 1180', '出力:giaaku', '正解:giwaku', '単語:疑惑')
# ('idx: 1186', '出力:kyouaakoku', '正解:kyouwakoku', '単語:共和国')
# ('idx: 1188', '出力:<EOW>oukiN', '正解:ryoukiN', '単語:料金')
# ('idx: 1231', '出力:sut<EOW>to', '正解:suta:to', '単語:スタート')
# ('idx: 1242', '出力:d<SOW>ta', '正解:de:ta', '単語:データ')
# ('idx: 1253', '出力:enutttt', '正解:enuti:ti:', '単語:ＮＴＴ')
# ('idx: 1292', '出力:taiaa', '正解:taiwa', '単語:対話')
# ('idx: 1299', '出力:imjji', '正解:ime:ji', '単語:イメージ')
# ('idx: 1311', '出力:kakaaaru', '正解:kakawaru', '単語:かかわる')
# ('idx: 1342', '出力:jouki', '正解:byouki', '単語:病気')
# ('idx: 1381', '出力:juudouiN', '正解:juugyouiN', '単語:従業員')
# ('idx: 1384', '出力:kanagaaakeN', '正解:kanagawakeN', '単語:神奈川県')
# ('idx: 1392', '出力:soturou', '正解:sotugyou', '単語:卒業')
# ('idx: 1401', '出力:ooujou', '正解:hyoujou', '単語:表情')
# ('idx: 1411', '出力:deN<EOW>oku', '正解:deNryoku', '単語:電力')
# ('idx: 1412', '出力:iuuiN', '正解:nyuuiN', '単語:入院')
# ('idx: 1435', '出力:suusi', '正解:chuusi', '単語:中止')
# ('idx: 1439', '出力:enerugu', '正解:enerugi:', '単語:エネルギー')
# ('idx: 1473', '出力:kourou', '正解:kougyou', '単語:工業')
# ('idx: 1477', '出力:aadai', '正解:wadai', '単語:話題')
# ('idx: 1486', '出力:atu<EOW>oku', '正解:aturyoku', '単語:圧力')
# ('idx: 1488', '出力:kaN<EOW>ou', '正解:kaNryou', '単語:官僚')
# ('idx: 1489', '出力:toutatu', '正解:choutatu', '単語:調達')
# ('idx: 1505', '出力:<EOW>outou', '正解:ryoutou', '単語:両党')
# ('idx: 1519', '出力:mu<EOW>ou', '正解:muryou', '単語:無料')
# ('idx: 1586', '出力:aakate', '正解:wakate', '単語:若手')
# ('idx: 1589', '出力:r<SOW>gaN', '正解:re:gaN', '単語:レーガン')
# ('idx: 1596', '出力:touseNmiNsyusyugijiNmiNkyouwakoku', '正解:chouseNmiNsyusyugijiNmiNkyouwakoku', '単語:朝鮮民主主義人民共和国')
# ('idx: 1634', '出力:aariai', '正解:wariai', '単語:割合')
# ('idx: 1637', '出力:syuu<EOW>ou', '正解:syuuryou', '単語:終了')
# ('idx: 1682', '出力:eriiiN', '正解:erityiN', '単語:エリツィン')
# ('idx: 1708', '出力:reiritu', '正解:zeiritu', '単語:税率')
# ('idx: 1750', '出力:u<EOW>su', '正解:nyu:su', '単語:ニュース')
# ('idx: 1783', '出力:sararmmaN', '正解:sarari:maN', '単語:サラリーマン')
# ('idx: 1796', '出力:kuaasii', '正解:kuwasii', '単語:詳しい')
# ('idx: 1798', '出力:oouji', '正解:hyouji', '単語:表示')
# ('idx: 1803', '出力:eioou', '正解:eizou', '単語:映像')
# ('idx: 1812', '出力:saNuuu', '正解:saNnyuu', '単語:参入')
# ('idx: 1845', '出力:dakuteN', '正解:gyakuteN', '単語:逆転')
# ('idx: 1873', '出力:kauuu', '正解:kanyuu', '単語:加入')
# ('idx: 1880', '出力:douseki', '正解:gyouseki', '単語:業績')
# ('idx: 1903', '出力:araaareru', '正解:arawareru', '単語:現れる')
# ('idx: 1910', '出力:kuw<SOW>to', '正解:kuwe:to', '単語:クウェート')
# ('idx: 1922', '出力:kaaaru', '正解:kawaru', '単語:代わる')
# ('idx: 1938', '出力:saQk<EOW>', '正解:saQka:', '単語:サッカー')
# ('idx: 1940', '出力:koukyoujidou', '正解:koukyoujigyou', '単語:公共事業')
# ('idx: 1947', '出力:k<EOW>do', '正解:ka:do', '単語:カード')
# ('idx: 1978', '出力:p<EOW>tt', '正解:pa:ti:', '単語:パーティー')
# ('idx: 1993', '出力:kaiuuu', '正解:kainyuu', '単語:介入')
# ('idx: 2003', '出力:chuusyoukirou', '正解:chuusyoukigyou', '単語:中小企業')
# ('idx: 2005', '出力:yoaai', '正解:yowai', '単語:弱い')
# ('idx: 2008', '出力:<EOW>ousiN', '正解:ryousiN', '単語:両親')
# ('idx: 2036', '出力:tuutou', '正解:chuutou', '単語:中東')
# ('idx: 2050', '出力:nisigaaa', '正解:nisigawa', '単語:西側')
# ('idx: 2069', '出力:oou', '正解:hyou', '単語:表')
# ('idx: 2071', '出力:saibaNsou', '正解:saibaNchou', '単語:裁判長')
# ('idx: 2080', '出力:uuujou', '正解:nyuujou', '単語:入場')
# ('idx: 2081', '出力:oougokeN', '正解:hyougokeN', '単語:兵庫県')
# ('idx: 2087', '出力:sitamaaaru', '正解:sitamawaru', '単語:下回る')
# ('idx: 2092', '出力:toutaku', '正解:touchaku', '単語:到着')
# ('idx: 2122', '出力:yrroQpa', '正解:yo:roQpa', '単語:ヨーロッパ')
# ('idx: 2141', '出力:ssutoraria', '正解:o:sutoraria', '単語:オーストラリア')
# ('idx: 2146', '出力:bdmu', '正解:bu:mu', '単語:ブーム')
# ('idx: 2147', '出力:jun<SOW>bu', '正解:june:bu', '単語:ジュネーブ')
# ('idx: 2155', '出力:siNgaprru', '正解:siNgapo:ru', '単語:シンガポール')
# ('idx: 2175', '出力:bou<EOW>oku', '正解:bouryoku', '単語:暴力')
# ('idx: 2179', '出力:sdp<EOW>', '正解:su:pa:', '単語:スーパー')
# ('idx: 2189', '出力:eaQkateN', '正解:hyaQkateN', '単語:百貨店')
# ('idx: 2192', '出力:aakai', '正解:wakai', '単語:和解')
# ('idx: 2196', '出力:uuusi', '正解:nyuusi', '単語:入試')
# ('idx: 2204', '出力:rrru', '正解:ru:ru', '単語:ルール')
# ('idx: 2214', '出力:tai<EOW>ou', '正解:tairyou', '単語:大量')
# ('idx: 2220', '出力:uuugaku', '正解:nyuugaku', '単語:入学')
# ('idx: 2229', '出力:uuusatu', '正解:nyuusatu', '単語:入札')
# ('idx: 2241', '出力:syokurou', '正解:syokugyou', '単語:職業')
# ('idx: 2243', '出力:kaaasaki', '正解:kawasaki', '単語:川崎')
# ('idx: 2254', '出力:jidoudaN', '正解:jigyoudaN', '単語:事業団')
# ('idx: 2262', '出力:rrgu', '正解:ri:gu', '単語:リーグ')
# ('idx: 2264', '出力:rsyto', '正解:ru:to', '単語:ルート')
# ('idx: 2267', '出力:touseNhaNtou', '正解:chouseNhaNtou', '単語:朝鮮半島')
# ('idx: 2275', '出力:kanagaaa', '正解:kanagawa', '単語:神奈川')
# ('idx: 2286', '出力:neQtow<EOW>ku', '正解:neQtowa:ku', '単語:ネットワーク')
# ('idx: 2314', '出力:yuu<EOW>oku', '正解:yuuryoku', '単語:有力')
# ('idx: 2324', '出力:totuoeN', '正解:totuzeN', '単語:突然')
# ('idx: 2326', '出力:aNk<SOW>to', '正解:aNke:to', '単語:アンケート')
# ('idx: 2346', '出力:iNtati', '正解:iNtabyu:', '単語:インタビュー')
# ('idx: 2393', '出力:sirrru', '正解:siri:zu', '単語:シリーズ')
# ('idx: 2404', '出力:seiooudou', '正解:seizougyou', '単語:製造業')
# ('idx: 2420', '出力:geNsi<EOW>oku', '正解:geNsiryoku', '単語:原子力')
# ('idx: 2423', '出力:kotoaaru', '正解:kotowaru', '単語:断る')
# ('idx: 2424', '出力:tutaaaru', '正解:tutawaru', '単語:伝わる')
# ('idx: 2428', '出力:omoaaku', '正解:omowaku', '単語:思惑')
# ('idx: 2485', '出力:<EOW>ousi', '正解:ryousi', '単語:両氏')
# ('idx: 2489', '出力:<EOW>oujitu', '正解:ryoujitu', '単語:両日')
# ('idx: 2492', '出力:r<SOW>su', '正解:re:su', '単語:レース')
# ('idx: 2503', '出力:kaaa', '正解:kawa', '単語:川')
# ('idx: 2542', '出力:aarau', '正解:warau', '単語:笑う')
# ('idx: 2546', '出力:<EOW>uugaku', '正解:ryuugaku', '単語:留学')
# ('idx: 2571', '出力:eikyou<EOW>oku', '正解:eikyouryoku', '単語:影響力')
# ('idx: 2590', '出力:prraNdo', '正解:po:raNdo', '単語:ポーランド')
# ('idx: 2605', '出力:i:yd', '正解:i:yu:', '単語:ＥＵ')
# ('idx: 2617', '出力:kodaaaru', '正解:kodawaru', '単語:こだわる')
# ('idx: 2618', '出力:sagaaa', '正解:sagawa', '単語:佐川')
# ('idx: 2624', '出力:siN<EOW>aku', '正解:siNryaku', '単語:侵略')
# ('idx: 2627', '出力:iooN', '正解:izoN', '単語:依存')
# ('idx: 2640', '出力:aaga', '正解:waga', '単語:わが')
# ('idx: 2670', '出力:iiaatasu', '正解:iiwatasu', '単語:言い渡す')
# ('idx: 2684', '出力:ap<EOW>to', '正解:apa:to', '単語:アパート')
# ('idx: 2703', '出力:douji', '正解:gyouji', '単語:行事')
# ('idx: 2705', '出力:mar<SOW>sia', '正解:mare:sia', '単語:マレーシア')
# ('idx: 2714', '出力:rikursyto', '正解:rikuru:to', '単語:リクルート')
# ('idx: 2726', '出力:okinaaakeN', '正解:okinawakeN', '単語:沖縄県')
# ('idx: 2760', '出力:g<SOW>mu', '正解:ge:mu', '単語:ゲーム')
# ('idx: 2780', '出力:uuusya', '正解:nyuusya', '単語:入社')
# ('idx: 2786', '出力:ooumeN', '正解:hyoumeN', '単語:表面')
# ('idx: 2787', '出力:oouroNka', '正解:hyouroNka', '単語:評論家')
# ('idx: 2832', '出力:puku', '正解:pi:ku', '単語:ピーク')
# ('idx: 2838', '出力:syourou', '正解:syougyou', '単語:商業')
# ('idx: 2844', '出力:takust', '正解:takusi:', '単語:タクシー')
# ('idx: 2862', '出力:oougikai', '正解:hyougikai', '単語:評議会')
# ('idx: 2877', '出力:suprdo', '正解:supi:do', '単語:スピード')
# ('idx: 2881', '出力:iNt<EOW>neQto', '正解:iNta:neQto', '単語:インターネット')
# ('idx: 2892', '出力:rousyu', '正解:gyousyu', '単語:業種')
# ('idx: 2911', '出力:bu<EOW>oku', '正解:buryoku', '単語:武力')
# ('idx: 2918', '出力:<EOW>uugakusei', '正解:ryuugakusei', '単語:留学生')
# ('idx: 2919', '出力:suemu', '正解:si:emu', '単語:ＣＭ')
# ('idx: 2922', '出力:koNs<EOW>to', '正解:koNsa:to', '単語:コンサート')
# ('idx: 2924', '出力:daikidou', '正解:daikigyou', '単語:大企業')
# ('idx: 2942', '出力:soumusou', '正解:soumuchou', '単語:総務庁')
# ('idx: 2951', '出力:meQsjji', '正解:meQse:ji', '単語:メッセージ')
# ('idx: 2973', '出力:enuji:e', '正解:enuji:o:', '単語:ＮＧＯ')
# ('idx: 2981', '出力:tesuu<EOW>ou', '正解:tesuuryou', '単語:手数料')
# ('idx: 2996', '出力:aatari', '正解:watari', '単語:わたり')
# ('idx: 3003', '出力:frramu', '正解:fo:ramu', '単語:フォーラム')
# ('idx: 3004', '出力:<EOW>uutuu', '正解:ryuutuu', '単語:流通')
# ('idx: 3006', '出力:grru', '正解:go:ru', '単語:ゴール')
# ('idx: 3023', '出力:aaisaN', '正解:zaisaN', '単語:財産')
# ('idx: 3032', '出力:jNsebuN', '正解:ji:sebuN', '単語:Ｇ７')
# ('idx: 3046', '出力:syu<EOW>oku', '正解:syuryoku', '単語:主力')
# ('idx: 3048', '出力:buru', '正解:bi:ru', '単語:ビール')
# ('idx: 3054', '出力:saNsu', '正解:chaNsu', '単語:チャンス')
# ('idx: 3062', '出力:itikaaa', '正解:itikawa', '単語:市川')
# ('idx: 3066', '出力:fusaaasii', '正解:fusawasii', '単語:ふさわしい')
# ('idx: 3071', '出力:sousakai', '正解:chousakai', '単語:調査会')
# ('idx: 3080', '出力:douseikaikaku', '正解:gyouseikaikaku', '単語:行政改革')
# ('idx: 3085', '出力:pere', '正解:peru:', '単語:ペルー')
# ('idx: 3093', '出力:suaaru', '正解:suwaru', '単語:座る')
# ('idx: 3099', '出力:rrdo', '正解:ri:do', '単語:リード')
# ('idx: 3102', '出力:gaikokukaaase', '正解:gaikokukawase', '単語:外国為替')
# ('idx: 3124', '出力:sousakeQka', '正解:chousakeQka', '単語:調査結果')
# ('idx: 3129', '出力:b<SOW>su', '正解:be:su', '単語:ベース')
# ('idx: 3138', '出力:saaagi', '正解:sawagi', '単語:騒ぎ')
# ('idx: 3162', '出力:p<SOW>su', '正解:pe:su', '単語:ペース')
# ('idx: 3168', '出力:maaari', '正解:mawari', '単語:周り')
# ('idx: 3180', '出力:tut', '正解:tua:', '単語:ツアー')
# ('idx: 3192', '出力:kakaaari', '正解:kakawari', '単語:かかわり')
# ('idx: 3202', '出力:uuusyu', '正解:nyuusyu', '単語:入手')
# ('idx: 3208', '出力:geN<EOW>ou', '正解:geNryou', '単語:原料')
# ('idx: 3218', '出力:tourot', '正解:touroN', '単語:討論')
# ('idx: 3240', '出力:sioou', '正解:sihyou', '単語:指標')
# ('idx: 3246', '出力:rrdo', '正解:ri:da:', '単語:リーダー')
# ('idx: 3248', '出力:apuru', '正解:api:ru', '単語:アピール')
# ('idx: 3296', '出力:dai<SOW>', '正解:daie:', '単語:ダイエー')
# ('idx: 3300', '出力:jitu<EOW>oku', '正解:jituryoku', '単語:実力')
# ('idx: 3308', '出力:gyorou', '正解:gyogyou', '単語:漁業')
# ('idx: 3328', '出力:pur<SOW>', '正解:pure:', '単語:プレー')
# ('idx: 3340', '出力:suzuN', '正解:si:zuN', '単語:シーズン')
# ('idx: 3350', '出力:mddo', '正解:mu:do', '単語:ムード')
# ('idx: 3359', '出力:jpuN', '正解:o:puN', '単語:オープン')
# ('idx: 3393', '出力:rikuretojikeN', '正解:rikuru:tojikeN', '単語:リクルート事件')
# ('idx: 3401', '出力:kyouaatou', '正解:kyouwatou', '単語:共和党')
# ('idx: 3406', '出力:kyuu<EOW>ou', '正解:kyuuryou', '単語:給料')
# ('idx: 3413', '出力:touoouritu', '正解:touhyouritu', '単語:投票率')
# ('idx: 3421', '出力:hakumaN', '正解:hyakumaN', '単語:百万')
# ('idx: 3435', '出力:pu<EOW>ru', '正解:pi:a:ru', '単語:ＰＲ')
# ('idx: 3440', '出力:tokuoou', '正解:tokuhyou', '単語:得票')
# ('idx: 3466', '出力:suku', '正解:suki:', '単語:スキー')
# ('idx: 3475', '出力:suwjdeN', '正解:suwe:deN', '単語:スウェーデン')
# ('idx: 3487', '出力:ttbtesu', '正解:ti:bi:esu', '単語:ＴＢＳ')
# ('idx: 3510', '出力:sourou', '正解:sougyou', '単語:操業')
# ('idx: 3512', '出力:haNgarr', '正解:haNgari:', '単語:ハンガリー')
# ('idx: 3532', '出力:hasegaaa', '正解:hasegawa', '単語:長谷川')
# ('idx: 3536', '出力:ooujuN', '正解:hyoujuN', '単語:標準')
# ('idx: 3566', '出力:brru', '正解:bo:ru', '単語:ボール')
# ('idx: 3587', '出力:aakaihito', '正解:wakaihito', '単語:若い人')
# ('idx: 3593', '出力:kopk', '正解:kopi:', '単語:コピー')
# ('idx: 3598', '出力:duuniku', '正解:gyuuniku', '単語:牛肉')
# ('idx: 3607', '出力:kaaa', '正解:kawa', '単語:かわ')
# ('idx: 3608', '出力:jidousya', '正解:jigyousya', '単語:事業者')
# ('idx: 3620', '出力:sonsy', '正解:soni:', '単語:ソニー')
# ('idx: 3622', '出力:wNN', '正解:wi:N', '単語:ウィーン')
# ('idx: 3634', '出力:m<SOW>toru', '正解:me:toru', '単語:メートル')
# ('idx: 3638', '出力:kyousou<EOW>oku', '正解:kyousouryoku', '単語:競争力')
# ('idx: 3645', '出力:kydba', '正解:kyu:ba', '単語:キューバ')
# ('idx: 3646', '出力:daNaa', '正解:daNwa', '単語:談話')
# ('idx: 3647', '出力:araaasu', '正解:arawasu', '単語:表す')
# ('idx: 3661', '出力:kddet<EOW>', '正解:ku:deta:', '単語:クーデター')
# ('idx: 3662', '出力:seaa', '正解:sewa', '単語:世話')
# ('idx: 3678', '出力:araaareru', '正解:arawareru', '単語:表れる')
# ('idx: 3705', '出力:chuu<EOW>uu', '正解:chuuryuu', '単語:駐留')
# ('idx: 3711', '出力:supskusumaN', '正解:supo:kusumaN', '単語:スポークスマン')
# ('idx: 3718', '出力:aatasi', '正解:watasi', '単語:わたし')
# ('idx: 3721', '出力:koaai', '正解:kowai', '単語:怖い')
# ('idx: 3724', '出力:oaari', '正解:owari', '単語:終わり')
# ('idx: 3725', '出力:kaaase', '正解:kawase', '単語:為替')
# ('idx: 3731', '出力:uuukoku', '正解:nyuukoku', '単語:入国')
# ('idx: 3740', '出力:keNsetudou', '正解:keNsetugyou', '単語:建設業')
# ('idx: 3750', '出力:suusiNbu', '正解:chuusiNbu', '単語:中心部')
# ('idx: 3759', '出力:de<EOW>e', '正解:debyu:', '単語:デビュー')
# ('idx: 3775', '出力:<EOW>ouhou', '正解:ryouhou', '単語:両方')
# ('idx: 3788', '出力:totiku', '正解:chotiku', '単語:貯蓄')
# ('idx: 3796', '出力:nakanokaaa', '正解:nakanokawa', '単語:中川')
# ('idx: 3810', '出力:kaioou', '正解:kaihyou', '単語:開票')
# ('idx: 3817', '出力:t<SOW>pu', '正解:te:pu', '単語:テープ')
# ('idx: 3827', '出力:seN<EOW>ou', '正解:seNryou', '単語:占領')
# ('idx: 3828', '出力:akasaN', '正解:akachaN', '単語:赤ちゃん')
# ('idx: 3848', '出力:<EOW>uusyutu', '正解:ryuusyutu', '単語:流出')
# ('idx: 3855', '出力:doseN', '正解:gyoseN', '単語:漁船')
# ('idx: 3861', '出力:jjri:gu', '正解:je:ri:gu', '単語:Ｊリーグ')
# ('idx: 3862', '出力:seN<EOW>oku', '正解:seNryoku', '単語:戦力')
# ('idx: 3887', '出力:deNaabaNgou', '正解:deNwabaNgou', '単語:電話番号')
# ('idx: 3901', '出力:kyaNpjN', '正解:kyaNpe:N', '単語:キャンペーン')
# ('idx: 3909', '出力:yhgosurabia', '正解:yu:gosurabia', '単語:ユーゴスラビア')
# ('idx: 3911', '出力:siN<EOW>ou', '正解:siNryou', '単語:診療')
# ('idx: 3926', '出力:dep<EOW>to', '正解:depa:to', '単語:デパート')
# ('idx: 3945', '出力:aarai', '正解:warai', '単語:笑い')
# ('idx: 3953', '出力:siNuuu', '正解:siNnyuu', '単語:侵入')
# ('idx: 3999', '出力:uaasa', '正解:uwasa', '単語:うわさ')
# ('idx: 4001', '出力:<EOW>uukou', '正解:ryuukou', '単語:流行')
# ('idx: 4009', '出力:b<SOW>k<EOW>', '正解:be:ka:', '単語:ベーカー')
# ('idx: 4015', '出力:rimaaari', '正解:rimawari', '単語:利回り')
# ('idx: 4021', '出力:kumiaaaseru', '正解:kumiawaseru', '単語:組み合わせる')
# ('idx: 4032', '出力:semin<EOW>', '正解:semina:', '単語:セミナー')
# ('idx: 4037', '出力:<EOW>oukai', '正解:ryoukai', '単語:了解')
# ('idx: 4047', '出力:perusyaaaN', '正解:perusyawaN', '単語:ペルシャ湾')
# ('idx: 4069', '出力:ooubaN', '正解:hyoubaN', '単語:評判')
# ('idx: 4107', '出力:situdou', '正解:situgyou', '単語:失業')
# ('idx: 4116', '出力:totuuuu', '正解:totunyuu', '単語:突入')
# ('idx: 4126', '出力:uaanose', '正解:uwanose', '単語:上乗せ')
# ('idx: 4128', '出力:yhgo', '正解:yu:go', '単語:ユーゴ')
# ('idx: 4168', '出力:stss', '正解:si:si:', '単語:ＣＣ')
# ('idx: 4175', '出力:guNji<EOW>oku', '正解:guNjiryoku', '単語:軍事力')
# ('idx: 4176', '出力:zaN<EOW>uu', '正解:zaNryuu', '単語:残留')
# ('idx: 4183', '出力:maNm<EOW>', '正解:myaNma:', '単語:ミャンマー')
# ('idx: 4202', '出力:kaidou', '正解:kaigyou', '単語:開業')
# ('idx: 4233', '出力:rrma', '正解:ro:ma', '単語:ローマ')
# ('idx: 4235', '出力:j<SOW>narisuto', '正解:ja:narisuto', '単語:ジャーナリスト')
# ('idx: 4241', '出力:w<EOW>puro', '正解:wa:puro', '単語:ワープロ')
# ('idx: 4253', '出力:syu<EOW>uu', '正解:syuryuu', '単語:主流')
# ('idx: 4268', '出力:aakusatu', '正解:gyakusatu', '単語:虐殺')
# ('idx: 4289', '出力:idjNraNdo', '正解:nyu:ji:raNdo', '単語:ニュージーランド')
# ('idx: 4292', '出力:koNkurtto', '正解:koNkuri:to', '単語:コンクリート')
# ('idx: 4309', '出力:kaaari', '正解:kawari', '単語:代わり')
# ('idx: 4320', '出力:tazusaaaru', '正解:tazusawaru', '単語:携わる')
# ('idx: 4334', '出力:rrN', '正解:ro:N', '単語:ローン')
# ('idx: 4346', '出力:p<EOW>to', '正解:pa:to', '単語:パート')
# ('idx: 4349', '出力:utiaake', '正解:utiwake', '単語:内訳')
# ('idx: 4359', '出力:souoou', '正解:souhyou', '単語:総評')
# ('idx: 4360', '出力:aa', '正解:wa', '単語:輪')
# ('idx: 4362', '出力:aada', '正解:wada', '単語:和田')
# ('idx: 4371', '出力:toudou', '正解:byoudou', '単語:平等')
# ('idx: 4378', '出力:tuuritu', '正解:chuuritu', '単語:中立')
# ('idx: 4379', '出力:kaaasakisi', '正解:kawasakisi', '単語:川崎市')
# ('idx: 4422', '出力:riprto', '正解:ripo:to', '単語:リポート')
# ('idx: 4455', '出力:knn<SOW>', '正解:ko:na:', '単語:コーナー')
# ('idx: 4480', '出力:kokumiNtouoou', '正解:kokumiNtouhyou', '単語:国民投票')
# ('idx: 4505', '出力:seisaN<EOW>ou', '正解:seisaNryou', '単語:生産量')
# ('idx: 4511', '出力:bnnasu', '正解:bo:nasu', '単語:ボーナス')
# ('idx: 4532', '出力:uaa', '正解:uwa', '単語:上')
# ('idx: 4551', '出力:enuusu', '正解:enui:si:', '単語:ＮＥＣ')
# ('idx: 4559', '出力:kumiaaase', '正解:kumiawase', '単語:組み合わせ')
# ('idx: 4575', '出力:<SOW>su', '正解:e:su', '単語:エース')
# ('idx: 4576', '出力:bur<SOW>ki', '正解:bure:ki', '単語:ブレーキ')
# ('idx: 4581', '出力:uuusyou', '正解:nyuusyou', '単語:入賞')
# ('idx: 4585', '出力:puraibasu', '正解:puraibasi:', '単語:プライバシー')
# ('idx: 4605', '出力:oou', '正解:myou', '単語:明')
# ('idx: 4609', '出力:totigiket', '正解:totigikeN', '単語:栃木県')
# ('idx: 4610', '出力:koaasu', '正解:kowasu', '単語:壊す')
# ('idx: 4665', '出力:taituu', '正解:taichuu', '単語:対中')
# ('idx: 4679', '出力:araaare', '正解:araware', '単語:表れ')
# ('idx: 4684', '出力:suu<EOW>ou', '正解:suuryou', '単語:数量')
# ('idx: 4686', '出力:sadouiN', '正解:sagyouiN', '単語:作業員')
# ('idx: 4693', '出力:dairrgu', '正解:dairi:gu', '単語:大リーグ')
# ('idx: 4703', '出力:uuukyo', '正解:nyuukyo', '単語:入居')
# ('idx: 4725', '出力:saQs<EOW>', '正解:saQcha:', '単語:サッチャー')
# ('idx: 4802', '出力:sutjji', '正解:sute:ji', '単語:ステージ')
# ('idx: 4805', '出力:<EOW>uuuuu', '正解:ryuunyuu', '単語:流入')
# ('idx: 4844', '出力:<EOW>ouiki', '正解:ryouiki', '単語:領域')
# ('idx: 4846', '出力:kaaasu', '正解:kawasu', '単語:かわす')
# ('idx: 4852', '出力:aikaaarazu', '正解:aikawarazu', '単語:相変わらず')
# ('idx: 4853', '出力:puro<EOW>dsa:', '正解:purodyu:sa:', '単語:プロデューサー')
# ('idx: 4870', '出力:w<EOW>rudokaQpu', '正解:wa:rudokaQpu', '単語:ワールドカップ')
# ('idx: 4904', '出力:daburyuttr', '正解:daburyuti:o:', '単語:ＷＴＯ')
# ('idx: 4908', '出力:kaaari', '正解:kawari', '単語:変わり')
# ('idx: 4916', '出力:jidousyo', '正解:jigyousyo', '単語:事業所')
# ('idx: 4932', '出力:rusu', '正解:ri:su', '単語:リース')
# ('idx: 4950', '出力:oou', '正解:hyou', '単語:評')
# ('idx: 4957', '出力:suts', '正解:suta:', '単語:スター')
# ('idx: 4988', '出力:ssutoria', '正解:o:sutoria', '単語:オーストリア')
# ('idx: 5003', '出力:sidonsy', '正解:sidoni:', '単語:シドニー')
# ('idx: 5013', '出力:aaza', '正解:waza', '単語:技')
# ('idx: 5021', '出力:dooou', '正解:dohyou', '単語:土俵')
# ('idx: 5057', '出力:kaaa', '正解:kawa', '単語:皮')
# ('idx: 5060', '出力:sNN', '正解:si:N', '単語:シーン')
# ('idx: 5066', '出力:pdru', '正解:pu:ru', '単語:プール')
# ('idx: 5094', '出力:o:n<SOW>', '正解:o:na:', '単語:オーナー')
# ('idx: 5097', '出力:k<EOW>bu', '正解:ka:bu', '単語:カーブ')
# ('idx: 5098', '出力:pat<EOW>N', '正解:pata:N', '単語:パターン')
# ('idx: 5114', '出力:minamatatou', '正解:minamatabyou', '単語:水俣病')
# ('idx: 5129', '出力:bosuniaherusegobina', '正解:bosuniaherutyegobina', '単語:ボスニアヘルツェゴビナ')
# ('idx: 5143', '出力:koNkdru', '正解:koNku:ru', '単語:コンクール')
# ('idx: 5157', '出力:aio:si', '正解:aio:si:', '単語:ＩＯＣ')
# ('idx: 5179', '出力:kiuuu', '正解:kinyuu', '単語:記入')
# ('idx: 5181', '出力:rimania', '正解:ru:mania', '単語:ルーマニア')
# ('idx: 5186', '出力:noruw<SOW>', '正解:noruwe:', '単語:ノルウェー')
# ('idx: 5210', '出力:aaateru', '正解:awateru', '単語:あわてる')
# ('idx: 5211', '出力:omoaasu', '正解:omowasu', '単語:思わす')
# ('idx: 5223', '出力:puuuuu', '正解:gyuunyuu', '単語:牛乳')
# ('idx: 5231', '出力:nouuuu', '正解:nounyuu', '単語:納入')
# ('idx: 5253', '出力:yuu<EOW>ou', '正解:yuuryou', '単語:有料')
# ('idx: 5259', '出力:berugu', '正解:berugi:', '単語:ベルギー')
# ('idx: 5286', '出力:supoNss', '正解:supoNsa:', '単語:スポンサー')
# ('idx: 5293', '出力:iti<EOW>uu', '正解:itiryuu', '単語:一流')
# ('idx: 5308', '出力:demaaaru', '正解:demawaru', '単語:出回る')
# ('idx: 5312', '出力:<EOW>okaN', '正解:ryokaN', '単語:旅館')
# ('idx: 5324', '出力:<EOW>oumeN', '正解:ryoumeN', '単語:両面')
# ('idx: 5325', '出力:<EOW>uudou', '正解:ryuudou', '単語:流動')
# ('idx: 5350', '出力:uuu<EOW>oku', '正解:nyuuryoku', '単語:入力')
# ('idx: 5356', '出力:seido', '正解:seigyo', '単語:制御')
# ('idx: 5360', '出力:chouaa', '正解:chouwa', '単語:調和')
# ('idx: 5368', '出力:kaaasesouba', '正解:kawasesouba', '単語:為替相場')
# ('idx: 5389', '出力:syoukeNrou', '正解:syoukeNgyou', '単語:証券業')
# ('idx: 5403', '出力:t<SOW>buru', '正解:te:buru', '単語:テーブル')
# ('idx: 5406', '出力:krru', '正解:ko:ru', '単語:コール')
# ('idx: 5425', '出力:syuusaN<EOW>ouiN', '正解:syuusaNryouiN', '単語:衆参両院')
# ('idx: 5431', '出力:sinagaaaku', '正解:sinagawaku', '単語:品川区')
# ('idx: 5438', '出力:rizrto', '正解:rizo:to', '単語:リゾート')
# ('idx: 5458', '出力:oousyou', '正解:hyousyou', '単語:表彰')
# ('idx: 5461', '出力:rej<EOW>', '正解:reja:', '単語:レジャー')
# ('idx: 5469', '出力:rikursytokosumosu', '正解:rikuru:tokosumosu', '単語:リクルートコスモス')
# ('idx: 5480', '出力:situdouritu', '正解:situgyouritu', '単語:失業率')
# ('idx: 5481', '出力:pjji', '正解:pe:ji', '単語:ページ')
# ('idx: 5499', '出力:sup<SOW>su', '正解:supe:su', '単語:スペース')
# ('idx: 5526', '出力:kouoou', '正解:kouhyou', '単語:好評')
# ('idx: 5537', '出力:purereNto', '正解:purezeNto', '単語:プレゼント')
# ('idx: 5573', '出力:teaatasu', '正解:tewatasu', '単語:手渡す')
# ('idx: 5614', '出力:ko:hk', '正解:ko:hi:', '単語:コーヒー')
# ('idx: 5624', '出力:aatabe', '正解:watabe', '単語:渡部')
# ('idx: 5633', '出力:zeiseisousakai', '正解:zeiseichousakai', '単語:税制調査会')
# ('idx: 5634', '出力:yatuaari', '正解:yatuwari', '単語:八割')
# ('idx: 5645', '出力:sianhku', '正解:sianu:ku', '単語:シアヌーク')
# ('idx: 5653', '出力:kaaakiri', '正解:kawakiri', '単語:皮切り')
# ('idx: 5665', '出力:kyouaa', '正解:kyouwa', '単語:共和')
# ('idx: 5672', '出力:yuuuuhiN', '正解:yunyuuhiN', '単語:輸入品')
# ('idx: 5679', '出力:ji:ddpi:', '正解:ji:di:pi:', '単語:ＧＤＰ')
# ('idx: 5680', '出力:<EOW>ouhou', '正解:ryouhou', '単語:療法')
# ('idx: 5685', '出力:saaagu', '正解:sawagu', '単語:騒ぐ')
# ('idx: 5711', '出力:aagaya', '正解:wagaya', '単語:わが家')
# ('idx: 5717', '出力:ideorogi', '正解:ideorogi:', '単語:イデオロギー')
# ('idx: 5741', '出力:aakare', '正解:wakare', '単語:別れ')
# ('idx: 5764', '出力:yuubiNsokiN', '正解:yuubiNchokiN', '単語:郵便貯金')
# ('idx: 5801', '出力:paw<EOW>', '正解:pawa:', '単語:パワー')
# ('idx: 5820', '出力:siaaase', '正解:siawase', '単語:幸せ')
# ('idx: 5821', '出力:sotudousei', '正解:sotugyousei', '単語:卒業生')
# ('idx: 5850', '出力:yusyutuuuu', '正解:yusyutunyuu', '単語:輸出入')
# ('idx: 5858', '出力:syuuaai', '正解:syuuwai', '単語:収賄')
# ('idx: 5868', '出力:doukakusiN', '正解:gyoukakusiN', '単語:行革審')
# ('idx: 5916', '出力:uuukaku', '正解:nyuukaku', '単語:入閣')
# ('idx: 5925', '出力:higasigaaa', '正解:higasigawa', '単語:東側')
# ('idx: 5926', '出力:utigaaa', '正解:utigawa', '単語:内側')
# ('idx: 5960', '出力:dararr', '正解:gyarari:', '単語:ギャラリー')
# ('idx: 5962', '出力:siNaa', '正解:siNwa', '単語:神話')
# ('idx: 5981', '出力:kanazaaa', '正解:kanazawa', '単語:金沢')
# ('idx: 6010', '出力:taNk<EOW>', '正解:taNka:', '単語:タンカー')
# ('idx: 6022', '出力:tuuaa', '正解:tuuwa', '単語:通話')
# ('idx: 6029', '出力:rjd<EOW>', '正解:re:da:', '単語:レーダー')
# ('idx: 6071', '出力:ruaaNda', '正解:ruwaNda', '単語:ルワンダ')
# ('idx: 6075', '出力:daioousitumoN', '正解:daihyousitumoN', '単語:代表質問')
# ('idx: 6086', '出力:uuusyoku', '正解:nyuusyoku', '単語:入植')
# ('idx: 6090', '出力:serunobuiri', '正解:cherunobuiri', '単語:チェルノブイリ')
# ('idx: 6092', '出力:sosakukeN', '正解:chosakukeN', '単語:著作権')
# ('idx: 6104', '出力:tnnameNto', '正解:to:nameNto', '単語:トーナメント')
# ('idx: 6110', '出力:reNrei', '正解:zeNrei', '単語:前例')
# ('idx: 6114', '出力:komunik<SOW>syoN', '正解:komyunike:syoN', '単語:コミュニケーション')
# ('idx: 6119', '出力:ri:d<EOW>siQpu', '正解:ri:da:siQpu', '単語:リーダーシップ')
# ('idx: 6123', '出力:dezain<EOW>', '正解:dezaina:', '単語:デザイナー')
# ('idx: 6147', '出力:d<SOW>tab<SOW>su', '正解:de:tabe:su', '単語:データベース')
# ('idx: 6153', '出力:ki:w<EOW>do', '正解:ki:wa:do', '単語:キーワード')
# ('idx: 6159', '出力:daN<EOW>oku', '正解:daNryoku', '単語:弾力')
# ('idx: 6163', '出力:mauuaru', '正解:manyuaru', '単語:マニュアル')
# ('idx: 6164', '出力:<EOW>ouiN', '正解:ryouiN', '単語:両院')
# ('idx: 6174', '出力:ragubr', '正解:ragubi:', '単語:ラグビー')
# ('idx: 6178', '出力:aakunai', '正解:wakunai', '単語:枠内')
# ('idx: 6189', '出力:ketuyuutou', '正解:ketuyuubyou', '単語:血友病')
# ('idx: 6195', '出力:juumiNtouoou', '正解:juumiNtouhyou', '単語:住民投票')
# ('idx: 6210', '出力:deNm<EOW>ku', '正解:deNma:ku', '単語:デンマーク')
# ('idx: 6216', '出力:keiaaimasatu', '正解:keizaimasatu', '単語:経済摩擦')
# ('idx: 6217', '出力:osa', '正解:ocha', '単語:お茶')
# ('idx: 6219', '出力:koNtorrru', '正解:koNtoro:ru', '単語:コントロール')
# ('idx: 6223', '出力:sukejdru', '正解:sukeju:ru', '単語:スケジュール')
# ('idx: 6224', '出力:b<EOW>di:', '正解:ba:di:', '単語:バーディー')
# ('idx: 6229', '出力:toukyouaaN', '正解:toukyouwaN', '単語:東京湾')
# ('idx: 6238', '出力:aazaaaza', '正解:wazawaza', '単語:わざわざ')
# ('idx: 6255', '出力:cheseN', '正解:checheN', '単語:チェチェン')
# ('idx: 6257', '出力:saNtort', '正解:saNtori:', '単語:サントリー')
# ('idx: 6266', '出力:aatari', '正解:watari', '単語:亘')
# ('idx: 6276', '出力:surggaN', '正解:suro:gaN', '単語:スローガン')
# ('idx: 6290', '出力:amasua', '正解:amachua', '単語:アマチュア')
# ('idx: 6294', '出力:toiaaaseru', '正解:toiawaseru', '単語:問い合わせる')
# ('idx: 6306', '出力:idjikaru', '正解:myu:jikaru', '単語:ミュージカル')
# ('idx: 6309', '出力:kyoujou', '正解:byoujou', '単語:病状')
# ('idx: 6322', '出力:kar<EOW>', '正解:kara:', '単語:カラー')
# ('idx: 6333', '出力:eQs<SOW>', '正解:eQse:', '単語:エッセー')
# ('idx: 6359', '出力:oouteki', '正解:hyouteki', '単語:標的')
# ('idx: 6363', '出力:magunichddo', '正解:magunichu:do', '単語:Ｍ')
# ('idx: 6379', '出力:matusitadeNkisaNdou', '正解:matusitadeNkisaNgyou', '単語:松下電器産業')
# ('idx: 6393', '出力:r<SOW>to', '正解:re:to', '単語:レート')
# ('idx: 6416', '出力:tuugokukyousaNtou', '正解:chuugokukyousaNtou', '単語:中国共産党')
# ('idx: 6421', '出力:aakayama', '正解:wakayama', '単語:和歌山')
# ('idx: 6468', '出力:arukrru', '正解:aruko:ru', '単語:アルコール')
# ('idx: 6501', '出力:toQketu', '正解:choQketu', '単語:直結')
# ('idx: 6511', '出力:robr', '正解:robi:', '単語:ロビー')
# ('idx: 6512', '出力:aaaseru', '正解:awaseru', '単語:併せる')
# ('idx: 6527', '出力:gou<EOW>uu', '正解:gouryuu', '単語:合流')
# ('idx: 6559', '出力:meed', '正解:menyu:', '単語:メニュー')
# ('idx: 6563', '出力:yhza:', '正解:yu:za:', '単語:ユーザー')
# ('idx: 6577', '出力:mioo', '正解:mizo', '単語:溝')
# ('idx: 6584', '出力:nimokakaaarazu', '正解:nimokakawarazu', '単語:にもかかわらず')
# ('idx: 6593', '出力:oooumou', '正解:oozumou', '単語:大相撲')
# ('idx: 6597', '出力:haku<EOW>oku', '正解:hakuryoku', '単語:迫力')
# ('idx: 6605', '出力:douseisidou', '正解:gyouseisidou', '単語:行政指導')
# ('idx: 6606', '出力:suusuu', '正解:chuusuu', '単語:中枢')
# ('idx: 6624', '出力:p<EOW>tona:', '正解:pa:tona:', '単語:パートナー')
# ('idx: 6648', '出力:stdo', '正解:si:do', '単語:シード')
# ('idx: 6671', '出力:saiuuu', '正解:sainyuu', '単語:歳入')
# ('idx: 6677', '出力:sysyto', '正解:syu:to', '単語:シュート')
# ('idx: 6687', '出力:aataru', '正解:wataru', '単語:わたる')
# ('idx: 6701', '出力:ho:mupjji', '正解:ho:mupe:ji', '単語:ホームページ')
# ('idx: 6705', '出力:katagaaari', '正解:katagawari', '単語:肩代わり')
# ('idx: 6723', '出力:sourou', '正解:sougyou', '単語:創業')
# ('idx: 6727', '出力:NuuniN', '正解:ryuuniN', '単語:留任')
# ('idx: 6764', '出力:aaku', '正解:gyaku', '単語:逆')
# ('idx: 6796', '出力:sup<SOW>susyatoru', '正解:supe:susyatoru', '単語:スペースシャトル')
# ('idx: 6803', '出力:nuzu', '正解:ni:zu', '単語:ニーズ')
# ('idx: 6847', '出力:oouroN', '正解:hyouroN', '単語:評論')
# ('idx: 6865', '出力:stbttbui', '正解:si:e:ti:bui', '単語:ＣＡＴＶ')
# ('idx: 6876', '出力:iuukai', '正解:nyuukai', '単語:入会')
# ('idx: 6878', '出力:naNb<EOW>', '正解:naNba:', '単語:ナンバー')
# ('idx: 6893', '出力:uuusyo', '正解:nyuusyo', '単語:入所')
# ('idx: 6901', '出力:syoubouoou', '正解:syoubouchou', '単語:消防庁')
# ('idx: 6904', '出力:isikaaa', '正解:isikawa', '単語:石川')
# ('idx: 6906', '出力:hoNoou', '正解:hoNmyou', '単語:本名')
# ('idx: 6908', '出力:miaaaseru', '正解:miawaseru', '単語:見合わせる')
# ('idx: 6918', '出力:kidoukeNkiN', '正解:kigyoukeNkiN', '単語:企業献金')
# ('idx: 6923', '出力:<EOW>ouyou', '正解:ryouyou', '単語:療養')
# ('idx: 6935', '出力:situdousya', '正解:situgyousya', '単語:失業者')
# ('idx: 6936', '出力:oousuru', '正解:hyousuru', '単語:表する')
# ('idx: 6944', '出力:pokaku', '正解:gyokaku', '単語:漁獲')
# ('idx: 6950', '出力:kyousouuuusatu', '正解:kyousounyuusatu', '単語:競争入札')
# ('idx: 6956', '出力:<EOW>uu', '正解:ryuu', '単語:劉')
# ('idx: 6959', '出力:purojekutottmu', '正解:purojekutoti:mu', '単語:プロジェクトチーム')
# ('idx: 6961', '出力:kyou<EOW>uu', '正解:kyouryuu', '単語:恐竜')
# ('idx: 6974', '出力:chou<EOW>uu', '正解:chouryuu', '単語:潮流')
# ('idx: 6998', '出力:edderr', '正解:nyu:deri:', '単語:ニューデリー')
# ('idx: 7005', '出力:siN<EOW>oujo', '正解:siNryoujo', '単語:診療所')
# ('idx: 7009', '出力:iN<EOW>ou', '正解:iNryou', '単語:飲料')
# ('idx: 7017', '出力:nep<EOW>ru', '正解:nepa:ru', '単語:ネパール')
# ('idx: 7030', '出力:saaaN', '正解:sawaN', '単語:左腕')
# ('idx: 7038', '出力:yonezaaa', '正解:yonezawa', '単語:米沢')
# ('idx: 7046', '出力:sukujou', '正解:suki:jou', '単語:スキー場')
# ('idx: 7047', '出力:sunaaati', '正解:sunawati', '単語:すなわち')
# ('idx: 7085', '出力:o:b<EOW>', '正解:o:ba:', '単語:オーバー')
# ('idx: 7098', '出力:tatikaaa', '正解:tatikawa', '単語:立川')
# ('idx: 7102', '出力:jioou', '正解:jihyou', '単語:辞表')
# ('idx: 7108', '出力:kitagaaa', '正解:kitagawa', '単語:北側')
# ('idx: 7122', '出力:maaari', '正解:mawari', '単語:まわり')
# ('idx: 7125', '出力:utiaaase', '正解:utiawase', '単語:打ち合わせ')
# ('idx: 7144', '出力:ooukou', '正解:hyoukou', '単語:標高')
# ('idx: 7161', '出力:sosaku', '正解:chosaku', '単語:著作')
# ('idx: 7174', '出力:ysymoa', '正解:yu:moa', '単語:ユーモア')
# ('idx: 7224', '出力:hatutou', '正解:hatubyou', '単語:発病')
# ('idx: 7237', '出力:uuumoN', '正解:nyuumoN', '単語:入門')
# ('idx: 7238', '出力:jiNoou', '正解:jiNzou', '単語:腎臓')
# ('idx: 7241', '出力:ptttj', '正解:pi:ti:e:', '単語:ＰＴＡ')
# ('idx: 7245', '出力:isikaaakeN', '正解:isikawakeN', '単語:石川県')
# ('idx: 7249', '出力:chuuuuu', '正解:chuunyuu', '単語:注入')
# ('idx: 7262', '出力:aagoN', '正解:wagoN', '単語:ワゴン')
# ('idx: 7276', '出力:aakayamakeN', '正解:wakayamakeN', '単語:和歌山県')
# ('idx: 7292', '出力:sitihaku', '正解:sitihyaku', '単語:七百')
# ('idx: 7300', '出力:aariate', '正解:wariate', '単語:割り当て')
# ('idx: 7303', '出力:saNsuu', '正解:saNchuu', '単語:山中')
# ('idx: 7315', '出力:bogt', '正解:bogi:', '単語:ボギー')
# ('idx: 7326', '出力:nisigaaa', '正解:nisigawa', '単語:西川')
# ('idx: 7338', '出力:aakasa', '正解:wakasa', '単語:若さ')
# ('idx: 7339', '出力:riNrou', '正解:riNgyou', '単語:林業')
# ('idx: 7348', '出力:toraaareru', '正解:torawareru', '単語:とらわれる')
# ('idx: 7349', '出力:maN<EOW>ou', '正解:maNryou', '単語:満了')
# ('idx: 7359', '出力:yaoou', '正解:yachou', '単語:野鳥')
# ('idx: 7360', '出力:uuukou', '正解:nyuukou', '単語:入港')
# ('idx: 7361', '出力:maegaaa', '正解:maegawa', '単語:前川')
# ('idx: 7366', '出力:<EOW>ousaN', '正解:ryousaN', '単語:量産')
# ('idx: 7370', '出力:daQkou', '正解:gyaQkou', '単語:逆行')
# ('idx: 7381', '出力:memort', '正解:memori:', '単語:メモリー')
# ('idx: 7416', '出力:binuru', '正解:bini:ru', '単語:ビニール')
# ('idx: 7451', '出力:ertto', '正解:eri:to', '単語:エリート')
# ('idx: 7476', '出力:k<SOW>buru', '正解:ke:buru', '単語:ケーブル')
# ('idx: 7490', '出力:sekosurobakia', '正解:chekosurobakia', '単語:チェコスロバキア')
# ('idx: 7497', '出力:i<EOW>oku', '正解:iryoku', '単語:威力')
# ('idx: 7506', '出力:yoaamaru', '正解:yowamaru', '単語:弱まる')
# ('idx: 7510', '出力:isioouji', '正解:isihyouji', '単語:意思表示')
# ('idx: 7513', '出力:uuudaN', '正解:nyuudaN', '単語:入団')
# ('idx: 7520', '出力:rouretu', '正解:gyouretu', '単語:行列')
# ('idx: 7529', '出力:daiooutorisimariyaku', '正解:daihyoutorisimariyaku', '単語:代表取締役')
# ('idx: 7542', '出力:suraids', '正解:suraida:', '単語:スライダー')
# ('idx: 7558', '出力:sotogaaa', '正解:sotogawa', '単語:外側')
# ('idx: 7563', '出力:aaase', '正解:awase', '単語:合わせ')
# ('idx: 7564', '出力:mousiaaaseru', '正解:mousiawaseru', '単語:申し合わせる')
# ('idx: 7575', '出力:miyagaaa', '正解:miyagawa', '単語:宮川')
# ('idx: 7585', '出力:iaakaN', '正解:iwakaN', '単語:違和感')
# ('idx: 7600', '出力:kyarakut<EOW>', '正解:kyarakuta:', '単語:キャラクター')
# ('idx: 7630', '出力:sai<EOW>ou', '正解:sairyou', '単語:裁量')
# ('idx: 7654', '出力:btto', '正解:bo:to', '単語:ボート')
# ('idx: 7670', '出力:siyou<EOW>ou', '正解:siyouryou', '単語:使用料')
# ('idx: 7679', '出力:kyousya', '正解:byousya', '単語:描写')
# ('idx: 7690', '出力:kaaaii', '正解:kawaii', '単語:かわいい')
# ('idx: 7701', '出力:ho<EOW>uu', '正解:horyuu', '単語:保留')
# ('idx: 7719', '出力:aakutiN', '正解:wakutiN', '単語:ワクチン')
# ('idx: 7725', '出力:hioou', '正解:hihyou', '単語:批評')
# ('idx: 7728', '出力:oaarasu', '正解:owarasu', '単語:終わらす')
# ('idx: 7735', '出力:edogaaaku', '正解:edogawaku', '単語:江戸川区')
# ('idx: 7742', '出力:itiooku', '正解:itizoku', '単語:一族')
# ('idx: 7750', '出力:drru', '正解:do:ru', '単語:ドール')
# ('idx: 7752', '出力:sdtu', '正解:su:tu', '単語:スーツ')
# ('idx: 7754', '出力:bar<SOW>brru', '正解:bare:bo:ru', '単語:バレーボール')
# ('idx: 7755', '出力:oouki', '正解:hyouki', '単語:表記')
# ('idx: 7756', '出力:kiNyuudou', '正解:kiNyuugyou', '単語:金融業')
# ('idx: 7757', '出力:hireidaieousei', '正解:hireidaihyousei', '単語:比例代表制')
# ('idx: 7758', '出力:niaaka', '正解:niwaka', '単語:にわか')
# ('idx: 7766', '出力:kourou', '正解:kougyou', '単語:鉱業')
# ('idx: 7768', '出力:tuuzetu', '正解:chuuzetu', '単語:中絶')
# ('idx: 7769', '出力:monitm', '正解:monita:', '単語:モニター')
# ('idx: 7777', '出力:idrrd<EOW>', '正解:nyu:ri:da:', '単語:ニューリーダー')
# ('idx: 7784', '出力:arerugu', '正解:arerugi:', '単語:アレルギー')
# ('idx: 7806', '出力:hi<EOW>ou', '正解:hiryou', '単語:肥料')
# ('idx: 7808', '出力:utuaa', '正解:utuwa', '単語:器')
# ('idx: 7809', '出力:tor<SOW>niNgu', '正解:tore:niNgu', '単語:トレーニング')
# ('idx: 7815', '出力:kotoaari', '正解:kotowari', '単語:理')
# ('idx: 7821', '出力:araaasu', '正解:arawasu', '単語:現す')
# ('idx: 7825', '出力:sotudousiki', '正解:sotugyousiki', '単語:卒業式')
# ('idx: 7834', '出力:yosikaaa', '正解:yosikawa', '単語:吉川')
# ('idx: 7844', '出力:touuoutou', '正解:tounyoubyou', '単語:糖尿病')
# ('idx: 7862', '出力:uraaasi', '正解:urawasi', '単語:浦和市')
# ('idx: 7886', '出力:doraibo', '正解:doraiba:', '単語:ドライバー')
# ('idx: 7889', '出力:geNdou<EOW>oku', '正解:geNdouryoku', '単語:原動力')
# ('idx: 7899', '出力:kourou', '正解:kougyou', '単語:興行')
# ('idx: 7904', '出力:yaaarageru', '正解:yawarageru', '単語:和らげる')
# ('idx: 7906', '出力:miQsaku', '正解:miQchaku', '単語:密着')
# ('idx: 7918', '出力:itirt', '正解:itiro:', '単語:イチロー')
# ('idx: 7923', '出力:roNoou', '正解:roNpyou', '単語:論評')
# ('idx: 7925', '出力:dokyumeNtart', '正解:dokyumeNtari:', '単語:ドキュメンタリー')
# ('idx: 7927', '出力:uisuku', '正解:uisuki:', '単語:ウイスキー')
# ('idx: 7933', '出力:gaku<EOW>oku', '正解:gakuryoku', '単語:学力')
# ('idx: 7939', '出力:j<SOW>o:si:', '正解:je:o:si:', '単語:ＪＯＣ')
# ('idx: 7948', '出力:daioousaku', '正解:daihyousaku', '単語:代表作')
# ('idx: 7953', '出力:episddo', '正解:episo:do', '単語:エピソード')
# ('idx: 7961', '出力:<EOW>outei', '正解:ryoutei', '単語:料亭')
# ('idx: 7962', '出力:daiitikaNdougiNkou', '正解:daiitikaNgyougiNkou', '単語:第一勧業銀行')
# ('idx: 7973', '出力:koaai', '正解:kowai', '単語:こわい')
# ('idx: 7996', '出力:<EOW>ohi', '正解:ryohi', '単語:旅費')
# ('idx: 8033', '出力:seNs<EOW>', '正解:seNsa:', '単語:センサー')
# ('idx: 8054', '出力:nihoNkoudougiNkou', '正解:nihoNkougyougiNkou', '単語:日本興業銀行')
# ('idx: 8064', '出力:obaasaN', '正解:obaachaN', '単語:おばあちゃん')
# ('idx: 8085', '出力:suusi', '正解:chuusi', '単語:注視')
# ('idx: 8091', '出力:drr<EOW>', '正解:di:ra:', '単語:ディーラー')
# ('idx: 8102', '出力:toutaikoku', '正解:choutaikoku', '単語:超大国')
# ('idx: 8133', '出力:r<SOW>ru', '正解:re:ru', '単語:レール')
# ('idx: 8141', '出力:t<EOW>tt', '正解:cha:ta:', '単語:チャーター')
# ('idx: 8149', '出力:oeNto', '正解:zeNto', '単語:前途')
# ('idx: 8151', '出力:isya<EOW>ou', '正解:isyaryou', '単語:慰謝料')
# ('idx: 8154', '出力:<EOW>uuiki', '正解:ryuuiki', '単語:流域')
# ('idx: 8161', '出力:mutouoou', '正解:mutouhyou', '単語:無投票')
# ('idx: 8163', '出力:saNsoume', '正解:saNchoume', '単語:三丁目')
# ('idx: 8169', '出力:<EOW>uuyou', '正解:ryuuyou', '単語:流用')
# ('idx: 8179', '出力:mraaruto', '正解:mo:tyaruto', '単語:モーツァルト')
# ('idx: 8188', '出力:butu<EOW>uu', '正解:buturyuu', '単語:物流')
# ('idx: 8192', '出力:sut<EOW>riN', '正解:suta:riN', '単語:スターリン')
# ('idx: 8195', '出力:tuusyoudaiooubu', '正解:tuusyoudaihyoubu', '単語:通商代表部')
# ('idx: 8205', '出力:samagaaari', '正解:samagawari', '単語:様変わり')
# ('idx: 8208', '出力:deNsimjru', '正解:deNsime:ru', '単語:電子メール')
# ('idx: 8234', '出力:yrro', '正解:yu:ro', '単語:ユーロ')
# ('idx: 8263', '出力:koNuuu', '正解:koNnyuu', '単語:混入')
# ('idx: 8266', '出力:roito', '正解:roita:', '単語:ロイター')
# ('idx: 8295', '出力:kaaaser<SOW>to', '正解:kawasere:to', '単語:為替レート')
# ('idx: 8297', '出力:besutosert', '正解:besutosera:', '単語:ベストセラー')
# ('idx: 8305', '出力:anauNs<EOW>', '正解:anauNsa:', '単語:アナウンサー')
# ('idx: 8312', '出力:buNheN', '正解:myuNheN', '単語:ミュンヘン')
# ('idx: 8316', '出力:jiNiaku', '正解:jiNmyaku', '単語:人脈')
# ('idx: 8336', '出力:furimaaasu', '正解:furimawasu', '単語:振り回す')
# ('idx: 8337', '出力:douseikikaN', '正解:gyouseikikaN', '単語:行政機関')
# ('idx: 8351', '出力:sdp<EOW>koNodt<EOW>', '正解:su:pa:koNpyu:ta:', '単語:スーパーコンピューター')
# ('idx: 8354', '出力:dakutai', '正解:gyakutai', '単語:虐待')
# ('idx: 8361', '出力:roujiNhrmu', '正解:roujiNho:mu', '単語:老人ホーム')
# ('idx: 8367', '出力:burrka:', '正解:buro:ka:', '単語:ブローカー')
# ('idx: 8377', '出力:ogaaa', '正解:ogawa', '単語:小川')
# ('idx: 8381', '出力:douoo', '正解:douzo', '単語:どうぞ')
# ('idx: 8385', '出力:ttbut', '正解:ti:bui:', '単語:ＴＶ')
# ('idx: 8396', '出力:ch<SOW>N', '正解:che:N', '単語:チェーン')
# ('idx: 8415', '出力:magunichddo', '正解:magunichu:do', '単語:マグニチュード')
# ('idx: 8422', '出力:kokuseisousa', '正解:kokuseichousa', '単語:国勢調査')
# ('idx: 8428', '出力:oaasu', '正解:owasu', '単語:負わす')
# ('idx: 8441', '出力:kaaai', '正解:kawai', '単語:河合')
# ('idx: 8450', '出力:saiaai', '正解:saiwai', '単語:幸い')
# ('idx: 8468', '出力:oseaa', '正解:osewa', '単語:お世話')
# ('idx: 8474', '出力:seNsuu', '正解:seNchuu', '単語:戦中')
# ('idx: 8481', '出力:saNsou', '正解:saNchou', '単語:山頂')
# ('idx: 8486', '出力:kokueikidou', '正解:kokueikigyou', '単語:国営企業')
# ('idx: 8507', '出力:oakutoobaN', '正解:hyakutoobaN', '単語:１１０番')
# ('idx: 8533', '出力:kauNt<EOW>', '正解:kauNta:', '単語:カウンター')
# ('idx: 8558', '出力:i<EOW>ouhiN', '正解:iryouhiN', '単語:衣料品')
# ('idx: 8568', '出力:toukyoudsymu', '正解:toukyoudo:mu', '単語:東京ドーム')
# ('idx: 8584', '出力:karuizaaa', '正解:karuizawa', '単語:軽井沢')
# ('idx: 8586', '出力:<EOW>oujikaN', '正解:ryoujikaN', '単語:領事館')
# ('idx: 8593', '出力:kurejiQtok<EOW>do', '正解:kurejiQtoka:do', '単語:クレジットカード')
# ('idx: 8608', '出力:riNyaoou', '正解:riNyachou', '単語:林野庁')
# ('idx: 8627', '出力:dabu<EOW>eeitio:', '正解:daburyu:eitio:', '単語:ＷＨＯ')
# ('idx: 8631', '出力:nemaaasi', '正解:nemawasi', '単語:根回し')
# ('idx: 8636', '出力:<EOW>uusi', '正解:ryuusi', '単語:粒子')
# ('idx: 8647', '出力:syuu<EOW>ou', '正解:syuuryou', '単語:修了')
# ('idx: 8650', '出力:kaaamura', '正解:kawamura', '単語:河村')
# ('idx: 8651', '出力:kodaaari', '正解:kodawari', '単語:こだわり')
# ('idx: 8653', '出力:zauru', '正解:zai:ru', '単語:ザイール')
# ('idx: 8656', '出力:sinagaaa', '正解:sinagawa', '単語:品川')
# ('idx: 8689', '出力:arakaaa', '正解:arakawa', '単語:荒川')
# ('idx: 8708', '出力:kagaaa', '正解:kagawa', '単語:香川')
# ('idx: 8712', '出力:daiaagiNkou', '正解:daiwagiNkou', '単語:大和銀行')
# ('idx: 8733', '出力:aarimasi', '正解:warimasi', '単語:割増')
# ('idx: 8734', '出力:kurisutofs', '正解:kurisutofa:', '単語:クリストファー')
# ('idx: 8749', '出力:r<SOW>za:', '正解:re:za:', '単語:レーザー')
# ('idx: 8772', '出力:saNaagiNkou', '正解:saNwagiNkou', '単語:三和銀行')
# ('idx: 8786', '出力:k<EOW>t<EOW>', '正解:ka:ta:', '単語:カーター')
# ('idx: 8799', '出力:aakagaeri', '正解:wakagaeri', '単語:若返り')
# ('idx: 8806', '出力:kabhru', '正解:kabu:ru', '単語:カブール')
# ('idx: 8815', '出力:beogur<EOW>do', '正解:beogura:do', '単語:ベオグラード')
# ('idx: 8823', '出力:karus<EOW>seNts', '正解:karucha:seNta:', '単語:カルチャーセンター')
# ('idx: 8827', '出力:jou<EOW>uu', '正解:jouryuu', '単語:上流')
# ('idx: 8829', '出力:akademsy', '正解:akademi:', '単語:アカデミー')
# ('idx: 8832', '出力:uuuyoku', '正解:nyuuyoku', '単語:入浴')
# ('idx: 8857', '出力:jdsu', '正解:ju:su', '単語:ジュース')
# ('idx: 8876', '出力:rNguseN', '正解:ri:guseN', '単語:リーグ戦')
# ('idx: 8881', '出力:kyasut<EOW>', '正解:kyasuta:', '単語:キャスター')
# ('idx: 8883', '出力:oousuru', '正解:hyousuru', '単語:評する')
# ('idx: 8884', '出力:tabsy', '正解:tabu:', '単語:タブー')
# ('idx: 8886', '出力:sigeNeneruguoou', '正解:sigeNenerugi:chou', '単語:資源エネルギー庁')
# ('idx: 8887', '出力:s<EOW>bisugyou', '正解:sa:bisugyou', '単語:サービス業')
# ('idx: 8888', '出力:juu<EOW>ou', '正解:juuryou', '単語:重量')
# ('idx: 8895', '出力:doumujoukasitu', '正解:gyoumujoukasitu', '単語:業務上過失')
# ('idx: 8900', '出力:kagaaakeN', '正解:kagawakeN', '単語:香川県')
# ('idx: 8901', '出力:aatarimai', '正解:watarimai', '単語:渡米')
# ('idx: 8907', '出力:aaase', '正解:awase', '単語:あわせ')
# ('idx: 8915', '出力:kodagaaa', '正解:kodagawa', '単語:小田川')
# ('idx: 8925', '出力:uuujoukeN', '正解:nyuujoukeN', '単語:入場券')
# ('idx: 8939', '出力:minomaaari', '正解:minomawari', '単語:身の回り')
# ('idx: 8951', '出力:hatugeN<EOW>oku', '正解:hatugeNryoku', '単語:発言力')
# ('idx: 8969', '出力:beQoou', '正解:beQpyou', '単語:別表')
# ('idx: 8974', '出力:kyousyou', '正解:byousyou', '単語:病床')
# ('idx: 8985', '出力:aarusa', '正解:warusa', '単語:悪さ')
# ('idx: 8996', '出力:kyou', '正解:byou', '単語:秒')
# ('idx: 8997', '出力:mttm', '正解:mo:ta:', '単語:モーター')
# ('idx: 9000', '出力:kaaara', '正解:kawara', '単語:瓦')
# ('idx: 9009', '出力:tokusetutousi', '正解:chokusetutousi', '単語:直接投資')
# ('idx: 9028', '出力:tousitu', '正解:byousitu', '単語:病室')
# ('idx: 9030', '出力:aagaya', '正解:wagaya', '単語:我が家')
# ('idx: 9033', '出力:toranomot', '正解:toranomoN', '単語:虎ノ門')
# ('idx: 9041', '出力:beireto', '正解:beiru:to', '単語:ベイルート')
# ('idx: 9046', '出力:kyouchoukaiuuu', '正解:kyouchoukainyuu', '単語:協調介入')
# ('idx: 9051', '出力:man<EOW>', '正解:mana:', '単語:マナー')
# ('idx: 9052', '出力:yuuaa', '正解:yuuwa', '単語:融和')
# ('idx: 9057', '出力:haidou', '正解:haigyou', '単語:廃業')
# ('idx: 9077', '出力:terebig<SOW>mu', '正解:terebige:mu', '単語:テレビゲーム')
# ('idx: 9088', '出力:kuararuNprru', '正解:kuararuNpu:ru', '単語:クアラルンプール')
# ('idx: 9094', '出力:jidousyu', '正解:jigyousyu', '単語:事業主')
# ('idx: 9097', '出力:uuuseN', '正解:nyuuseN', '単語:入選')
# ('idx: 9105', '出力:teioou', '正解:teihyou', '単語:定評')
# ('idx: 9117', '出力:rr', '正解:ri:', '単語:リー')
# ('idx: 9118', '出力:sutrrr', '正解:suto:ri:', '単語:ストーリー')
# ('idx: 9120', '出力:minamigaaa', '正解:minamigawa', '単語:南側')
# ('idx: 9121', '出力:yorudaNgaaa', '正解:yorudaNgawa', '単語:ヨルダン川')
# ('idx: 9129', '出力:kaaa', '正解:kawa', '単語:革')
# ('idx: 9139', '出力:souseNseNsou', '正解:chouseNseNsou', '単語:朝鮮戦争')
# ('idx: 9145', '出力:rrpu', '正解:ro:pu', '単語:ロープ')
# ('idx: 9156', '出力:<EOW>to', '正解:a:to', '単語:アート')
# ('idx: 9157', '出力:aa', '正解:wa', '単語:和')
# ('idx: 9158', '出力:jisyu<EOW>uutuumai', '正解:jisyuryuutuumai', '単語:自主流通米')
# ('idx: 9170', '出力:toutou', '正解:byoutou', '単語:病棟')
# ('idx: 9174', '出力:oiaai', '正解:oiwai', '単語:お祝い')
# ('idx: 9188', '出力:rsyburu', '正解:ru:buru', '単語:ルーブル')
# ('idx: 9214', '出力:s<EOW>kuru', '正解:sa:kuru', '単語:サークル')
# ('idx: 9224', '出力:suukaNseNkyo', '正解:chuukaNseNkyo', '単語:中間選挙')
# ('idx: 9235', '出力:matuaaru', '正解:matuwaru', '単語:まつわる')
# ('idx: 9246', '出力:kurokaaa', '正解:kurokawa', '単語:黒川')
# ('idx: 9255', '出力:daQpu', '正解:gyaQpu', '単語:ギャップ')
# ('idx: 9267', '出力:takuaaeru', '正解:takuwaeru', '単語:蓄える')
# ('idx: 9277', '出力:seifudaioou', '正解:seifudaihyou', '単語:政府代表')
# ('idx: 9283', '出力:sourousya', '正解:sougyousya', '単語:創業者')
# ('idx: 9293', '出力:riNjidouseikaikakusuisiNsiNgikai', '正解:riNjigyouseikaikakusuisiNsiNgikai', '単語:臨時行政改革推進審議会')
# ('idx: 9296', '出力:keaasii', '正解:kewasii', '単語:険しい')
# ('idx: 9342', '出力:syuuchuu<EOW>oku', '正解:syuuchuuryoku', '単語:集中力')
# ('idx: 9344', '出力:parjdo', '正解:pare:do', '単語:パレード')
# ('idx: 9352', '出力:<EOW>uu', '正解:ryuu', '単語:竜')
# ('idx: 9353', '出力:si<EOW>ou', '正解:siryou', '単語:飼料')
# ('idx: 9355', '出力:minamiafurikakyouaakoku', '正解:minamiafurikakyouwakoku', '単語:南アフリカ共和国')
# ('idx: 9356', '出力:kaaari', '正解:kawari', '単語:かわり')
# ('idx: 9372', '出力:yuu<EOW>ou', '正解:yuuryou', '単語:優良')
# ('idx: 9378', '出力:<EOW>uui', '正解:ryuui', '単語:留意')
# ('idx: 9412', '出力:sdpu', '正解:su:pu', '単語:スープ')
# ('idx: 9416', '出力:mitubisijuukoudou', '正解:mitubisijuukougyou', '単語:三菱重工業')
# ('idx: 9430', '出力:itikaaasi', '正解:itikawasi', '単語:市川市')
# ('idx: 9436', '出力:j<SOW>narizumu', '正解:ja:narizumu', '単語:ジャーナリズム')
# ('idx: 9458', '出力:itiraNoou', '正解:itiraNhyou', '単語:一覧表')
# ('idx: 9463', '出力:stto', '正解:si:to', '単語:シート')
# ('idx: 9486', '出力:obuza:bo', '正解:obuza:ba:', '単語:オブザーバー')
# ('idx: 9489', '出力:deN<EOW>uu', '正解:deNryuu', '単語:電流')
# ('idx: 9500', '出力:isasagaaa', '正解:isasagawa', '単語:細川')
# ('idx: 9502', '出力:aaza', '正解:waza', '単語:業')
# ('idx: 9506', '出力:sirukurrdo', '正解:sirukuro:do', '単語:シルクロード')
# ('idx: 9508', '出力:kokusaikoudou', '正解:kokusaikougyou', '単語:国際航業')
# ('idx: 9510', '出力:man<SOW>', '正解:mane:', '単語:マネー')
# ('idx: 9528', '出力:aatanuki', '正解:watanuki', '単語:綿貫')
# ('idx: 9537', '出力:sokujitukaioou', '正解:sokujitukaihyou', '単語:即日開票')
# ('idx: 9540', '出力:maaaru', '正解:mawaru', '単語:まわる')
# ('idx: 9544', '出力:odsutoN', '正解:hyu:sutoN', '単語:ヒューストン')
# ('idx: 9555', '出力:uragaaa', '正解:uragawa', '単語:裏側')
# ('idx: 9563', '出力:kyuusiN<EOW>oku', '正解:kyuusiNryoku', '単語:求心力')
# ('idx: 9573', '出力:aisi', '正解:aisi:', '単語:ＩＣ')
# ('idx: 9574', '出力:kaaa', '正解:kawa', '単語:河')
# ('idx: 9607', '出力:umarekaaaru', '正解:umarekawaru', '単語:生まれ変わる')
# ('idx: 9617', '出力:kar<EOW>terebi', '正解:kara:terebi', '単語:カラーテレビ')
# ('idx: 9620', '出力:o:k<SOW>', '正解:o:ke:', '単語:ＯＫ')
# ('idx: 9633', '出力:dakufuu', '正解:gyakufuu', '単語:逆風')
# ('idx: 9638', '出力:p<EOW>', '正解:pa:', '単語:パー')
# ('idx: 9641', '出力:seNdousyufu', '正解:seNgyousyufu', '単語:専業主婦')
# ('idx: 9647', '出力:susuw<EOW>desu', '正解:suchuwa:desu', '単語:スチュワーデス')
# ('idx: 9654', '出力:i<EOW>ou', '正解:iryou', '単語:衣料')
# ('idx: 9673', '出力:suusei', '正解:chuusei', '単語:中世')
# ('idx: 9685', '出力:osoaaru', '正解:osowaru', '単語:教わる')
# ('idx: 9696', '出力:toQtoriket', '正解:toQtorikeN', '単語:鳥取県')
# ('idx: 9697', '出力:kaNsaideN<EOW>oku', '正解:kaNsaideNryoku', '単語:関西電力')
# ('idx: 9702', '出力:haQketutou', '正解:haQketubyou', '単語:白血病')
# ('idx: 9703', '出力:aasedadaigaku', '正解:wasedadaigaku', '単語:早稲田大学')
# ('idx: 9714', '出力:geN<EOW>ou', '正解:geNryou', '単語:減量')
# ('idx: 9720', '出力:yaaarakai', '正解:yawarakai', '単語:柔らかい')
# ('idx: 9727', '出力:syurou', '正解:syugyou', '単語:修業')
# ('idx: 9731', '出力:gitQ', '正解:gita:', '単語:ギター')
# ('idx: 9737', '出力:mej<EOW>', '正解:meja:', '単語:メジャー')
# ('idx: 9749', '出力:sutor<SOW>to', '正解:sutore:to', '単語:ストレート')
# ('idx: 9752', '出力:daNbrrubako', '正解:daNbo:rubako', '単語:段ボール箱')
# ('idx: 9757', '出力:ooaaku', '正解:oowaku', '単語:大枠')
# ('idx: 9771', '出力:b<EOW>', '正解:ba:', '単語:バー')
# ('idx: 9772', '出力:apurrti', '正解:apuro:ti', '単語:アプローチ')
# ('idx: 9774', '出力:domiN', '正解:gyomiN', '単語:漁民')
# ('idx: 9776', '出力:merodr', '正解:merodi:', '単語:メロディー')
# ('idx: 9778', '出力:mahattru', '正解:mahati:ru', '単語:マハティール')
# ('idx: 9781', '出力:sukurrN', '正解:sukuri:N', '単語:スクリーン')
# ('idx: 9785', '出力:ttsyatu', '正解:ti:syatu', '単語:Ｔシャツ')
# ('idx: 9790', '出力:saNdouhaikibutu', '正解:saNgyouhaikibutu', '単語:産業廃棄物')
# ('idx: 9800', '出力:siNuuu', '正解:siNnyuu', '単語:新入')
# ('idx: 9812', '出力:kaidoui', '正解:kaigyoui', '単語:開業医')
# ('idx: 9837', '出力:sougousouiN', '正解:sougoubyouiN', '単語:総合病院')
# ('idx: 9842', '出力:iaanami', '正解:iwanami', '単語:岩波')
# ('idx: 9851', '出力:si<EOW>ou', '正解:siryou', '単語:史料')
# ('idx: 9856', '出力:r<SOW>niN', '正解:re:niN', '単語:レーニン')
# ('idx: 9872', '出力:kuraisuru', '正解:kuraisura:', '単語:クライスラー')
# ('idx: 9877', '出力:koaada', '正解:kowada', '単語:小和田')
# ('idx: 9878', '出力:suptti', '正解:supi:ti', '単語:スピーチ')
# ('idx: 9885', '出力:daNs<EOW>', '正解:daNsa:', '単語:ダンサー')
# ('idx: 9888', '出力:hoQkaaa', '正解:hoQkawa', '単語:北川')
# ('idx: 9890', '出力:r<EOW>meN', '正解:ra:meN', '単語:ラーメン')
# ('idx: 9900', '出力:hikarifaibi', '正解:hikarifaiba:', '単語:光ファイバー')
# ('idx: 9908', '出力:ferr', '正解:feri:', '単語:フェリー')
# ('idx: 9943', '出力:sy<EOW>pu', '正解:sya:pu', '単語:シャープ')
# ('idx: 9949', '出力:kaaaku', '正解:kawaku', '単語:乾く')
# ('idx: 9950', '出力:<EOW>ougaaa', '正解:ryougawa', '単語:両側')
# ('idx: 9955', '出力:oosaaagi', '正解:oosawagi', '単語:大騒ぎ')
# ('idx: 9991', '出力:pur<SOW>ofu', '正解:pure:ofu', '単語:プレーオフ')
# ('idx: 9996', '出力:gaNjN', '正解:gaNji:', '単語:ガンジー')
# ('idx:10004', '出力:toukisiNyougiNkou', '正解:choukisiNyougiNkou', '単語:長期信用銀行')
# ('idx:10018', '出力:esukar<SOW>to', '正解:esukare:to', '単語:エスカレート')
# ('idx:10069', '出力:<EOW>ouiti', '正解:ryouiti', '単語:良一')
# ('idx:10070', '出力:siriNgu', '正解:si:riNgu', '単語:シーリング')
# ('idx:10111', '出力:yokotaaaru', '正解:yokotawaru', '単語:横たわる')
# ('idx:10123', '出力:suk<SOW>to', '正解:suke:to', '単語:スケート')
# ('idx:10124', '出力:usuuhikousi', '正解:uchuuhikousi', '単語:宇宙飛行士')
# ('idx:10147', '出力:aaseda', '正解:waseda', '単語:早稲田')
# ('idx:10153', '出力:oousyousiki', '正解:hyousyousiki', '単語:表彰式')
# ('idx:10160', '出力:sddaN', '正解:su:daN', '単語:スーダン')
# ('idx:10174', '出力:iaasu', '正解:iwasu', '単語:言わす')
# ('idx:10187', '出力:<EOW>uuta', '正解:ryuuta', '単語:柳田')
# ('idx:10190', '出力:sy<SOW>kusupia', '正解:sye:kusupia', '単語:シェークスピア')
# ('idx:10215', '出力:<EOW>ounai', '正解:ryounai', '単語:領内')
# ('idx:10226', '出力:ogiaara', '正解:ogiwara', '単語:荻原')
# ('idx:10229', '出力:jitudou', '正解:jitugyou', '単語:実業')
# ('idx:10236', '出力:mitusaaa', '正解:mitusawa', '単語:三沢')
# ('idx:10243', '出力:kaNt<EOW>', '正解:kaNta:', '単語:カンター')
# ('idx:10246', '出力:syurou', '正解:syugyou', '単語:修行')
# ('idx:10257', '出力:kakaaaru', '正解:kakawaru', '単語:係る')
# ('idx:10260', '出力:migigaaa', '正解:migigawa', '単語:右側')
# ('idx:10288', '出力:uoubou', '正解:nyoubou', '単語:女房')
# ('idx:10295', '出力:kyaQtifur<SOW>zu', '正解:kyaQtifure:zu', '単語:キャッチフレーズ')
# ('idx:10305', '出力:ogasaaara', '正解:ogasawara', '単語:小笠原')
# ('idx:10306', '出力:oooou', '正解:oozou', '単語:大沢')
# ('idx:10322', '出力:patok<EOW>', '正解:patoka:', '単語:パトカー')
# ('idx:10332', '出力:deNaaki', '正解:deNwaki', '単語:電話機')
# ('idx:10337', '出力:famirr', '正解:famiri:', '単語:ファミリー')
# ...
# ('idx:24565', '出力:idou', '正解:igyou', '単語:偉業')
# ('idx:24567', '出力:roQkufero', '正解:roQkufera:', '単語:ロックフェラー')
# ('idx:24574', '出力:oper<SOW>to', '正解:opere:ta:', '単語:オペレーター')
# ('idx:24579', '出力:merrraNdo', '正解:meri:raNdo', '単語:メリーランド')
# ('idx:24580', '出力:kokuoou', '正解:kokuhyou', '単語:酷評')
# ('idx:24584', '出力:k<EOW>suto', '正解:ka:suto', '単語:カースト')
# ('idx:24590', '出力:yaNaari', '正解:yaNwari', '単語:やんわり')
# ('idx:24605', '出力:soukousou', '正解:choukousou', '単語:超高層')
# ('idx:24610', '出力:douji', '正解:gyouji', '単語:行司')
# ('idx:24616', '出力:haNdobrru', '正解:haNdobo:ru', '単語:ハンドボール')
# ('idx:24624', '出力:rnba:', '正解:ro:ba:', '単語:ローバー')
# ('idx:24629', '出力:juu<EOW>oukyuu', '正解:juuryoukyuu', '単語:重量級')
# ('idx:24649', '出力:seamaN', '正解:cheamaN', '単語:チェアマン')
# ('idx:24654', '出力:<EOW>uuki', '正解:ryuuki', '単語:隆起')
# ('idx:24665', '出力:ris<SOW>ru', '正解:rise:ru', '単語:リセール')
# ('idx:24669', '出力:koNs<EOW>tohrru', '正解:koNsa:toho:ru', '単語:コンサートホール')
# ('idx:24671', '出力:kyuusou', '正解:kyuubyou', '単語:急病')
# ('idx:24681', '出力:b<SOW>ju', '正解:be:ju', '単語:ベージュ')
# ('idx:24688', '出力:uaasa', '正解:uwasa', '単語:噂')
# ('idx:24690', '出力:kaaagutiko', '正解:kawagutiko', '単語:河口湖')
# ('idx:24696', '出力:frri:', '正解:fo:ri:', '単語:フォーリー')
# ('idx:24697', '出力:atopNseihifueN', '正解:atopi:seihifueN', '単語:アトピー性皮膚炎')
# ('idx:24705', '出力:kouoou', '正解:koumyou', '単語:光明')
# ('idx:24706', '出力:burisubuN', '正解:burisube:N', '単語:ブリスベーン')
# ('idx:24721', '出力:booou', '正解:bohyou', '単語:墓標')
# ('idx:24740', '出力:mioou', '正解:mizou', '単語:みぞう')
# ('idx:24743', '出力:<EOW>uutani', '正解:ryuutani', '単語:龍谷')
# ('idx:24751', '出力:kurumu', '正解:kuri:mu', '単語:クリーム')
# ('idx:24769', '出力:seidosouti', '正解:seigyosouti', '単語:制御装置')
# ('idx:24816', '出力:hakuniti', '正解:hyakuniti', '単語:百日')
# ('idx:24820', '出力:bogrru', '正解:bogo:ru', '単語:ボゴール')
# ('idx:24821', '出力:supukusu', '正解:supi:kusu', '単語:スピークス')
# ('idx:24824', '出力:daburubogu', '正解:daburubogi:', '単語:ダブルボギー')
# ('idx:24826', '出力:norimaaasu', '正解:norimawasu', '単語:乗り回す')
# ('idx:24836', '出力:kyouaasei', '正解:kyouwasei', '単語:共和制')
# ('idx:24873', '出力:aadatumi', '正解:wadatumi', '単語:わだつみ')
# ('idx:24874', '出力:s<SOW>fuga:do', '正解:se:fuga:do', '単語:セーフガード')
# ('idx:24887', '出力:rrdor<SOW>su', '正解:ro:dore:su', '単語:ロードレース')
# ('idx:24888', '出力:pesyaaaru', '正解:pesyawaru', '単語:ペシャワル')
# ('idx:24894', '出力:p<EOW>kiNsoNtou', '正解:pa:kiNsoNbyou', '単語:パーキンソン病')
# ('idx:24903', '出力:supkytumaN', '正解:supo:tumaN', '単語:スポーツマン')
# ('idx:24918', '出力:tai<EOW>uu', '正解:tairyuu', '単語:滞留')
# ('idx:24924', '出力:seidobou', '正解:seigyobou', '単語:制御棒')
# ('idx:24925', '出力:neNjuudouji', '正解:neNjuugyouji', '単語:年中行事')
# ('idx:24933', '出力:tuukaNkaNrisyoku', '正解:chuukaNkaNrisyoku', '単語:中間管理職')
# ('idx:24935', '出力:marin<SOW>zu', '正解:marina:zu', '単語:マリナーズ')
# ('idx:24938', '出力:sumitomokagakukourou', '正解:sumitomokagakukougyou', '単語:住友化学工業')
# ('idx:24961', '出力:jpuniNgu', '正解:o:puniNgu', '単語:オープニング')
# ('idx:24964', '出力:t<EOW>tiru', '正解:cha:tiru', '単語:チャーチル')
# ('idx:24965', '出力:aNd<EOW>soN', '正解:aNda:soN', '単語:アンダーソン')
# ('idx:24971', '出力:idbijinesu', '正解:nyu:bijinesu', '単語:ニュービジネス')
# ('idx:24974', '出力:aakata', '正解:wakata', '単語:若田')
# ('idx:24977', '出力:gardti', '正解:garu:ti', '単語:ガルーチ')
# ('idx:24978', '出力:tuutou', '正解:chuutou', '単語:中等')
# ('idx:24986', '出力:buroQkorr', '正解:buroQkori:', '単語:ブロッコリー')
# ('idx:25002', '出力:souheisei', '正解:chouheisei', '単語:徴兵制')
# ('idx:25008', '出力:ooudou', '正解:hyoudou', '単語:兵藤')
# ('idx:25053', '出力:jjji:', '正解:ja:ji:', '単語:ジャージー')
# ('idx:25054', '出力:syokudouaNteisyo', '正解:syokugyouaNteisyo', '単語:職業安定所')
# ('idx:25063', '出力:hoQk<SOW>', '正解:hoQke:', '単語:ホッケー')
# ('idx:25065', '出力:arukrruchuudoku', '正解:aruko:ruchuudoku', '単語:アルコール中毒')
# ('idx:25070', '出力:mouumeNto', '正解:monyumeNto', '単語:モニュメント')
# ('idx:25090', '出力:kaaade', '正解:kawade', '単語:河出')
# ('idx:25094', '出力:rouriN', '正解:ryouriN', '単語:両輪')
# ('idx:25104', '出力:koprraito', '正解:kopi:raita:', '単語:コピーライター')
# ('idx:25108', '出力:suukaNsou', '正解:chuukaNsou', '単語:中間層')
# ('idx:25121', '出力:aakatu', '正解:wakatu', '単語:分かつ')
# ('idx:25128', '出力:moNrr', '正解:moNro:', '単語:モンロー')
# ('idx:25141', '出力:syuQsousaki', '正解:syuQchousaki', '単語:出張先')
# ('idx:25151', '出力:inuaasi', '正解:inuwasi', '単語:イヌワシ')
# ('idx:25164', '出力:misaaasi', '正解:misawasi', '単語:三沢市')
# ('idx:25170', '出力:suusei', '正解:chuusei', '単語:中性')
# ('idx:25174', '出力:kuaaaari', '正解:kuwawari', '単語:加わり')
# ('idx:25176', '出力:haQk<EOW>', '正解:haQka:', '単語:ハッカー')
# ('idx:25189', '出力:kaaasakisitamaku', '正解:kawasakisitamaku', '単語:川崎市多摩区')
# ('idx:25198', '出力:soNgurait<EOW>', '正解:soNguraita:', '単語:ソングライター')
# ('idx:25200', '出力:furrhaNdo', '正解:furi:haNdo', '単語:フリーハンド')
# ('idx:25207', '出力:cherunobuirigeNsirokuhatudeNsyo', '正解:cherunobuirigeNsiryokuhatudeNsyo', '単語:チェルノブイリ原子力発電所')
# ('idx:25215', '出力:japaNman<SOW>', '正解:japaNmane:', '単語:ジャパンマネー')
# ('idx:25255', '出力:j<SOW>musu', '正解:je:musu', '単語:ジェームス')
# ('idx:25283', '出力:momooou', '正解:momozou', '単語:百三')
# ('idx:25301', '出力:pasuw<EOW>do', '正解:pasuwa:do', '単語:パスワード')
# ('idx:25306', '出力:baQkusukuruN', '正解:baQkusukuri:N', '単語:バックスクリーン')
# ('idx:25314', '出力:p<EOW>totaimu', '正解:pa:totaimu', '単語:パートタイム')
# ('idx:25325', '出力:koukoudouseisaNsisuu', '正解:koukougyouseisaNsisuu', '単語:鉱工業生産指数')
# ('idx:25337', '出力:btto', '正解:bi:to', '単語:ビート')
# ('idx:25339', '出力:rsymu', '正解:ru:mu', '単語:ルーム')
# ('idx:25347', '出力:w<EOW>gun<EOW>', '正解:wa:guna:', '単語:ワーグナー')
# ('idx:25353', '出力:aNk<EOW>', '正解:aNka:', '単語:アンカー')
# ('idx:25358', '出力:siNsei<EOW>oku', '正解:siNseiryoku', '単語:新勢力')
# ('idx:25360', '出力:aaza', '正解:waza', '単語:わざ')
# ('idx:25377', '出力:kakimaaasu', '正解:kakimawasu', '単語:かき回す')
# ('idx:25380', '出力:irukdtuku', '正解:iruku:tuku', '単語:イルクーツク')
# ('idx:25381', '出力:siomiou', '正解:siomizu', '単語:塩水')
# ('idx:25390', '出力:maaasi', '正解:mawasi', '単語:回し')
# ('idx:25402', '出力:n<SOW>miNgu', '正解:ne:miNgu', '単語:ネーミング')
# ('idx:25405', '出力:taimt', '正解:taima:', '単語:タイマー')
# ('idx:25407', '出力:torikaaasu', '正解:torikawasu', '単語:取り交わす')
# ('idx:25422', '出力:aakasugi', '正解:wakasugi', '単語:若杉')
# ('idx:25437', '出力:minagaaa', '正解:minagawa', '単語:皆川')
# ('idx:25438', '出力:oeNtou', '正解:zeNtou', '単語:全島')
# ('idx:25457', '出力:b<EOW>ru', '正解:ba:ru', '単語:ｂ')
# ('idx:25464', '出力:har<SOW>', '正解:hare:', '単語:ハレー')
# ('idx:25471', '出力:rousyou', '正解:gyousyou', '単語:行商')
# ('idx:25498', '出力:jipusi', '正解:jipusi:', '単語:ジプシー')
# ('idx:25501', '出力:<SOW>ai', '正解:e:ai', '単語:ＡＩ')
# ('idx:25514', '出力:ooujuNgo', '正解:hyoujuNgo', '単語:標準語')
# ('idx:25515', '出力:bitamiNst', '正解:bitamiNsi:', '単語:ビタミンＣ')
# ('idx:25519', '出力:bej<EOW>ru', '正解:beja:ru', '単語:ベジャール')
# ('idx:25528', '出力:aaga', '正解:waga', '単語:我')
# ('idx:25540', '出力:roNgusero', '正解:roNgusera:', '単語:ロングセラー')
# ('idx:25541', '出力:idginia', '正解:nyu:ginia', '単語:ニューギニア')
# ('idx:25561', '出力:tatimaaari', '正解:tatimawari', '単語:立ち回り')
# ('idx:25562', '出力:buraNd<SOW>', '正解:buraNde:', '単語:ブランデー')
# ('idx:25564', '出力:kaaanisisi', '正解:kawanisisi', '単語:川西市')
# ('idx:25566', '出力:eNkabinuru', '正解:eNkabini:ru', '単語:塩化ビニール')
# ('idx:25569', '出力:sakaigaaa', '正解:sakaigawa', '単語:境川')
# ('idx:25586', '出力:m<EOW>tiN', '正解:ma:tiN', '単語:マーチン')
# ('idx:25589', '出力:oousatu', '正解:hyousatu', '単語:表札')
# ('idx:25591', '出力:yrguruto', '正解:yo:guruto', '単語:ヨーグルト')
# ('idx:25594', '出力:kuaadate', '正解:kuwadate', '単語:企て')
# ('idx:25598', '出力:saNpioNsiQpu', '正解:chaNpioNsiQpu', '単語:チャンピオンシップ')
# ('idx:25608', '出力:syutou', '正解:syubyou', '単語:種苗')
# ('idx:25656', '出力:moderuk<SOW>su', '正解:moderuke:su', '単語:モデルケース')
# ('idx:25659', '出力:barukonu', '正解:barukoni:', '単語:バルコニー')
# ('idx:25662', '出力:aazuraaasii', '正解:wazurawasii', '単語:わずらわしい')
# ('idx:25665', '出力:koNuaku', '正解:koNnyaku', '単語:こんにゃく')
# ('idx:25669', '出力:guNtou', '正解:guNbyou', '単語:軍兵')
# ('idx:25674', '出力:okiaasureru', '正解:okiwasureru', '単語:置き忘れる')
# ('idx:25683', '出力:ooaarai', '正解:oowarai', '単語:大笑い')
# ('idx:25686', '出力:seQsaku', '正解:seQchaku', '単語:接着')
# ('idx:25687', '出力:iuuu', '正解:inyuu', '単語:移入')
# ('idx:25703', '出力:sousyuuuuu', '正解:sousyuunyuu', '単語:総収入')
# ('idx:25705', '出力:nbuN', '正解:o:buN', '単語:オーブン')
# ('idx:25706', '出力:oougaki', '正解:hyougaki', '単語:氷河期')
# ('idx:25715', '出力:iooN', '正解:izoN', '単語:異存')
# ('idx:25717', '出力:hibusousuuritu', '正解:hibusouchuuritu', '単語:非武装中立')
# ('idx:25723', '出力:irokaaa', '正解:irokawa', '単語:色川')
# ('idx:25727', '出力:binrrustto', '正解:bini:rusi:to', '単語:ビニールシート')
# ('idx:25751', '出力:kobayakaaa', '正解:kobayakawa', '単語:小早川')
# ('idx:25765', '出力:jo<EOW>oku', '正解:joryoku', '単語:助力')
# ('idx:25777', '出力:rrreNsu', '正解:ro:reNsu', '単語:ローレンス')
# ('idx:25784', '出力:uaamaaari', '正解:uwamawari', '単語:上回り')
# ('idx:25788', '出力:mda', '正解:mu:a', '単語:ムーア')
# ('idx:25799', '出力:<EOW>ousima', '正解:ryousima', '単語:両島')
# ('idx:25815', '出力:kaaagisi', '正解:kawagisi', '単語:川岸')
# ('idx:25819', '出力:hebukyuu', '正解:hebi:kyuu', '単語:ヘビー級')
# ('idx:25824', '出力:siroaaiN', '正解:sirowaiN', '単語:白ワイン')
# ('idx:25843', '出力:niNtaiouyoi', '正解:niNtaizuyoi', '単語:忍耐強い')
# ('idx:25858', '出力:kakusikikiso', '正解:ryakusikikiso', '単語:略式起訴')
# ('idx:25859', '出力:b<SOW>ta', '正解:be:ta', '単語:ベータ')
# ('idx:25877', '出力:jioou', '正解:jizou', '単語:地蔵')
# ('idx:25895', '出力:<EOW>uusitu', '正解:ryuusitu', '単語:流失')
# ('idx:25906', '出力:<EOW>ousyuusyou', '正解:ryousyuusyou', '単語:領収証')
# ('idx:25912', '出力:kyuuuuu', '正解:kyuunyuu', '単語:吸入')
# ('idx:25913', '出力:hiioukika', '正解:hinyoukika', '単語:泌尿器科')
# ('idx:25914', '出力:jougai', '正解:byougai', '単語:病害')
# ('idx:25921', '出力:garjji', '正解:gare:ji', '単語:ガレージ')
# ('idx:25922', '出力:suttbuN', '正解:suti:buN', '単語:スティーブン')
# ('idx:25933', '出力:p<SOW>sum<SOW>k<EOW>', '正解:pe:sume:ka:', '単語:ペースメーカー')
# ('idx:25937', '出力:matukaaa', '正解:matukawa', '単語:松川')
# ('idx:25956', '出力:<EOW>oujuu', '正解:ryoujuu', '単語:猟銃')
# ('idx:25959', '出力:werun<EOW>', '正解:weruna:', '単語:ウェルナー')
# ('idx:25970', '出力:yuzuriaatasu', '正解:yuzuriwatasu', '単語:譲り渡す')
# ('idx:26001', '出力:toraiasurot', '正解:toraiasuroN', '単語:トライアスロン')
# ('idx:26004', '出力:saya', '正解:chaya', '単語:茶屋')
# ('idx:26012', '出力:ioureNji', '正解:myoureNji', '単語:妙蓮寺')
# ('idx:26025', '出力:p<EOW>sonaritt', '正解:pa:sonariti:', '単語:パーソナリティー')
# ('idx:26046', '出力:hosutokoNosyto', '正解:hosutokoNpyu:ta:', '単語:ホストコンピューター')
# ('idx:26059', '出力:sinozaaa', '正解:sinozawa', '単語:篠沢')
# ('idx:26064', '出力:rrgaN', '正解:ri:gaN', '単語:リーガン')
# ('idx:26069', '出力:<EOW>s<EOW>', '正解:a:sa:', '単語:アーサー')
# ('idx:26070', '出力:b<EOW>sutou', '正解:ba:sutou', '単語:バース党')
# ('idx:26073', '出力:yuuuukumiai', '正解:yunyuukumiai', '単語:輸入組合')
# ('idx:26076', '出力:baNp<EOW>', '正解:baNpa:', '単語:バンパー')
# ('idx:26077', '出力:furig<SOW>tokaN', '正解:furige:tokaN', '単語:フリゲート艦')
# ('idx:26090', '出力:kaaana', '正解:kawana', '単語:川奈')
# ('idx:26099', '出力:aNaaru', '正解:aNwaru', '単語:アンワル')
# ('idx:26101', '出力:burezu', '正解:bureza:', '単語:ブレザー')
# ('idx:26102', '出力:chou<EOW>oku', '正解:chouryoku', '単語:聴力')
# ('idx:26110', '出力:kagaku<EOW>ouhou', '正解:kagakuryouhou', '単語:化学療法')
# ('idx:26111', '出力:uuubu', '正解:nyuubu', '単語:入部')
# ('idx:26113', '出力:aQpurukoNmdta', '正解:aQpurukoNpyu:ta', '単語:アップルコンピュータ')
# ('idx:26123', '出力:oeQtaioNdo', '正解:zeQtaioNdo', '単語:絶対温度')
# ('idx:26132', '出力:aaseda', '正解:waseda', '単語:早田')
# ('idx:26133', '出力:sousou', '正解:byousou', '単語:病巣')
# ('idx:26148', '出力:hiNzdkyou', '正解:hiNzu:kyou', '単語:ヒンズー教')
# ('idx:26161', '出力:k<EOW>toriQji', '正解:ka:toriQji', '単語:カートリッジ')
# ('idx:26165', '出力:kurumanorouriN', '正解:kurumanoryouriN', '単語:車の両輪')
# ('idx:26170', '出力:m<SOW>ku', '正解:me:ku', '単語:メーク')
# ('idx:26181', '出力:prtoairaNdo', '正解:po:toairaNdo', '単語:ポートアイランド')
# ('idx:26192', '出力:rouriniN', '正解:ryouriniN', '単語:料理人')
# ('idx:26203', '出力:bebi:k<EOW>', '正解:bebi:ka:', '単語:ベビーカー')
# ('idx:26220', '出力:k<EOW>dorrN', '正解:ka:doro:N', '単語:カードローン')
# ('idx:26224', '出力:riNk<EOW>N', '正解:riNka:N', '単語:リンカーン')
# ('idx:26242', '出力:aakuzaya', '正解:gyakuzaya', '単語:逆ざや')
# ('idx:26246', '出力:norudiQkusuku', '正解:norudiQkusuki:', '単語:ノルディックスキー')
# ('idx:26261', '出力:rnpuu<SOW>', '正解:ro:puue:', '単語:ロープウエー')
# ('idx:26276', '出力:komatugaaa', '正解:komatugawa', '単語:小松川')
# ('idx:26277', '出力:haQka', '正解:hyaQka', '単語:百科')
# ('idx:26281', '出力:araaare', '正解:araware', '単語:顕')
# ('idx:26285', '出力:kaaairasii', '正解:kawairasii', '単語:かわいらしい')
# ('idx:26288', '出力:smmeNsu', '正解:si:meNsu', '単語:シーメンス')
# ('idx:26289', '出力:kuaabara', '正解:kuwabara', '単語:桑原')
# ('idx:26290', '出力:tjNdauN', '正解:to:NdauN', '単語:トーンダウン')
# ('idx:26295', '出力:suusaN', '正解:chuusaN', '単語:中三')
# ('idx:26299', '出力:kokureNsyokuryounouroukikaN', '正解:kokureNsyokuryounougyoukikaN', '単語:国連食糧農業機関')
# ('idx:26307', '出力:sunuk<EOW>', '正解:suni:ka:', '単語:スニーカー')
# ('idx:26313', '出力:krraN', '正解:ko:raN', '単語:コーラン')
# ('idx:26334', '出力:doukaN', '正解:gyoukaN', '単語:行間')
# ('idx:26339', '出力:sut<EOW>toraiN', '正解:suta:toraiN', '単語:スタートライン')
# ('idx:26342', '出力:taaara', '正解:tawara', '単語:俵')
# ('idx:26348', '出力:sikou<EOW>oku', '正解:sikouryoku', '単語:思考力')
# ('idx:26352', '出力:dokyumeNtarteiga', '正解:dokyumeNtari:eiga', '単語:ドキュメンタリー映画')
# ('idx:26353', '出力:kakegaaa', '正解:kakegawa', '単語:掛川')
# ('idx:26363', '出力:aiaa', '正解:aiwa', '単語:アイワ')
# ('idx:26376', '出力:siat<EOW>kokdN', '正解:siata:koku:N', '単語:シアターコクーン')
# ('idx:26389', '出力:minisuk<EOW>to', '正解:minisuka:to', '単語:ミニスカート')
# ('idx:26402', '出力:saaako', '正解:sawako', '単語:佐和子')
# ('idx:26412', '出力:marrna', '正解:mari:na', '単語:マリーナ')
# ('idx:26417', '出力:naNb<EOW>pur<SOW>to', '正解:naNba:pure:to', '単語:ナンバープレート')
# ('idx:26418', '出力:puroguramu', '正解:purogurama:', '単語:プログラマー')
# ('idx:26442', '出力:miristberuto', '正解:mirisi:beruto', '単語:ミリシーベルト')
# ('idx:26446', '出力:tuuoubuNritai', '正解:chuuoubuNritai', '単語:中央分離帯')
# ('idx:26447', '出力:nsybo:', '正解:nu:bo:', '単語:ヌーボー')
# ('idx:26448', '出力:ooudo', '正解:hyoudo', '単語:表土')
# ('idx:26452', '出力:touoe', '正解:touze', '単語:党是')
# ('idx:26469', '出力:supo:tuk<EOW>', '正解:supo:tuka:', '単語:スポーツカー')
# ('idx:26470', '出力:u<SOW>toresu', '正解:ue:toresu', '単語:ウエートレス')
# ('idx:26474', '出力:kisiaadasi', '正解:kisiwadasi', '単語:岸和田市')
# ('idx:26496', '出力:suttru', '正解:suti:ru', '単語:スチール')
# ('idx:26498', '出力:dokeNdou', '正解:dokeNgyou', '単語:土建業')
# ('idx:26504', '出力:<EOW>uuzou', '正解:ryuuzou', '単語:隆三')
# ('idx:26505', '出力:ooioumi', '正解:ooizumi', '単語:大泉')
# ('idx:26513', '出力:simaNtogaaa', '正解:simaNtogawa', '単語:四万十川')
# ('idx:26518', '出力:djbiQdo', '正解:de:biQdo', '単語:デービッド')
# ('idx:26522', '出力:penaNtor<SOW>su', '正解:penaNtore:su', '単語:ペナントレース')
# ('idx:26541', '出力:soukaaa', '正解:soukawa', '単語:相川')
# ('idx:26554', '出力:aizeNhaw<EOW>', '正解:aizeNhawa:', '単語:アイゼンハワー')
# ('idx:26569', '出力:daisyouaa', '正解:daisyouwa', '単語:大昭和')
# ('idx:26570', '出力:<EOW>uuha', '正解:ryuuha', '単語:流派')
# ('idx:26572', '出力:maNhrru', '正解:maNho:ru', '単語:マンホール')
# ('idx:26590', '出力:namaburu', '正解:namabi:ru', '単語:生ビール')
# ('idx:26616', '出力:jesus<EOW>', '正解:jesucha:', '単語:ジェスチャー')
# ('idx:26626', '出力:raid<EOW>', '正解:raida:', '単語:ライダー')
# ('idx:26639', '出力:miaataseru', '正解:miwataseru', '単語:見渡せる')
# ('idx:26652', '出力:taig<EOW>su', '正解:taiga:su', '単語:タイガース')
# ('idx:26656', '出力:saaari', '正解:sawari', '単語:さわり')
# ('idx:26666', '出力:reNriN', '正解:zeNriN', '単語:前輪')
# ('idx:26668', '出力:sidousiki', '正解:sigyousiki', '単語:始業式')
# ('idx:26676', '出力:monor<SOW>ru', '正解:monore:ru', '単語:モノレール')
# ('idx:26691', '出力:iQsouiQseki', '正解:iQchouiQseki', '単語:一朝一夕')
# ('idx:26704', '出力:jisuk<EOW>rudesutaN', '正解:jisuka:rudesutaN', '単語:ジスカールデスタン')
# ('idx:26715', '出力:ooujou', '正解:hyoujou', '単語:氷上')
# ('idx:26718', '出力:aagami', '正解:wagami', '単語:我が身')
# ('idx:26719', '出力:sdp<EOW>dorai', '正解:su:pa:dorai', '単語:スーパードライ')
# ('idx:26732', '出力:<EOW>ouyou', '正解:ryouyou', '単語:両用')
# ('idx:26733', '出力:ozoNhrru', '正解:ozoNho:ru', '単語:オゾンホール')
# ('idx:26741', '出力:takedayakuhiNkoudou', '正解:takedayakuhiNkougyou', '単語:武田薬品工業')
# ('idx:26743', '出力:kouoou', '正解:koumyou', '単語:巧妙')
# ('idx:26751', '出力:soujuu<EOW>ou', '正解:soujuuryou', '単語:総重量')
# ('idx:26755', '出力:juuuu', '正解:junyuu', '単語:授乳')
# ('idx:26770', '出力:supuriNkurs', '正解:supuriNkura:', '単語:スプリンクラー')
# ('idx:26786', '出力:k<EOW>riNgu', '正解:ka:riNgu', '単語:カーリング')
# ('idx:26793', '出力:iQsaNkataNsosuudoku', '正解:iQsaNkataNsochuudoku', '単語:一酸化炭素中毒')
# ('idx:26796', '出力:sosikioou', '正解:sosikihyou', '単語:組織票')
# ('idx:26801', '出力:nigemaaaru', '正解:nigemawaru', '単語:逃げ回る')
# ('idx:26805', '出力:w<EOW>rudosirrru', '正解:wa:rudosiri:zu', '単語:ワールドシリーズ')
# ('idx:26806', '出力:b<EOW>ru', '正解:ba:ru', '単語:バール')
# ('idx:26807', '出力:dnnatu', '正解:do:natu', '単語:ドーナツ')
# ('idx:26827', '出力:k<SOW>nibaru', '正解:ka:nibaru', '単語:カーニバル')
# ('idx:26833', '出力:rabukrru', '正解:rabuko:ru', '単語:ラブコール')
# ('idx:26842', '出力:k<EOW>to', '正解:ka:to', '単語:カート')
# ('idx:26844', '出力:miNsyusyuusuusei', '正解:miNsyusyuuchuusei', '単語:民主集中制')
# ('idx:26853', '出力:taNkurrrr', '正解:taNkuro:ri:', '単語:タンクローリー')
# ('idx:26873', '出力:rabusutrrr', '正解:rabusuto:ri:', '単語:ラブストーリー')
# ('idx:26876', '出力:koaadaka', '正解:kowadaka', '単語:声高')
# 総エラー数:2716 正解率:89.894%

# %% [markdown]
# # 2 産出モデル 意味から音韻

# %% [markdown]
# ## 2.1 モデルの定義

# %%
# Define model
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
from torch.nn.utils.rnn import pad_sequence

class EncDec_s2p(nn.Module):
    def __init__(self,
                 sem_dim:int,
                 dec_vocab_size:int,
                 n_hid:int,
                 n_layers:int=2,
                 bidirectional:bool=False):
        super().__init__()

        # 単語の意味ベクトル a.k.a 埋め込み表現 を decoder の中間層に接続するための変換層
        # 別解としては，入力層に接続する方法があるが，それはまた別実装にする
        self.enc_transform_layer = nn.Linear(in_features=sem_dim,
                                             out_features=n_hid)
        self.decoder_emb = nn.Embedding(num_embeddings=dec_vocab_size,
                                        embedding_dim=n_hid,
                                        padding_idx=0)

        self.decoder = nn.LSTM(input_size=n_hid,
                               hidden_size=n_hid,
                               num_layers=n_layers,
                               batch_first=True,
                               bidirectional=bidirectional)

        # 最終出力層
        self.out_layer = nn.Linear(n_hid, dec_vocab_size)

    def forward(self, enc_inp, dec_inp):
        enc_emb = self.enc_transform_layer(enc_inp)
        hnx, cnx = enc_emb.clone(), enc_emb.clone()
        dec_emb = self.decoder_emb(dec_inp)
        dec_out, (hny, cny) = self.decoder(dec_emb,(hnx, cnx))
        return self.out_layer(dec_out)

n_hid = 64
n_layers = 1
bidirectional=False
# 直下行で，enc_vocab_size と dec_vocab_size を phoneme にしているので，音韻複勝課題に相当する
enc_dec = EncDec_s2p(sem_dim=_psylex71_ds.w2v.vector_size,
                     dec_vocab_size=len(_psylex71_ds.phoneme),
                     n_layers=n_layers,
                     bidirectional=bidirectional,
                     n_hid=n_hid).to(device)
enc_dec.eval()
# Out:
# EncDec_s2p(
#   (enc_transform_layer): Linear(in_features=200, out_features=64, bias=True)
#   (decoder_emb): Embedding(45, 64, padding_idx=0)
#   (decoder): LSTM(64, 64, batch_first=True)
#   (out_layer): Linear(in_features=64, out_features=45, bias=True)
# )

# %% [markdown]
# ## 2.2 訓練の実施

# %%
start_time = time.time()
n_hid = 64
n_layers = 1
epochs = 10
bidirectional=False
model = EncDec_s2p(sem_dim=_psylex71_ds.w2v.vector_size,
                   dec_vocab_size=len(_psylex71_ds.phoneme),
                   n_layers=n_layers,
                   bidirectional=bidirectional,
                   n_hid=n_hid).to(device)

optimizer = optim.Adam(model.parameters(),lr=0.001)
criterion = nn.CrossEntropyLoss(ignore_index=-1)

model.train()
interval = int(_psylex71_ds.__len__()/batch_size) >> 2
losses = []
for epoch in range(epochs):
    i = 0
    for x, y in dataloader:
        #enc_inp = torch.from_numpy([np.array(_x) for _x in x]).to(device).unsqueeze(0)
        enc_inp = torch.tensor([np.array(_x) for _x in x]).to(device).unsqueeze(0)
        # enc_inp = torch.from_numpy(np.array(x)).to(device).unsqueeze(0)
        dec_inp = pad_sequence(y, batch_first=True).to(device)
        #dec_inp = pad_sequence(y, batch_first=True).to(device).unsqueeze(0)
        tch = pad_sequence(y, batch_first=True, padding_value=-1.0).to(device)
        out = model(enc_inp, dec_inp)
        loss = criterion(out[0], tch[0])
        for h in range(1,len(tch)):
            loss += criterion(out[h], tch[h])
        losses.append(loss.item()/len(x))

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        i += 1
        if (i % interval) == 0:
            print(f'epoch:{epoch:2d}, batch:{i:2d}, loss:{loss.item()/len(x):.3f}')

end_time = time.time()
total_time = end_time - start_time
total_time_str = str(datetime.timedelta(seconds=int(total_time)))
print(f'Training time {total_time_str}')

plt.plot(losses)
plt.title(f'epochs:{epochs}, batch_size:{batch_size}, n_hid:{n_hid}, n_layers:{n_layers}, time collapsed:{total_time_str}')
plt.show()
# Out:
# epoch: 0, batch: 6, loss:3.609
# epoch: 0, batch:12, loss:3.379
# epoch: 0, batch:18, loss:3.093
# epoch: 0, batch:24, loss:2.781
# epoch: 1, batch: 6, loss:2.283
# epoch: 1, batch:12, loss:1.992
# epoch: 1, batch:18, loss:1.711
# epoch: 1, batch:24, loss:1.463
# epoch: 2, batch: 6, loss:1.201
# epoch: 2, batch:12, loss:1.024
# epoch: 2, batch:18, loss:0.870
# epoch: 2, batch:24, loss:0.734
# epoch: 3, batch: 6, loss:0.581
# epoch: 3, batch:12, loss:0.521
# epoch: 3, batch:18, loss:0.450
# epoch: 3, batch:24, loss:0.391
# epoch: 4, batch: 6, loss:0.321
# epoch: 4, batch:12, loss:0.272
# epoch: 4, batch:18, loss:0.246
# epoch: 4, batch:24, loss:0.232
# epoch: 5, batch: 6, loss:0.195
# epoch: 5, batch:12, loss:0.168
# epoch: 5, batch:18, loss:0.173
# epoch: 5, batch:24, loss:0.153
# epoch: 6, batch: 6, loss:0.132
# epoch: 6, batch:12, loss:0.121
# epoch: 6, batch:18, loss:0.111
# epoch: 6, batch:24, loss:0.102
# epoch: 7, batch: 6, loss:0.096
# epoch: 7, batch:12, loss:0.085
# epoch: 7, batch:18, loss:0.080
# epoch: 7, batch:24, loss:0.078
# epoch: 8, batch: 6, loss:0.069
# epoch: 8, batch:12, loss:0.063
# epoch: 8, batch:18, loss:0.064
# epoch: 8, batch:24, loss:0.063
# epoch: 9, batch: 6, loss:0.051
# epoch: 9, batch:12, loss:0.053
# epoch: 9, batch:18, loss:0.049
# epoch: 9, batch:24, loss:0.045
# Training time 0:03:57

# %% [markdown]
# ## 2.3 学習結果の評価

# %%
model.eval()
isPrint = True
errors = []
for N in tqdm(range(_psylex71_ds.__len__())):
#for N in np.random.permutation(_psylex71_ds.__len__())[:100]:
    x, y = _psylex71_ds.__getitem__(N)
    #enc_inp = torch.from_numpy(np.array(x)).to('cpu').unsqueeze(0)
    enc_inp = torch.from_numpy(np.array(x)).to(device).unsqueeze(0)
    enc_emb = model.enc_transform_layer(enc_inp)
    hnx, cnx = enc_emb.clone(), enc_emb.clone()
    dec_inp = y.to(device)
    #dec_inp = y
    dec_emb = model.decoder_emb(dec_inp).to(device)
    #dec_emb = model.decoder_emb(dec_inp).to('cpu')
    dec_out, (hny, cny) = model.decoder(dec_emb,(hnx, cnx))
    dec_out = model.out_layer(dec_out).to('cpu')
    #dec_out = model.out_layer(dec_out)
    y_ids = np.argmax(dec_out.detach().numpy(),axis=1)

    n_correct = np.array((y_ids[1:-1] == _psylex71_ds.getitem(N)[2]).sum())
    isOK = n_correct == len(_psylex71_ds.getitem(N)[2])
    color = 'grey' if isOK else 'red'

    if not isOK:
        errors.append((N,y_ids))
        if isPrint:
            print(colored((f'{N:05d}', #y_ids,
                           "".join(p for p in _psylex71_ds.phon_ids2phn(y_ids[1:-1]))),color,attrs=["bold"]), end=" ")
            print(_psylex71_ds.getitem(N))

cr = len(errors) / _psylex71_ds.__len__()
print(f'総エラー数:{len(errors)}',
      f'正解率:{(1.-cr)*100:.3f}')
# Out:
#   0%|          | 0/26877 [00:00<?, ?it/s]
# ('00030', 'moumei') ('表明', ['hy', 'o', 'u', 'm', 'e', 'i'], [25, 8, 6, 29, 7, 5], [2102, 2312])
# ('00063', 'douuaku') ('動脈', ['d', 'o', 'u', 'my', 'a', 'k', 'u'], [19, 8, 6, 30, 4, 27, 6], [1923, 2300])
# ('00080', 'mousi') ('表紙', ['hy', 'o', 'u', 's', 'i'], [25, 8, 6, 37, 5], [2102, 1174])
# ('00101', 'juuou') ('寿命', ['j', 'u', 'my', 'o', 'u'], [26, 6, 30, 8, 6], [1260, 2311])
# ('00202', 'haQsyou') ('発表', ['h', 'a', 'Q', 'py', 'o', 'u'], [24, 4, 15, 34, 8, 6], [2033, 2102])
# ('00210', 'daiiou') ('代表', ['d', 'a', 'i', 'hy', 'o', 'u'], [19, 4, 5, 25, 8, 6], [1697, 2102])
# ('00308', 'mouiN') ('病院', ['by', 'o', 'u', 'i', 'N'], [17, 8, 6, 5, 14], [2110, 436])
# ('00344', 'gurapu') ('グループ', ['g', 'u', 'r', 'u:', 'p', 'u'], [22, 6, 35, 11, 33, 6], [159, 214, 265, 197])
# ('00406', 'douchuu') ('導入', ['d', 'o', 'u', 'ny', 'u', 'u'], [19, 8, 6, 32, 6, 6], [1929, 1968])
# ('00408', 'mouka') ('評価', ['hy', 'o', 'u', 'k', 'a'], [25, 8, 6, 27, 4], [2105, 524])
# ('00413', 'yuuuu') ('輸入', ['y', 'u', 'ny', 'u', 'u'], [42, 6, 32, 6, 6], [2352, 1968])
# ('00551', 'saaou') ('作業', ['s', 'a', 'gy', 'o', 'u'], [37, 4, 23, 8, 6], [1107, 806])
# ('00578', 'mokuiou') ('目標', ['m', 'o', 'k', 'u', 'hy', 'o', 'u'], [29, 8, 27, 6, 25, 8, 6], [2331, 2107])
# ('00621', '<SOW>ayo:ku') ('ニューヨーク', ['ny', 'u:', 'y', 'o:', 'k', 'u'], [32, 11, 42, 13, 27, 6], [185, 237, 265, 211, 265, 158])
# ('00693', 'toumou') ('投票', ['t', 'o', 'u', 'hy', 'o', 'u'], [39, 8, 6, 25, 8, 6], [1886, 2104])
# ('00845', 'mougeN') ('表現', ['hy', 'o', 'u', 'g', 'e', 'N'], [25, 8, 6, 22, 7, 14], [2102, 936])
# ('00969', 'kouauu') ('購入', ['k', 'o', 'u', 'ny', 'u', 'u'], [27, 8, 6, 32, 6, 6], [1033, 1968])
# ('00979', 'kksu') ('ケース', ['k', 'e:', 's', 'u'], [27, 12, 37, 6], [160, 265, 168])
# ('01008', 'koNsyata:') ('コンピューター', ['k', 'o', 'N', 'py', 'u:', 't', 'a:'], [27, 8, 14, 34, 11, 39, 9], [162, 221, 194, 237, 265, 174, 265])
# ('01050', 'koumou') ('公表', ['k', 'o', 'u', 'hy', 'o', 'u'], [27, 8, 6, 25, 8, 6], [973, 2102])
# ('01102', 'syuuchuu') ('収入', ['sy', 'u', 'u', 'ny', 'u', 'u'], [38, 6, 6, 32, 6, 6], [1267, 1968])
# ('01150', 'iou') ('票', ['hy', 'o', 'u'], [25, 8, 6], [2104])
# ('01342', 'mouki') ('病気', ['by', 'o', 'u', 'k', 'i'], [17, 8, 6, 27, 5], [2110, 689])
# ('01401', 'moujou') ('表情', ['hy', 'o', 'u', 'j', 'o', 'u'], [25, 8, 6, 26, 8, 6], [2102, 1403])
# ('01412', '<SOW>uuiN') ('入院', ['ny', 'u', 'u', 'i', 'N'], [32, 6, 6, 5, 14], [1968, 436])
# ('01682', 'eriaiN') ('エリツィン', ['e', 'r', 'i', 'ty', 'i', 'N'], [7, 35, 5, 40, 5, 14], [152, 213, 178, 228, 221])
# ('01750', 'aasu') ('ニュース', ['ny', 'u:', 's', 'u'], [32, 11, 37, 6], [185, 237, 265, 168])
# ('01798', 'mouji') ('表示', ['hy', 'o', 'u', 'j', 'i'], [25, 8, 6, 26, 5], [2102, 1190])
# ('01812', 'saNauu') ('参入', ['s', 'a', 'N', 'ny', 'u', 'u'], [37, 4, 14, 32, 6, 6], [1130, 1968])
# ('01873', 'kaauu') ('加入', ['k', 'a', 'ny', 'u', 'u'], [27, 4, 32, 6, 6], [518, 1968])
# ('01993', 'kaiauu') ('介入', ['k', 'a', 'i', 'ny', 'u', 'u'], [27, 4, 5, 32, 6, 6], [556, 1968])
# ('02069', 'mou') ('表', ['hy', 'o', 'u'], [25, 8, 6], [2102])
# ('02080', '<SOW>uujou') ('入場', ['ny', 'u', 'u', 'j', 'o', 'u'], [32, 6, 6, 26, 8, 6], [1968, 1404])
# ('02081', 'mougokeN') ('兵庫県', ['hy', 'o', 'u', 'g', 'o', 'k', 'e', 'N'], [25, 8, 6, 22, 8, 27, 7, 14], [2174, 953, 905])
# ('02146', 'bamu') ('ブーム', ['b', 'u:', 'm', 'u'], [16, 11, 29, 6], [196, 265, 206])
# ('02179', 'sapa:') ('スーパー', ['s', 'u:', 'p', 'a:'], [37, 11, 33, 9], [168, 265, 191, 265])
# ('02189', 'maQkateN') ('百貨店', ['hy', 'a', 'Q', 'k', 'a', 't', 'e', 'N'], [25, 4, 15, 27, 4, 39, 7, 14], [2100, 535, 1858])
# ('02196', 'chuusi') ('入試', ['ny', 'u', 'u', 's', 'i'], [32, 6, 6, 37, 5], [1968, 1181])
# ('02204', 'raru') ('ルール', ['r', 'u:', 'r', 'u'], [35, 11, 35, 6], [214, 265, 214])
# ('02220', '<SOW>uugaku') ('入学', ['ny', 'u', 'u', 'g', 'a', 'k', 'u'], [32, 6, 6, 22, 4, 27, 6], [1968, 610])
# ('02229', '<SOW>uusatu') ('入札', ['ny', 'u', 'u', 's', 'a', 't', 'u'], [32, 6, 6, 37, 4, 39, 6], [1968, 1118])
# ('02264', 'rato') ('ルート', ['r', 'u:', 't', 'o'], [35, 11, 39, 8], [214, 265, 182])
# ('02346', 'iNtaia') ('インタビュー', ['i', 'N', 't', 'a', 'by', 'u:'], [5, 14, 39, 4, 17, 11], [150, 221, 174, 193, 237, 265])
# ('02714', 'rikurato') ('リクルート', ['r', 'i', 'k', 'u', 'r', 'u:', 't', 'o'], [35, 5, 27, 6, 35, 11, 39, 8], [213, 158, 214, 265, 182])
# ('02780', 'chuusya') ('入社', ['ny', 'u', 'u', 'sy', 'a'], [32, 6, 6, 38, 4], [1968, 1226])
# ('02786', 'moumeN') ('表面', ['hy', 'o', 'u', 'm', 'e', 'N'], [25, 8, 6, 29, 7, 14], [2102, 2320])
# ('02787', 'mouroNka') ('評論家', ['hy', 'o', 'u', 'r', 'o', 'N', 'k', 'a'], [25, 8, 6, 35, 8, 14, 27, 4], [2105, 2512, 531])
# ('02862', 'mougikai') ('評議会', ['hy', 'o', 'u', 'g', 'i', 'k', 'a', 'i'], [25, 8, 6, 22, 5, 27, 4, 5], [2105, 733, 559])
# ('03085', 'pera') ('ペルー', ['p', 'e', 'r', 'u:'], [33, 7, 35, 11], [200, 214, 265])
# ('03202', '<SOW>uusyu') ('入手', ['ny', 'u', 'u', 'sy', 'u'], [32, 6, 6, 38, 6], [1968, 1247])
# ('03240', 'siiou') ('指標', ['s', 'i', 'hy', 'o', 'u'], [37, 5, 25, 8, 6], [1170, 2107])
# ('03350', 'mmdo') ('ムード', ['m', 'u:', 'd', 'o'], [29, 11, 19, 8], [206, 265, 183])
# ('03393', 'rikuratojikeN') ('リクルート事件', ['r', 'i', 'k', 'u', 'r', 'u:', 't', 'o', 'j', 'i', 'k', 'e', 'N'], [35, 5, 27, 6, 35, 11, 39, 8, 26, 5, 27, 7, 14], [213, 158, 214, 265, 182, 1198, 899])
# ('03413', 'toumouritu') ('投票率', ['t', 'o', 'u', 'hy', 'o', 'u', 'r', 'i', 't', 'u'], [39, 8, 6, 25, 8, 6, 35, 5, 39, 6], [1886, 2104, 1661])
# ('03421', 'makumaN') ('百万', ['hy', 'a', 'k', 'u', 'm', 'a', 'N'], [25, 4, 27, 6, 29, 4, 14], [2100, 2290])
# ('03440', 'tokuiou') ('得票', ['t', 'o', 'k', 'u', 'hy', 'o', 'u'], [39, 8, 27, 6, 25, 8, 6], [1934, 2104])
# ('03536', 'moujuN') ('標準', ['hy', 'o', 'u', 'j', 'u', 'N'], [25, 8, 6, 26, 6, 14], [2107, 1324])
# ('03661', 'kadeta:') ('クーデター', ['k', 'u:', 'd', 'e', 't', 'a:'], [27, 11, 19, 7, 39, 9], [158, 265, 181, 174, 265])
# ('03731', '<SOW>uukoku') ('入国', ['ny', 'u', 'u', 'k', 'o', 'k', 'u'], [32, 6, 6, 27, 8, 27, 6], [1968, 1045])
# ('03759', 'deia') ('デビュー', ['d', 'e', 'by', 'u:'], [19, 7, 17, 11], [181, 193, 237, 265])
# ('03810', 'kaiiou') ('開票', ['k', 'a', 'i', 'hy', 'o', 'u'], [27, 4, 5, 25, 8, 6], [571, 2104])
# ('03909', 'yygosurabia') ('ユーゴスラビア', ['y', 'u:', 'g', 'o', 's', 'u', 'r', 'a', 'b', 'i', 'a'], [42, 11, 22, 8, 37, 6, 35, 4, 16, 5, 4], [210, 265, 163, 168, 212, 193, 149])
# ('03953', 'siNchuu') ('侵入', ['s', 'i', 'N', 'ny', 'u', 'u'], [37, 5, 14, 32, 6, 6], [1432, 1968])
# ('04069', 'moubaN') ('評判', ['hy', 'o', 'u', 'b', 'a', 'N'], [25, 8, 6, 16, 4, 14], [2105, 2046])
# ('04116', 'totuauu') ('突入', ['t', 'o', 't', 'u', 'ny', 'u', 'u'], [39, 8, 39, 6, 32, 6, 6], [1943, 1968])
# ('04128', 'yygo') ('ユーゴ', ['y', 'u:', 'g', 'o'], [42, 11, 22, 8], [210, 265, 163])
# ('04183', 'uaNma:') ('ミャンマー', ['my', 'a', 'N', 'm', 'a:'], [30, 4, 14, 29, 9], [205, 235, 221, 204, 265])
# ('04289', 'aaji:raNdo') ('ニュージーランド', ['ny', 'u:', 'j', 'i:', 'r', 'a', 'N', 'd', 'o'], [32, 11, 26, 10, 35, 4, 14, 19, 8], [185, 237, 265, 167, 265, 212, 221, 183])
# ('04359', 'soumou') ('総評', ['s', 'o', 'u', 'hy', 'o', 'u'], [37, 8, 6, 25, 8, 6], [1629, 2105])
# ('04371', 'moudou') ('平等', ['by', 'o', 'u', 'd', 'o', 'u'], [17, 8, 6, 19, 8, 6], [2173, 1909])
# ('04480', 'kokumiNtoumou') ('国民投票', ['k', 'o', 'k', 'u', 'm', 'i', 'N', 't', 'o', 'u', 'hy', 'o', 'u'], [27, 8, 27, 6, 29, 5, 14, 39, 8, 6, 25, 8, 6], [1045, 2302, 1886, 2104])
# ('04581', '<SOW>uusyou') ('入賞', ['ny', 'u', 'u', 'sy', 'o', 'u'], [32, 6, 6, 38, 8, 6], [1968, 1389])
# ('04605', 'eou') ('明', ['my', 'o', 'u'], [30, 8, 6], [2312])
# ('04686', 'saaouiN') ('作業員', ['s', 'a', 'gy', 'o', 'u', 'i', 'N'], [37, 4, 23, 8, 6, 5, 14], [1107, 806, 435])
# ('04703', '<SOW>uukyo') ('入居', ['ny', 'u', 'u', 'ky', 'o'], [32, 6, 6, 28, 8], [1968, 768])
# ('04805', 'ryuuuuu') ('流入', ['ry', 'u', 'u', 'ny', 'u', 'u'], [36, 6, 6, 32, 6, 6], [2434, 1968])
# ('04853', 'purowasa:') ('プロデューサー', ['p', 'u', 'r', 'o', 'dy', 'u:', 's', 'a:'], [33, 6, 35, 8, 20, 11, 37, 9], [197, 216, 181, 237, 265, 164, 265])
# ('04950', 'mou') ('評', ['hy', 'o', 'u'], [25, 8, 6], [2105])
# ('05021', 'doiou') ('土俵', ['d', 'o', 'hy', 'o', 'u'], [19, 8, 25, 8, 6], [1877, 2103])
# ('05066', 'paru') ('プール', ['p', 'u:', 'r', 'u'], [33, 11, 35, 6], [197, 265, 214])
# ('05114', 'minamataiou') ('水俣病', ['m', 'i', 'n', 'a', 'm', 'a', 't', 'a', 'by', 'o', 'u'], [29, 5, 31, 4, 29, 4, 39, 4, 17, 8, 6], [1465, 2532, 2110])
# ('05129', 'bosuniaheruaegobina') ('ボスニアヘルツェゴビナ', ['b', 'o', 's', 'u', 'n', 'i', 'a', 'h', 'e', 'r', 'u', 'ty', 'e', 'g', 'o', 'b', 'i', 'n', 'a'], [16, 8, 37, 6, 31, 5, 4, 24, 7, 35, 6, 40, 7, 22, 8, 16, 5, 31, 4], [202, 168, 185, 149, 198, 214, 178, 232, 163, 193, 184])
# ('05143', 'koNkaru') ('コンクール', ['k', 'o', 'N', 'k', 'u:', 'r', 'u'], [27, 8, 14, 27, 11, 35, 6], [162, 221, 158, 265, 214])
# ('05179', 'kiauu') ('記入', ['k', 'i', 'ny', 'u', 'u'], [27, 5, 32, 6, 6], [700, 1968])
# ('05181', 'ramania') ('ルーマニア', ['r', 'u:', 'm', 'a', 'n', 'i', 'a'], [35, 11, 29, 4, 31, 5, 4], [214, 265, 204, 185, 149])
# ('05223', 'gyuuchuu') ('牛乳', ['gy', 'u', 'u', 'ny', 'u', 'u'], [23, 6, 6, 32, 6, 6], [765, 1969])
# ('05231', 'nouchuu') ('納入', ['n', 'o', 'u', 'ny', 'u', 'u'], [31, 8, 6, 32, 6, 6], [1983, 1968])
# ('05350', '<SOW>uuryoku') ('入力', ['ny', 'u', 'u', 'ry', 'o', 'k', 'u'], [32, 6, 6, 36, 8, 27, 6], [1968, 2458])
# ('05458', 'mousyou') ('表彰', ['hy', 'o', 'u', 'sy', 'o', 'u'], [25, 8, 6, 38, 8, 6], [2102, 1385])
# ('05469', 'rikuratokosumosu') ('リクルートコスモス', ['r', 'i', 'k', 'u', 'r', 'u:', 't', 'o', 'k', 'o', 's', 'u', 'm', 'o', 's', 'u'], [35, 5, 27, 6, 35, 11, 39, 8, 27, 8, 37, 6, 29, 8, 37, 6], [213, 158, 214, 265, 182, 162, 168, 208, 168])
# ('05526', 'koumou') ('好評', ['k', 'o', 'u', 'hy', 'o', 'u'], [27, 8, 6, 25, 8, 6], [984, 2105])
# ('05645', 'sianaku') ('シアヌーク', ['s', 'i', 'a', 'n', 'u:', 'k', 'u'], [37, 5, 4, 31, 11, 27, 6], [166, 149, 186, 265, 158])
# ('05672', 'yuchuuhiN') ('輸入品', ['y', 'u', 'ny', 'u', 'u', 'h', 'i', 'N'], [42, 6, 32, 6, 6, 24, 5, 14], [2352, 1968, 2113])
# ('05850', 'yusyutuchuu') ('輸出入', ['y', 'u', 'sy', 'u', 't', 'u', 'ny', 'u', 'u'], [42, 6, 38, 6, 39, 6, 32, 6, 6], [2352, 1310, 1968])
# ('05916', '<SOW>uukaku') ('入閣', ['ny', 'u', 'u', 'k', 'a', 'k', 'u'], [32, 6, 6, 27, 4, 27, 6], [1968, 605])
# ('06075', 'daiiousitumoN') ('代表質問', ['d', 'a', 'i', 'hy', 'o', 'u', 's', 'i', 't', 'u', 'm', 'o', 'N'], [19, 4, 5, 25, 8, 6, 37, 5, 39, 6, 29, 8, 14], [1697, 2102, 1222, 2335])
# ('06086', 'chuusyoku') ('入植', ['ny', 'u', 'u', 'sy', 'o', 'k', 'u'], [32, 6, 6, 38, 8, 27, 6], [1968, 1416])
# ('06114', 'kouunikksyoN') ('コミュニケーション', ['k', 'o', 'my', 'u', 'n', 'i', 'k', 'e:', 'sy', 'o', 'N'], [27, 8, 30, 6, 31, 5, 27, 12, 38, 8, 14], [162, 205, 237, 185, 160, 265, 166, 236, 221])
# ('06163', 'maauaru') ('マニュアル', ['m', 'a', 'ny', 'u', 'a', 'r', 'u'], [29, 4, 32, 6, 4, 35, 6], [204, 185, 237, 149, 214])
# ('06189', 'ketuyuumou') ('血友病', ['k', 'e', 't', 'u', 'y', 'u', 'u', 'by', 'o', 'u'], [27, 7, 39, 6, 42, 6, 6, 17, 8, 6], [892, 2355, 2110])
# ('06195', 'juumiNtoumou') ('住民投票', ['j', 'u', 'u', 'm', 'i', 'N', 't', 'o', 'u', 'hy', 'o', 'u'], [26, 6, 6, 29, 5, 14, 39, 8, 6, 25, 8, 6], [1294, 2302, 1886, 2104])
# ('06223', 'sukejjru') ('スケジュール', ['s', 'u', 'k', 'e', 'j', 'u:', 'r', 'u'], [37, 6, 27, 7, 26, 11, 35, 6], [168, 160, 167, 237, 265, 214])
# ('06306', 'uajikaru') ('ミュージカル', ['my', 'u:', 'j', 'i', 'k', 'a', 'r', 'u'], [30, 11, 26, 5, 27, 4, 35, 6], [205, 237, 265, 167, 154, 214])
# ('06309', 'moujou') ('病状', ['by', 'o', 'u', 'j', 'o', 'u'], [17, 8, 6, 26, 8, 6], [2110, 1397])
# ('06359', 'mouteki') ('標的', ['hy', 'o', 'u', 't', 'e', 'k', 'i'], [25, 8, 6, 39, 7, 27, 5], [2107, 1844])
# ('06363', 'magunichado') ('Ｍ', ['m', 'a', 'g', 'u', 'n', 'i', 'ch', 'u:', 'd', 'o'], [29, 4, 22, 6, 31, 5, 18, 11, 19, 8], [26])
# ('06559', 'meea') ('メニュー', ['m', 'e', 'ny', 'u:'], [29, 7, 32, 11], [207, 185, 237, 265])
# ('06563', 'yyza:') ('ユーザー', ['y', 'u:', 'z', 'a:'], [42, 11, 43, 9], [210, 265, 165, 265])
# ('06671', 'saiauu') ('歳入', ['s', 'a', 'i', 'ny', 'u', 'u'], [37, 4, 5, 32, 6, 6], [1097, 1968])
# ('06677', 'sysyto') ('シュート', ['sy', 'u:', 't', 'o'], [38, 11, 39, 8], [166, 237, 265, 182])
# ('06764', 'aaku') ('逆', ['gy', 'a', 'k', 'u'], [23, 4, 27, 6], [741])
# ('06847', 'mouroN') ('評論', ['hy', 'o', 'u', 'r', 'o', 'N'], [25, 8, 6, 35, 8, 14], [2105, 2512])
# ('06876', '<SOW>uukai') ('入会', ['ny', 'u', 'u', 'k', 'a', 'i'], [32, 6, 6, 27, 4, 5], [1968, 559])
# ('06893', '<SOW>uusyo') ('入所', ['ny', 'u', 'u', 'sy', 'o'], [32, 6, 6, 38, 8], [1968, 1329])
# ('06906', 'hoNuou') ('本名', ['h', 'o', 'N', 'my', 'o', 'u'], [24, 8, 14, 30, 8, 6], [2270, 2310])
# ('06936', 'mousuru') ('表する', ['hy', 'o', 'u', 's', 'u', 'r', 'u'], [25, 8, 6, 37, 6, 35, 6], [2102, 85, 131])
# ('06950', 'kyousouauusatu') ('競争入札', ['ky', 'o', 'u', 's', 'o', 'u', 'ny', 'u', 'u', 's', 'a', 't', 'u'], [28, 8, 6, 37, 8, 6, 32, 6, 6, 37, 4, 39, 6], [801, 1604, 1968, 1118])
# ('06998', 'aaderi:') ('ニューデリー', ['ny', 'u:', 'd', 'e', 'r', 'i:'], [32, 11, 19, 7, 35, 10], [185, 237, 265, 181, 213, 265])
# ('07102', 'jiiou') ('辞表', ['j', 'i', 'hy', 'o', 'u'], [26, 5, 25, 8, 6], [1205, 2102])
# ('07144', 'moukou') ('標高', ['hy', 'o', 'u', 'k', 'o', 'u'], [25, 8, 6, 27, 8, 6], [2107, 1012])
# ('07174', 'yymoa') ('ユーモア', ['y', 'u:', 'm', 'o', 'a'], [42, 11, 29, 8, 4], [210, 265, 208, 149])
# ('07224', 'hatumou') ('発病', ['h', 'a', 't', 'u', 'by', 'o', 'u'], [24, 4, 39, 6, 17, 8, 6], [2033, 2110])
# ('07237', '<SOW>uumoN') ('入門', ['ny', 'u', 'u', 'm', 'o', 'N'], [32, 6, 6, 29, 8, 14], [1968, 2333])
# ('07249', 'chuuchuu') ('注入', ['ch', 'u', 'u', 'ny', 'u', 'u'], [18, 6, 6, 32, 6, 6], [1767, 1968])
# ('07292', 'sitiiaku') ('七百', ['s', 'i', 't', 'i', 'hy', 'a', 'k', 'u'], [37, 5, 39, 5, 25, 4, 27, 6], [1213, 2100])
# ('07360', '<SOW>uukou') ('入港', ['ny', 'u', 'u', 'k', 'o', 'u'], [32, 6, 6, 27, 8, 6], [1968, 1019])
# ('07476', 'kkburu') ('ケーブル', ['k', 'e:', 'b', 'u', 'r', 'u'], [27, 12, 16, 6, 35, 6], [160, 265, 196, 214])
# ('07510', 'isiiouji') ('意思表示', ['i', 's', 'i', 'hy', 'o', 'u', 'j', 'i'], [5, 37, 5, 25, 8, 6, 26, 5], [417, 1169, 2102, 1190])
# ('07513', 'chuudaN') ('入団', ['ny', 'u', 'u', 'd', 'a', 'N'], [32, 6, 6, 19, 4, 14], [1968, 1731])
# ('07529', 'daiioutorisimariyaku') ('代表取締役', ['d', 'a', 'i', 'hy', 'o', 'u', 't', 'o', 'r', 'i', 's', 'i', 'm', 'a', 'r', 'i', 'y', 'a', 'k', 'u'], [19, 4, 5, 25, 8, 6, 39, 8, 35, 5, 37, 5, 29, 4, 35, 5, 42, 4, 27, 6], [1697, 2102, 1251, 1841, 2341])
# ('07679', 'mousya') ('描写', ['by', 'o', 'u', 'sy', 'a'], [17, 8, 6, 38, 4], [2111, 1225])
# ('07725', 'hiiou') ('批評', ['h', 'i', 'hy', 'o', 'u'], [24, 5, 25, 8, 6], [2071, 2105])
# ('07752', 'satu') ('スーツ', ['s', 'u:', 't', 'u'], [37, 11, 39, 6], [168, 265, 178])
# ('07755', 'mouki') ('表記', ['hy', 'o', 'u', 'k', 'i'], [25, 8, 6, 27, 5], [2102, 700])
# ('07757', 'hireidaiiousei') ('比例代表制', ['h', 'i', 'r', 'e', 'i', 'd', 'a', 'i', 'hy', 'o', 'u', 's', 'e', 'i'], [24, 5, 35, 7, 5, 19, 4, 5, 25, 8, 6, 37, 7, 5], [2067, 2476, 1697, 2102, 1495])
# ('07777', 'chari:da:') ('ニューリーダー', ['ny', 'u:', 'r', 'i:', 'd', 'a:'], [32, 11, 35, 10, 19, 9], [185, 237, 265, 213, 265, 175, 265])
# ('07844', 'touaoumou') ('糖尿病', ['t', 'o', 'u', 'ny', 'o', 'u', 'by', 'o', 'u'], [39, 8, 6, 32, 8, 6, 17, 8, 6], [1914, 1970, 2110])
# ('07923', 'roNsyou') ('論評', ['r', 'o', 'N', 'py', 'o', 'u'], [35, 8, 14, 34, 8, 6], [2512, 2105])
# ('07948', 'daiiousaku') ('代表作', ['d', 'a', 'i', 'hy', 'o', 'u', 's', 'a', 'k', 'u'], [19, 4, 5, 25, 8, 6, 37, 4, 27, 6], [1697, 2102, 1107])
# ('08161', 'mutoumou') ('無投票', ['m', 'u', 't', 'o', 'u', 'hy', 'o', 'u'], [29, 6, 39, 8, 6, 25, 8, 6], [2306, 1886, 2104])
# ('08179', 'mo:aaruto') ('モーツァルト', ['m', 'o:', 'ty', 'a', 'r', 'u', 't', 'o'], [29, 13, 40, 4, 35, 6, 39, 8], [208, 265, 178, 227, 214, 182])
# ('08195', 'tuusyoudaiioubu') ('通商代表部', ['t', 'u', 'u', 'sy', 'o', 'u', 'd', 'a', 'i', 'hy', 'o', 'u', 'b', 'u'], [39, 6, 6, 38, 8, 6, 19, 4, 5, 25, 8, 6, 16, 6], [1814, 1366, 1697, 2102, 2145])
# ('08234', 'yyro') ('ユーロ', ['y', 'u:', 'r', 'o'], [42, 11, 35, 8], [210, 265, 216])
# ('08263', 'koNchuu') ('混入', ['k', 'o', 'N', 'ny', 'u', 'u'], [27, 8, 14, 32, 6, 6], [1060, 1968])
# ('08312', 'uuNheN') ('ミュンヘン', ['my', 'u', 'N', 'h', 'e', 'N'], [30, 6, 14, 24, 7, 14], [205, 237, 221, 198, 221])
# ('08316', 'jiNuaku') ('人脈', ['j', 'i', 'N', 'my', 'a', 'k', 'u'], [26, 5, 14, 30, 4, 27, 6], [1454, 2300])
# ('08351', 'sapa:koNsyata:') ('スーパーコンピューター', ['s', 'u:', 'p', 'a:', 'k', 'o', 'N', 'py', 'u:', 't', 'a:'], [37, 11, 33, 9, 27, 8, 14, 34, 11, 39, 9], [168, 265, 191, 265, 162, 221, 194, 237, 265, 174, 265])
# ('08396', 'chchN') ('チェーン', ['ch', 'e:', 'N'], [18, 12, 14], [176, 232, 265, 221])
# ('08415', 'magunichado') ('マグニチュード', ['m', 'a', 'g', 'u', 'n', 'i', 'ch', 'u:', 'd', 'o'], [29, 4, 22, 6, 31, 5, 18, 11, 19, 8], [204, 159, 185, 176, 237, 265, 183])
# ('08507', 'makutoobaN') ('１１０番', ['hy', 'a', 'k', 'u', 't', 'o', 'o', 'b', 'a', 'N'], [25, 4, 27, 6, 39, 8, 8, 16, 4, 14], [5, 5, 4, 2064])
# ('08627', 'daburyjeitio:') ('ＷＨＯ', ['d', 'a', 'b', 'u', 'ry', 'u:', 'e', 'i', 't', 'i', 'o:'], [19, 4, 16, 6, 36, 11, 7, 5, 39, 5, 13], [36, 21, 28])
# ('08806', 'kabaru') ('カブール', ['k', 'a', 'b', 'u:', 'r', 'u'], [27, 4, 16, 11, 35, 6], [154, 196, 265, 214])
# ('08832', '<SOW>uuyoku') ('入浴', ['ny', 'u', 'u', 'y', 'o', 'k', 'u'], [32, 6, 6, 42, 8, 27, 6], [1968, 2399])
# ('08857', 'jjsu') ('ジュース', ['j', 'u:', 's', 'u'], [26, 11, 37, 6], [167, 237, 265, 168])
# ('08883', 'mousuru') ('評する', ['hy', 'o', 'u', 's', 'u', 'r', 'u'], [25, 8, 6, 37, 6, 35, 6], [2105, 85, 131])
# ('08884', 'taba') ('タブー', ['t', 'a', 'b', 'u:'], [39, 4, 16, 11], [174, 196, 265])
# ('08925', '<SOW>uujoukeN') ('入場券', ['ny', 'u', 'u', 'j', 'o', 'u', 'k', 'e', 'N'], [32, 6, 6, 26, 8, 6, 27, 7, 14], [1968, 1404, 901])
# ('08969', 'beQsyou') ('別表', ['b', 'e', 'Q', 'py', 'o', 'u'], [16, 7, 15, 34, 8, 6], [2189, 2102])
# ('08974', 'mousyou') ('病床', ['by', 'o', 'u', 'sy', 'o', 'u'], [17, 8, 6, 38, 8, 6], [2110, 1348])
# ('08996', 'dou') ('秒', ['by', 'o', 'u'], [17, 8, 6], [2109])
# ('09028', 'mousitu') ('病室', ['by', 'o', 'u', 's', 'i', 't', 'u'], [17, 8, 6, 37, 5, 39, 6], [2110, 1216])
# ('09041', 'beirato') ('ベイルート', ['b', 'e', 'i', 'r', 'u:', 't', 'o'], [16, 7, 5, 35, 11, 39, 8], [199, 150, 214, 265, 182])
# ('09046', 'kyouchoukaiauu') ('協調介入', ['ky', 'o', 'u', 'ch', 'o', 'u', 'k', 'a', 'i', 'ny', 'u', 'u'], [28, 8, 6, 18, 8, 6, 27, 4, 5, 32, 6, 6], [785, 1799, 556, 1968])
# ('09088', 'kuararuNparu') ('クアラルンプール', ['k', 'u', 'a', 'r', 'a', 'r', 'u', 'N', 'p', 'u:', 'r', 'u'], [27, 6, 4, 35, 4, 35, 6, 14, 33, 11, 35, 6], [158, 149, 212, 214, 221, 197, 265, 214])
# ('09097', '<SOW>uuseN') ('入選', ['ny', 'u', 'u', 's', 'e', 'N'], [32, 6, 6, 37, 7, 14], [1968, 1576])
# ('09105', 'teiiou') ('定評', ['t', 'e', 'i', 'hy', 'o', 'u'], [39, 7, 5, 25, 8, 6], [1825, 2105])
# ('09170', 'moutou') ('病棟', ['by', 'o', 'u', 't', 'o', 'u'], [17, 8, 6, 39, 8, 6], [2110, 1904])
# ('09188', 'raburu') ('ルーブル', ['r', 'u:', 'b', 'u', 'r', 'u'], [35, 11, 16, 6, 35, 6], [214, 265, 196, 214])
# ('09277', 'seifudaiiou') ('政府代表', ['s', 'e', 'i', 'f', 'u', 'd', 'a', 'i', 'hy', 'o', 'u'], [37, 7, 5, 21, 6, 19, 4, 5, 25, 8, 6], [1501, 2126, 1697, 2102])
# ('09412', 'sapu') ('スープ', ['s', 'u:', 'p', 'u'], [37, 11, 33, 6], [168, 265, 197])
# ('09458', 'itiraNiou') ('一覧表', ['i', 't', 'i', 'r', 'a', 'N', 'hy', 'o', 'u'], [5, 39, 5, 35, 4, 14, 25, 8, 6], [425, 2415, 2102])
# ('09537', 'sokujitukaiiou') ('即日開票', ['s', 'o', 'k', 'u', 'j', 'i', 't', 'u', 'k', 'a', 'i', 'hy', 'o', 'u'], [37, 8, 27, 6, 26, 5, 39, 6, 27, 4, 5, 25, 8, 6], [1645, 1967, 571, 2104])
# ('09544', 'masutoN') ('ヒューストン', ['hy', 'u:', 's', 'u', 't', 'o', 'N'], [25, 11, 37, 6, 39, 8, 14], [192, 237, 265, 168, 182, 221])
# ('09620', 'o:kk') ('ＯＫ', ['o:', 'k', 'e:'], [13, 27, 12], [28, 24])
# ('09633', 'aakufuu') ('逆風', ['gy', 'a', 'k', 'u', 'f', 'u', 'u'], [23, 4, 27, 6, 21, 6, 6], [741, 2148])
# ('09702', 'haQketumou') ('白血病', ['h', 'a', 'Q', 'k', 'e', 't', 'u', 'by', 'o', 'u'], [24, 4, 15, 27, 7, 39, 6, 17, 8, 6], [2014, 892, 2110])
# ('09800', 'siNchuu') ('新入', ['s', 'i', 'N', 'ny', 'u', 'u'], [37, 5, 14, 32, 6, 6], [1449, 1968])
# ('09837', 'sougoumouiN') ('総合病院', ['s', 'o', 'u', 'g', 'o', 'u', 'by', 'o', 'u', 'i', 'N'], [37, 8, 6, 22, 8, 6, 17, 8, 6, 5, 14], [1629, 1036, 2110, 436])
# ('10123', 'sukkto') ('スケート', ['s', 'u', 'k', 'e:', 't', 'o'], [37, 6, 27, 12, 39, 8], [168, 160, 265, 182])
# ('10153', 'mousyousiki') ('表彰式', ['hy', 'o', 'u', 'sy', 'o', 'u', 's', 'i', 'k', 'i'], [25, 8, 6, 38, 8, 6, 37, 5, 27, 5], [2102, 1385, 1210])
# ('10160', 'sadaN') ('スーダン', ['s', 'u:', 'd', 'a', 'N'], [37, 11, 19, 4, 14], [168, 265, 175, 221])
# ('10288', 'aoubou') ('女房', ['ny', 'o', 'u', 'b', 'o', 'u'], [32, 8, 6, 16, 8, 6], [1336, 2243])
# ('10354', 'siNzoumou') ('心臓病', ['s', 'i', 'N', 'z', 'o', 'u', 'by', 'o', 'u'], [37, 5, 14, 43, 8, 6, 17, 8, 6], [1425, 1644, 2110])
# ('10413', 'supi:dosukkto') ('スピードスケート', ['s', 'u', 'p', 'i:', 'd', 'o', 's', 'u', 'k', 'e:', 't', 'o'], [37, 6, 33, 10, 19, 8, 37, 6, 27, 12, 39, 8], [168, 194, 265, 183, 168, 160, 265, 182])
# ('10417', '<SOW>ou') ('尿', ['ny', 'o', 'u'], [32, 8, 6], [1970])
# ('10427', '<SOW>uutou') ('入党', ['ny', 'u', 'u', 't', 'o', 'u'], [32, 6, 6, 39, 8, 6], [1968, 1898])
# ('10473', 'tiiou') ('地表', ['t', 'i', 'hy', 'o', 'u'], [39, 5, 25, 8, 6], [1739, 2102])
# ('10480', 'mougiiN') ('評議員', ['hy', 'o', 'u', 'g', 'i', 'i', 'N'], [25, 8, 6, 22, 5, 5, 14], [2105, 733, 435])
# ('10544', 'deNsyou') ('伝票', ['d', 'e', 'N', 'py', 'o', 'u'], [19, 7, 14, 34, 8, 6], [1865, 2104])
# ('10649', '<SOW>uuiNkaNja') ('入院患者', ['ny', 'u', 'u', 'i', 'N', 'k', 'a', 'N', 'j', 'a'], [32, 6, 6, 5, 14, 27, 4, 14, 26, 4], [1968, 436, 645, 1229])
# ('10808', 'haauu') ('羽生', ['h', 'a', 'ny', 'u', 'u'], [24, 4, 32, 6, 6], [444, 1491])
# ('10853', 'sijoukaiauu') ('市場介入', ['s', 'i', 'j', 'o', 'u', 'k', 'a', 'i', 'ny', 'u', 'u'], [37, 5, 26, 8, 6, 27, 4, 5, 32, 6, 6], [1152, 1404, 556, 1968])
# ('10883', 'mouniN') ('病人', ['by', 'o', 'u', 'n', 'i', 'N'], [17, 8, 6, 31, 5, 14], [2110, 1454])
# ('11004', 'wukakisu') ('デュカキス', ['dy', 'u', 'k', 'a', 'k', 'i', 's', 'u'], [20, 6, 27, 4, 27, 5, 37, 6], [181, 237, 154, 156, 168])
# ('11029', 'chuukokukaNri') ('入国管理', ['ny', 'u', 'u', 'k', 'o', 'k', 'u', 'k', 'a', 'N', 'r', 'i'], [32, 6, 6, 27, 8, 27, 6, 27, 4, 14, 35, 5], [1968, 1045, 662, 2422])
# ('11056', 'naNmou') ('難病', ['n', 'a', 'N', 'by', 'o', 'u'], [31, 4, 14, 17, 8, 6], [1960, 2110])
# ('11151', 'heNchuu') ('編入', ['h', 'e', 'N', 'ny', 'u', 'u'], [24, 7, 14, 32, 6, 6], [2197, 1968])
# ('11214', 'raNgaN') ('ラングーン', ['r', 'a', 'N', 'g', 'u:', 'N'], [35, 4, 14, 22, 11, 14], [212, 221, 159, 265, 221])
# ('11307', 'keQseNtoumou') ('決選投票', ['k', 'e', 'Q', 's', 'e', 'N', 't', 'o', 'u', 'hy', 'o', 'u'], [27, 7, 15, 37, 7, 14, 39, 8, 6, 25, 8, 6], [893, 1576, 1886, 2104])
# ('11369', 'syosiNioumeieNzetu') ('所信表明演説', ['sy', 'o', 's', 'i', 'N', 'hy', 'o', 'u', 'm', 'e', 'i', 'e', 'N', 'z', 'e', 't', 'u'], [38, 8, 37, 5, 14, 25, 8, 6, 29, 7, 5, 7, 14, 43, 7, 39, 6], [1329, 1433, 2102, 2312, 485, 1547])
# ('11460', '<SOW>uugakusiki') ('入学式', ['ny', 'u', 'u', 'g', 'a', 'k', 'u', 's', 'i', 'k', 'i'], [32, 6, 6, 22, 4, 27, 6, 37, 5, 27, 5], [1968, 610, 1210])
# ('11469', 'zeNkokujiNmiNdaiioutaikai') ('全国人民代表大会', ['z', 'e', 'N', 'k', 'o', 'k', 'u', 'j', 'i', 'N', 'm', 'i', 'N', 'd', 'a', 'i', 'hy', 'o', 'u', 't', 'a', 'i', 'k', 'a', 'i'], [43, 7, 14, 27, 8, 27, 6, 26, 5, 14, 29, 5, 14, 19, 4, 5, 25, 8, 6, 39, 4, 5, 27, 4, 5], [1580, 1045, 1454, 2302, 1697, 2102, 1696, 559])
# ('11484', 'fumoudou') ('不平等', ['f', 'u', 'by', 'o', 'u', 'd', 'o', 'u'], [21, 6, 17, 8, 6, 19, 8, 6], [2120, 2173, 1909])
# ('11526', 'sukkru') ('スケール', ['s', 'u', 'k', 'e:', 'r', 'u'], [37, 6, 27, 12, 35, 6], [168, 160, 265, 214])
# ('11541', 'mouryuu') ('漂流', ['hy', 'o', 'u', 'ry', 'u', 'u'], [25, 8, 6, 36, 6, 6], [2106, 2434])
# ('11619', 'chuukaN') ('入管', ['ny', 'u', 'u', 'k', 'a', 'N'], [32, 6, 6, 27, 4, 14], [1968, 662])
# ('11687', 'moukasoN') ('評価損', ['hy', 'o', 'u', 'k', 'a', 's', 'o', 'N'], [25, 8, 6, 27, 4, 37, 8, 14], [2105, 524, 1666])
# ('11741', 'nousaaou') ('農作業', ['n', 'o', 'u', 's', 'a', 'gy', 'o', 'u'], [31, 8, 6, 37, 4, 23, 8, 6], [1986, 1107, 806])
# ('11913', 'yyta:N') ('Ｕターン', ['y', 'u:', 't', 'a:', 'N'], [42, 11, 39, 9, 14], [34, 174, 265, 221])
# ('12071', 'siuure:syoN') ('シミュレーション', ['s', 'i', 'my', 'u', 'r', 'e:', 'sy', 'o', 'N'], [37, 5, 30, 6, 35, 12, 38, 8, 14], [166, 205, 237, 215, 265, 166, 236, 221])
# ('12138', '<SOW>uuyouji') ('乳幼児', ['ny', 'u', 'u', 'y', 'o', 'u', 'j', 'i'], [32, 6, 6, 42, 8, 6, 26, 5], [1969, 2375, 1197])
# ('12160', 'baNkaba:') ('バンクーバー', ['b', 'a', 'N', 'k', 'u:', 'b', 'a:'], [16, 4, 14, 27, 11, 16, 9], [190, 221, 158, 265, 190, 265])
# ('12188', 'kkki') ('ケーキ', ['k', 'e:', 'k', 'i'], [27, 12, 27, 5], [160, 265, 156])
# ('12201', 'moumei') ('病名', ['by', 'o', 'u', 'm', 'e', 'i'], [17, 8, 6, 29, 7, 5], [2110, 2310])
# ('12232', 'ratu') ('ルーツ', ['r', 'u:', 't', 'u'], [35, 11, 39, 6], [214, 265, 178])
# ('12271', 'seijiNiou') ('成人病', ['s', 'e', 'i', 'j', 'i', 'N', 'by', 'o', 'u'], [37, 7, 5, 26, 5, 14, 17, 8, 6], [1492, 1454, 2110])
# ('12316', 'kouunike') ('コミュニケ', ['k', 'o', 'my', 'u', 'n', 'i', 'k', 'e'], [27, 8, 30, 6, 31, 5, 27, 7], [162, 205, 237, 185, 160])
# ('12354', '<SOW>uukiN') ('入金', ['ny', 'u', 'u', 'k', 'i', 'N'], [32, 6, 6, 27, 5, 14], [1968, 816])
# ('12429', 'haNchuu') ('搬入', ['h', 'a', 'N', 'ny', 'u', 'u'], [24, 4, 14, 32, 6, 6], [2057, 1968])
# ('12552', 'uairu') ('ファイル', ['f', 'a', 'i', 'r', 'u'], [21, 4, 5, 35, 6], [195, 227, 150, 214])
# ('12579', 'moukei') ('表敬', ['hy', 'o', 'u', 'k', 'e', 'i'], [25, 8, 6, 27, 7, 5], [2102, 869])
# ('12607', 'juumiNiou') ('住民票', ['j', 'u', 'u', 'm', 'i', 'N', 'hy', 'o', 'u'], [26, 6, 6, 29, 5, 14, 25, 8, 6], [1294, 2302, 2104])
# ('12701', 'berarasi') ('ベラルーシ', ['b', 'e', 'r', 'a', 'r', 'u:', 's', 'i'], [16, 7, 35, 4, 35, 11, 37, 5], [199, 212, 214, 265, 166])
# ('12727', '<SOW>uueN') ('入園', ['ny', 'u', 'u', 'e', 'N'], [32, 6, 6, 7, 14], [1968, 479])
# ('12749', 'chamedia') ('ニューメディア', ['ny', 'u:', 'm', 'e', 'd', 'i', 'a'], [32, 11, 29, 7, 19, 5, 4], [185, 237, 265, 207, 181, 228, 149])
# ('12750', '<SOW>uuji') ('乳児', ['ny', 'u', 'u', 'j', 'i'], [32, 6, 6, 26, 5], [1969, 1197])
# ('12802', 'chakuouji') ('若王子', ['ny', 'a', 'k', 'u', 'o', 'u', 'j', 'i'], [32, 4, 27, 6, 8, 6, 26, 5], [1244, 489, 1144])
# ('12847', '<SOW>atauN') ('ニュータウン', ['ny', 'u:', 't', 'a', 'u', 'N'], [32, 11, 39, 4, 6, 14], [185, 237, 265, 174, 151, 221])
# ('12860', 'reaura:') ('レギュラー', ['r', 'e', 'gy', 'u', 'r', 'a:'], [35, 7, 23, 6, 35, 9], [215, 157, 237, 212, 265])
# ('12871', 'boauu') ('母乳', ['b', 'o', 'ny', 'u', 'u'], [16, 8, 32, 6, 6], [2207, 1969])
# ('13015', 'mouhoN') ('標本', ['hy', 'o', 'u', 'h', 'o', 'N'], [25, 8, 6, 24, 8, 14], [2107, 2270])
# ('13046', 'kko:') ('ＫＯ', ['k', 'e:', 'o:'], [27, 12, 13], [24, 28])
# ('13108', 'raNuaku') ('乱脈', ['r', 'a', 'N', 'my', 'a', 'k', 'u'], [35, 4, 14, 30, 4, 27, 6], [2413, 2300])
# ('13213', 'aisuhoQkk') ('アイスホッケー', ['a', 'i', 's', 'u', 'h', 'o', 'Q', 'k', 'e:'], [4, 5, 37, 6, 24, 8, 15, 27, 12], [149, 150, 168, 201, 234, 160, 265])
# ('13229', 'uajisyaN') ('ミュージシャン', ['my', 'u:', 'j', 'i', 'sy', 'a', 'N'], [30, 11, 26, 5, 38, 4, 14], [205, 237, 265, 167, 166, 235, 221])
# ('13243', 'syutuchuukokukaNri') ('出入国管理', ['sy', 'u', 't', 'u', 'ny', 'u', 'u', 'k', 'o', 'k', 'u', 'k', 'a', 'N', 'r', 'i'], [38, 6, 39, 6, 32, 6, 6, 27, 8, 27, 6, 27, 4, 14, 35, 5], [1310, 1968, 1045, 662, 2422])
# ('13347', 'moudai') ('表題', ['hy', 'o', 'u', 'd', 'a', 'i'], [25, 8, 6, 19, 4, 5], [2102, 1700])
# ('13354', 'auNsaNsati:') ('アウンサンスーチー', ['a', 'u', 'N', 's', 'a', 'N', 's', 'u:', 't', 'i:'], [4, 6, 14, 37, 4, 14, 37, 11, 39, 10], [149, 151, 221, 164, 221, 168, 265, 176, 265])
# ('13359', 'mougeN') ('病原', ['by', 'o', 'u', 'g', 'e', 'N'], [17, 8, 6, 22, 7, 14], [2110, 935])
# ('13393', 'mousiki') ('標識', ['hy', 'o', 'u', 's', 'i', 'k', 'i'], [25, 8, 6, 37, 5, 27, 5], [2107, 1211])
# ('13396', 'deNseNdou') ('伝染病', ['d', 'e', 'N', 's', 'e', 'N', 'by', 'o', 'u'], [19, 7, 14, 37, 7, 14, 17, 8, 6], [1865, 1560, 2110])
# ('13446', 'siNchuusei') ('新入生', ['s', 'i', 'N', 'ny', 'u', 'u', 's', 'e', 'i'], [37, 5, 14, 32, 6, 6, 37, 7, 5], [1449, 1968, 1491])
# ('13624', 'purowasu') ('プロデュース', ['p', 'u', 'r', 'o', 'dy', 'u:', 's', 'u'], [33, 6, 35, 8, 20, 11, 37, 6], [197, 216, 181, 237, 265, 168])
# ('13625', 'rabiN') ('ルービン', ['r', 'u:', 'b', 'i', 'N'], [35, 11, 16, 5, 14], [214, 265, 193, 221])
# ('13707', 'daiiouteki') ('代表的', ['d', 'a', 'i', 'hy', 'o', 'u', 't', 'e', 'k', 'i'], [19, 4, 5, 25, 8, 6, 39, 7, 27, 5], [1697, 2102, 1844])
# ('13728', 'auaNsu') ('ニュアンス', ['ny', 'u', 'a', 'N', 's', 'u'], [32, 6, 4, 14, 37, 6], [185, 237, 149, 221, 168])
# ('13834', 'uakuhaku') ('脈拍', ['my', 'a', 'k', 'u', 'h', 'a', 'k', 'u'], [30, 4, 27, 6, 24, 4, 27, 6], [2300, 2016])
# ('13848', 'tokuiousuu') ('得票数', ['t', 'o', 'k', 'u', 'hy', 'o', 'u', 's', 'u', 'u'], [39, 8, 27, 6, 25, 8, 6, 37, 6, 6], [1934, 2104, 1481])
# ('13889', 'kouuniti:') ('コミュニティー', ['k', 'o', 'my', 'u', 'n', 'i', 't', 'i:'], [27, 8, 30, 6, 31, 5, 39, 10], [162, 205, 237, 185, 180, 228, 265])
# ('13899', 'siNchuu') ('進入', ['s', 'i', 'N', 'ny', 'u', 'u'], [37, 5, 14, 32, 6, 6], [1444, 1968])
# ('13940', 'seisiNiouiN') ('精神病院', ['s', 'e', 'i', 's', 'i', 'N', 'by', 'o', 'u', 'i', 'N'], [37, 7, 5, 37, 5, 14, 17, 8, 6, 5, 14], [1514, 1435, 2110, 436])
# ('13953', 'buNuaku') ('文脈', ['b', 'u', 'N', 'my', 'a', 'k', 'u'], [16, 6, 14, 30, 4, 27, 6], [2170, 2300])
# ('14026', 'mousu') ('評す', ['hy', 'o', 'u', 's', 'u'], [25, 8, 6, 37, 6], [2105, 85])
# ('14048', 'mouketu') ('評決', ['hy', 'o', 'u', 'k', 'e', 't', 'u'], [25, 8, 6, 27, 7, 39, 6], [2105, 893])
# ('14083', 'kkburuterebi') ('ケーブルテレビ', ['k', 'e:', 'b', 'u', 'r', 'u', 't', 'e', 'r', 'e', 'b', 'i'], [27, 12, 16, 6, 35, 6, 39, 7, 35, 7, 16, 5], [160, 265, 196, 214, 180, 215, 193])
# ('14220', 'chaja:ji:') ('ニュージャージー', ['ny', 'u:', 'j', 'a:', 'j', 'i:'], [32, 11, 26, 9, 26, 10], [185, 237, 265, 167, 235, 265, 167, 265])
# ('14345', 'auuseihiN') ('乳製品', ['ny', 'u', 'u', 's', 'e', 'i', 'h', 'i', 'N'], [32, 6, 6, 37, 7, 5, 24, 5, 14], [1969, 1515, 2113])
# ('14354', 'syouseNkyokuhireidaiiousei') ('小選挙区比例代表制', ['sy', 'o', 'u', 's', 'e', 'N', 'ky', 'o', 'k', 'u', 'h', 'i', 'r', 'e', 'i', 'd', 'a', 'i', 'hy', 'o', 'u', 's', 'e', 'i'], [38, 8, 6, 37, 7, 14, 28, 8, 27, 6, 24, 5, 35, 7, 5, 19, 4, 5, 25, 8, 6, 37, 7, 5], [1343, 1576, 771, 829, 2067, 2476, 1697, 2102, 1495])
# ('14460', 'mouchaku') ('漂着', ['hy', 'o', 'u', 'ch', 'a', 'k', 'u'], [25, 8, 6, 18, 4, 27, 6], [2106, 1758])
# ('14509', 'kara:') ('クーラー', ['k', 'u:', 'r', 'a:'], [27, 11, 35, 9], [158, 265, 212, 265])
# ('14589', 'syoumou') ('商標', ['sy', 'o', 'u', 'hy', 'o', 'u'], [38, 8, 6, 25, 8, 6], [1366, 2107])
# ('14600', 'biuou') ('微妙', ['b', 'i', 'my', 'o', 'u'], [16, 5, 30, 8, 6], [2091, 2301])
# ('14619', 'kana') ('カヌー', ['k', 'a', 'n', 'u:'], [27, 4, 31, 11], [154, 186, 265])
# ('14646', 'iiou') ('異名', ['i', 'my', 'o', 'u'], [5, 30, 8, 6], [411, 2310])
# ('14773', 'kaNmou') ('看病', ['k', 'a', 'N', 'by', 'o', 'u'], [27, 4, 14, 17, 8, 6], [641, 2110])
# ('14907', 'mouri') ('病理', ['by', 'o', 'u', 'r', 'i'], [17, 8, 6, 35, 5], [2110, 2422])
# ('14923', 'fuzaisyatoumou') ('不在者投票', ['f', 'u', 'z', 'a', 'i', 'sy', 'a', 't', 'o', 'u', 'hy', 'o', 'u'], [21, 6, 43, 4, 5, 38, 4, 39, 8, 6, 25, 8, 6], [2120, 1101, 1229, 1886, 2104])
# ('14964', 'maiiou') ('毎秒', ['m', 'a', 'i', 'by', 'o', 'u'], [29, 4, 5, 17, 8, 6], [2279, 2109])
# ('14980', 'souauu') ('挿入', ['s', 'o', 'u', 'ny', 'u', 'u'], [37, 8, 6, 32, 6, 6], [1613, 1968])
# ('15007', 'jjru') ('Ｊ', ['j', 'u:', 'r', 'u'], [26, 11, 35, 6], [23])
# ('15055', 'nndo') ('ヌード', ['n', 'u:', 'd', 'o'], [31, 11, 19, 8], [186, 265, 183])
# ('15095', 'nakaaou') ('中京', ['n', 'a', 'k', 'a', 'gy', 'o', 'u'], [31, 4, 27, 4, 23, 8, 6], [1760, 782])
# ('15117', 'uajiQku') ('ミュージック', ['my', 'u:', 'j', 'i', 'Q', 'k', 'u'], [30, 11, 26, 5, 15, 27, 6], [205, 237, 265, 167, 234, 158])
# ('15129', 'kaaou') ('家業', ['k', 'a', 'gy', 'o', 'u'], [27, 4, 23, 8, 6], [531, 806])
# ('15221', 'heikiNjuuou') ('平均寿命', ['h', 'e', 'i', 'k', 'i', 'N', 'j', 'u', 'my', 'o', 'u'], [24, 7, 5, 27, 5, 14, 26, 6, 30, 8, 6], [2173, 814, 1260, 2311])
# ('15228', 'moujuNka') ('標準化', ['hy', 'o', 'u', 'j', 'u', 'N', 'k', 'a'], [25, 8, 6, 26, 6, 14, 27, 4], [2107, 1324, 516])
# ('15366', 'toumou') ('闘病', ['t', 'o', 'u', 'by', 'o', 'u'], [39, 8, 6, 17, 8, 6], [1918, 2110])
# ('15463', 'sukaru') ('スクール', ['s', 'u', 'k', 'u:', 'r', 'u'], [37, 6, 27, 11, 35, 6], [168, 158, 265, 214])
# ('15482', 'masachaseQtu') ('マサチューセッツ', ['m', 'a', 's', 'a', 'ch', 'u:', 's', 'e', 'Q', 't', 'u'], [29, 4, 37, 4, 18, 11, 37, 7, 15, 39, 6], [204, 164, 176, 237, 265, 170, 234, 178])
# ('15508', 'koNsyata:me:ka:') ('コンピューターメーカー', ['k', 'o', 'N', 'py', 'u:', 't', 'a:', 'm', 'e:', 'k', 'a:'], [27, 8, 14, 34, 11, 39, 9, 29, 12, 27, 9], [162, 221, 194, 237, 265, 174, 265, 207, 265, 154, 265])
# ('15511', 'mougo') ('標語', ['hy', 'o', 'u', 'g', 'o'], [25, 8, 6, 22, 8], [2107, 968])
# ('15522', '<SOW>uuka') ('入荷', ['ny', 'u', 'u', 'k', 'a'], [32, 6, 6, 27, 4], [1968, 532])
# ('15544', 'burasu') ('ブルース', ['b', 'u', 'r', 'u:', 's', 'u'], [16, 6, 35, 11, 37, 6], [196, 214, 265, 168])
# ('15598', 'beNaeN') ('ベンツェン', ['b', 'e', 'N', 'ty', 'e', 'N'], [16, 7, 14, 40, 7, 14], [199, 221, 178, 232, 221])
# ('15600', '<SOW>uukaN') ('入館', ['ny', 'u', 'u', 'k', 'a', 'N'], [32, 6, 6, 27, 4, 14], [1968, 669])
# ('15613', 'paQkkji') ('パッケージ', ['p', 'a', 'Q', 'k', 'e:', 'j', 'i'], [33, 4, 15, 27, 12, 26, 5], [191, 234, 160, 265, 167])
# ('15628', 'chchNsutoa') ('チェーンストア', ['ch', 'e:', 'N', 's', 'u', 't', 'o', 'a'], [18, 12, 14, 37, 6, 39, 8, 4], [176, 232, 265, 221, 168, 182, 149])
# ('15687', 'ao') ('如', ['ny', 'o'], [32, 8], [1337])
# ('15694', 'tesaaou') ('手作業', ['t', 'e', 's', 'a', 'gy', 'o', 'u'], [39, 7, 37, 4, 23, 8, 6], [1247, 1107, 806])
# ('15796', 'jiiou') ('持病', ['j', 'i', 'by', 'o', 'u'], [26, 5, 17, 8, 6], [1201, 2110])
# ('15846', 'syoiou') ('書評', ['sy', 'o', 'hy', 'o', 'u'], [38, 8, 25, 8, 6], [1330, 2105])
# ('15869', 'auusyou') ('入省', ['ny', 'u', 'u', 'sy', 'o', 'u'], [32, 6, 6, 38, 8, 6], [1968, 1504])
# ('15901', 'posyura:') ('ポピュラー', ['p', 'o', 'py', 'u', 'r', 'a:'], [33, 8, 34, 6, 35, 9], [203, 194, 237, 212, 265])
# ('15955', 'moue') ('兵衛', ['hy', 'o', 'u', 'e'], [25, 8, 6, 7], [2174, 461])
# ('16046', 'furato') ('フルート', ['f', 'u', 'r', 'u:', 't', 'o'], [21, 6, 35, 11, 39, 8], [195, 214, 265, 182])
# ('16080', 'rikado') ('リクード', ['r', 'i', 'k', 'u:', 'd', 'o'], [35, 5, 27, 11, 19, 8], [213, 158, 265, 183])
# ('16102', 'teNchuu') ('転入', ['t', 'e', 'N', 'ny', 'u', 'u'], [39, 7, 14, 32, 6, 6], [1862, 1968])
# ('16111', 'sisyagoauu') ('四捨五入', ['s', 'i', 'sy', 'a', 'g', 'o', 'ny', 'u', 'u'], [37, 5, 38, 4, 22, 8, 32, 6, 6], [1151, 1231, 960, 1968])
# ('16125', 'haNseNiou') ('ハンセン病', ['h', 'a', 'N', 's', 'e', 'N', 'by', 'o', 'u'], [24, 4, 14, 37, 7, 14, 17, 8, 6], [189, 221, 170, 221, 2110])
# ('16140', 'hoteruchao:tani') ('ホテルニューオータニ', ['h', 'o', 't', 'e', 'r', 'u', 'ny', 'u:', 'o:', 't', 'a', 'n', 'i'], [24, 8, 39, 7, 35, 6, 32, 11, 13, 39, 4, 31, 5], [201, 180, 214, 185, 237, 265, 153, 265, 174, 185])
# ('16256', 'chabu') ('チューブ', ['ch', 'u:', 'b', 'u'], [18, 11, 16, 6], [176, 237, 265, 196])
# ('16273', 'ryuumou') ('流氷', ['ry', 'u', 'u', 'hy', 'o', 'u'], [36, 6, 6, 25, 8, 6], [2434, 2101])
# ('16410', 'mou') ('ひょう', ['hy', 'o', 'u'], [25, 8, 6], [109, 146, 68])
# ('16431', 'roujiNmouiN') ('老人病院', ['r', 'o', 'u', 'j', 'i', 'N', 'by', 'o', 'u', 'i', 'N'], [35, 8, 6, 26, 5, 14, 17, 8, 6, 5, 14], [2499, 1454, 2110, 436])
# ('16463', '<SOW>uutai') ('入隊', ['ny', 'u', 'u', 't', 'a', 'i'], [32, 6, 6, 39, 4, 5], [1968, 1692])
# ('16553', 'bura') ('ブルー', ['b', 'u', 'r', 'u:'], [16, 6, 35, 11], [196, 214, 265])
# ('16570', 'sezoNgurapu') ('セゾングループ', ['s', 'e', 'z', 'o', 'N', 'g', 'u', 'r', 'u:', 'p', 'u'], [37, 7, 43, 8, 14, 22, 6, 35, 11, 33, 6], [170, 173, 221, 159, 214, 265, 197])
# ('16648', 'toukyuumaQkateN') ('東急百貨店', ['t', 'o', 'u', 'ky', 'u', 'u', 'hy', 'a', 'Q', 'k', 'a', 't', 'e', 'N'], [39, 8, 6, 28, 6, 6, 25, 4, 15, 27, 4, 39, 7, 14], [1888, 756, 2100, 535, 1858])
# ('16668', 'koNsyata:sofuto') ('コンピューターソフト', ['k', 'o', 'N', 'py', 'u:', 't', 'a:', 's', 'o', 'f', 'u', 't', 'o'], [27, 8, 14, 34, 11, 39, 9, 37, 8, 21, 6, 39, 8], [162, 221, 194, 237, 265, 174, 265, 172, 195, 182])
# ('16678', 'siNniNtoumou') ('信任投票', ['s', 'i', 'N', 'n', 'i', 'N', 't', 'o', 'u', 'hy', 'o', 'u'], [37, 5, 14, 31, 5, 14, 39, 8, 6, 25, 8, 6], [1433, 1971, 1886, 2104])
# ('16704', 'sapa:ma:keQto') ('スーパーマーケット', ['s', 'u:', 'p', 'a:', 'm', 'a:', 'k', 'e', 'Q', 't', 'o'], [37, 11, 33, 9, 29, 9, 27, 7, 15, 39, 8], [168, 265, 191, 265, 204, 265, 160, 234, 182])
# ('16826', 'saNchuu') ('算入', ['s', 'a', 'N', 'ny', 'u', 'u'], [37, 4, 14, 32, 6, 6], [1137, 1968])
# ('16832', '<SOW>uusiN') ('入信', ['ny', 'u', 'u', 's', 'i', 'N'], [32, 6, 6, 37, 5, 14], [1968, 1433])
# ('16863', 'uajiamu') ('ミュージアム', ['my', 'u:', 'j', 'i', 'a', 'm', 'u'], [30, 11, 26, 5, 4, 29, 6], [205, 237, 265, 167, 149, 206])
# ('16874', 'suiseNchuugaku') ('推薦入学', ['s', 'u', 'i', 's', 'e', 'N', 'ny', 'u', 'u', 'g', 'a', 'k', 'u'], [37, 6, 5, 37, 7, 14, 32, 6, 6, 22, 4, 27, 6], [1472, 1577, 1968, 610])
# ('16896', 'fumou') ('不評', ['f', 'u', 'hy', 'o', 'u'], [21, 6, 25, 8, 6], [2120, 2105])
# ('16946', 'gyakuyuchuu') ('逆輸入', ['gy', 'a', 'k', 'u', 'y', 'u', 'ny', 'u', 'u'], [23, 4, 27, 6, 42, 6, 32, 6, 6], [741, 2352, 1968])
# ('16992', 'saNuaku') ('山脈', ['s', 'a', 'N', 'my', 'a', 'k', 'u'], [37, 4, 14, 30, 4, 27, 6], [1129, 2300])
# ('17084', 'sapa:suta:') ('スーパースター', ['s', 'u:', 'p', 'a:', 's', 'u', 't', 'a:'], [37, 11, 33, 9, 37, 6, 39, 9], [168, 265, 191, 265, 168, 174, 265])
# ('17192', 'sysyberuto') ('シューベルト', ['sy', 'u:', 'b', 'e', 'r', 'u', 't', 'o'], [38, 11, 16, 7, 35, 6, 39, 8], [166, 237, 265, 199, 214, 182])
# ('17287', 'mituchuukoku') ('密入国', ['m', 'i', 't', 'u', 'ny', 'u', 'u', 'k', 'o', 'k', 'u'], [29, 5, 39, 6, 32, 6, 6, 27, 8, 27, 6], [2298, 1968, 1045])
# ('17469', 'kazeiioujuN') ('課税標準', ['k', 'a', 'z', 'e', 'i', 'hy', 'o', 'u', 'j', 'u', 'N'], [27, 4, 43, 7, 5, 25, 8, 6, 26, 6, 14], [546, 1521, 2107, 1324])
# ('17478', 'syaNpa') ('シャンプー', ['sy', 'a', 'N', 'p', 'u:'], [38, 4, 14, 33, 11], [166, 235, 221, 197, 265])
# ('17480', 'pi:kk') ('ＰＫ', ['p', 'i:', 'k', 'e:'], [33, 10, 27, 12], [29, 24])
# ('17485', 'eruni:cho') ('エルニーニョ', ['e', 'r', 'u', 'n', 'i:', 'ny', 'o'], [7, 35, 6, 31, 10, 32, 8], [152, 214, 185, 265, 185, 236])
# ('17581', 'moudeN') ('票田', ['hy', 'o', 'u', 'd', 'e', 'N'], [25, 8, 6, 19, 7, 14], [2104, 1864])
# ('17609', 'yysu') ('ユース', ['y', 'u:', 's', 'u'], [42, 11, 37, 6], [210, 265, 168])
# ('17618', 'papuaaaginia') ('パプアニューギニア', ['p', 'a', 'p', 'u', 'a', 'ny', 'u:', 'g', 'i', 'n', 'i', 'a'], [33, 4, 33, 6, 4, 32, 11, 22, 5, 31, 5, 4], [191, 197, 149, 185, 237, 265, 157, 185, 149])
# ('17632', 'moubu') ('びょうぶ', ['by', 'o', 'u', 'b', 'u'], [17, 8, 6, 16, 6], [110, 146, 68, 113])
# ('17650', 'moubu') ('屏風', ['by', 'o', 'u', 'b', 'u'], [17, 8, 6, 16, 6], [2573, 2148])
# ('17667', 'makusyou') ('百姓', ['hy', 'a', 'k', 'u', 'sy', 'o', 'u'], [25, 4, 27, 6, 38, 8, 6], [2100, 1496])
# ('17758', '<SOW>azu') ('ニューズ', ['ny', 'u:', 'z', 'u'], [32, 11, 43, 6], [185, 237, 265, 169])
# ('17774', 'neNsyou') ('年表', ['n', 'e', 'N', 'py', 'o', 'u'], [31, 7, 14, 34, 8, 6], [1977, 2102])
# ('17811', 'auukou') ('入行', ['ny', 'u', 'u', 'k', 'o', 'u'], [32, 6, 6, 27, 8, 6], [1968, 987])
# ('17876', 'marurani:') ('マルルーニー', ['m', 'a', 'r', 'u', 'r', 'u:', 'n', 'i:'], [29, 4, 35, 6, 35, 11, 31, 10], [204, 214, 214, 265, 185, 265])
# ('18061', 'raNauu') ('乱入', ['r', 'a', 'N', 'ny', 'u', 'u'], [35, 4, 14, 32, 6, 6], [2413, 1968])
# ('18065', 'mougogiNkou') ('兵庫銀行', ['hy', 'o', 'u', 'g', 'o', 'g', 'i', 'N', 'k', 'o', 'u'], [25, 8, 6, 22, 8, 22, 5, 14, 27, 8, 6], [2174, 953, 828, 987])
# ('18119', 'seNchuukaN') ('先入観', ['s', 'e', 'N', 'ny', 'u', 'u', 'k', 'a', 'N'], [37, 7, 14, 32, 6, 6, 27, 4, 14], [1554, 1968, 672])
# ('18154', 'waauu') ('和牛', ['w', 'a', 'gy', 'u', 'u'], [41, 4, 23, 6, 6], [2513, 765])
# ('18193', 'isutaNbaru') ('イスタンブール', ['i', 's', 'u', 't', 'a', 'N', 'b', 'u:', 'r', 'u'], [5, 37, 6, 39, 4, 14, 16, 11, 35, 6], [150, 168, 174, 221, 196, 265, 214])
# ('18266', 'reia') ('レビュー', ['r', 'e', 'by', 'u:'], [35, 7, 17, 11], [215, 193, 237, 265])
# ('18304', 'taaou') ('他行', ['t', 'a', 'gy', 'o', 'u'], [39, 4, 23, 8, 6], [1668, 987])
# ('18437', 'kkputauN') ('ケープタウン', ['k', 'e:', 'p', 'u', 't', 'a', 'u', 'N'], [27, 12, 33, 6, 39, 4, 6, 14], [160, 265, 197, 174, 151, 221])
# ('18556', 'barawaru') ('バラデュール', ['b', 'a', 'r', 'a', 'dy', 'u:', 'r', 'u'], [16, 4, 35, 4, 20, 11, 35, 6], [190, 212, 181, 237, 265, 214])
# ('18564', 'douuakukouka') ('動脈硬化', ['d', 'o', 'u', 'my', 'a', 'k', 'u', 'k', 'o', 'u', 'k', 'a'], [19, 8, 6, 30, 4, 27, 6, 27, 8, 6, 27, 4], [1923, 2300, 1020, 516])
# ('18678', 'mousuke') ('兵輔', ['hy', 'o', 'u', 's', 'u', 'k', 'e'], [25, 8, 6, 37, 6, 27, 7], [2174, 2736])
# ('18707', 'syutuchuukoku') ('出入国', ['sy', 'u', 't', 'u', 'ny', 'u', 'u', 'k', 'o', 'k', 'u'], [38, 6, 39, 6, 32, 6, 6, 27, 8, 27, 6], [1310, 1968, 1045])
# ('18710', 'buNgeiiouroN') ('文芸評論', ['b', 'u', 'N', 'g', 'e', 'i', 'hy', 'o', 'u', 'r', 'o', 'N'], [16, 6, 14, 22, 7, 5, 25, 8, 6, 35, 8, 14], [2170, 882, 2105, 2512])
# ('18748', '<SOW>uugakusikeN') ('入学試験', ['ny', 'u', 'u', 'g', 'a', 'k', 'u', 's', 'i', 'k', 'e', 'N'], [32, 6, 6, 22, 4, 27, 6, 37, 5, 27, 7, 14], [1968, 610, 1181, 927])
# ('18758', 'mousoku') ('秒速', ['by', 'o', 'u', 's', 'o', 'k', 'u'], [17, 8, 6, 37, 8, 27, 6], [2109, 1652])
# ('18789', 'hiiouka') ('批評家', ['h', 'i', 'hy', 'o', 'u', 'k', 'a'], [24, 5, 25, 8, 6, 27, 4], [2071, 2105, 531])
# ('18931', 'mouzaNnoiQkaku') ('氷山の一角', ['hy', 'o', 'u', 'z', 'a', 'N', 'n', 'o', 'i', 'Q', 'k', 'a', 'k', 'u'], [25, 8, 6, 43, 4, 14, 31, 8, 5, 15, 27, 4, 27, 6], [2101, 1129, 105, 425, 595])
# ('18949', 'eaku') ('脈', ['my', 'a', 'k', 'u'], [30, 4, 27, 6], [2300])
# ('18969', 'chchrihi') ('チューリヒ', ['ch', 'u:', 'r', 'i', 'h', 'i'], [18, 11, 35, 5, 24, 5], [176, 237, 265, 213, 192])
# ('18997', 'fasutofjdo') ('ファストフード', ['f', 'a', 's', 'u', 't', 'o', 'f', 'u:', 'd', 'o'], [21, 4, 37, 6, 39, 8, 21, 11, 19, 8], [195, 227, 168, 182, 195, 265, 183])
# ('19030', 'sukapu') ('スクープ', ['s', 'u', 'k', 'u:', 'p', 'u'], [37, 6, 27, 11, 33, 6], [168, 158, 265, 197])
# ('19039', 'kura') ('クルー', ['k', 'u', 'r', 'u:'], [27, 6, 35, 11], [158, 214, 265])
# ('19092', 'mizari') ('ミズーリ', ['m', 'i', 'z', 'u:', 'r', 'i'], [29, 5, 43, 11, 35, 5], [205, 169, 265, 213])
# ('19112', 'daidouuaku') ('大動脈', ['d', 'a', 'i', 'd', 'o', 'u', 'my', 'a', 'k', 'u'], [19, 4, 5, 19, 8, 6, 30, 4, 27, 6], [1696, 1923, 2300])
# ('19133', 'figyuasukkto') ('フィギュアスケート', ['f', 'i', 'gy', 'u', 'a', 's', 'u', 'k', 'e:', 't', 'o'], [21, 5, 23, 6, 4, 37, 6, 27, 12, 39, 8], [195, 228, 157, 237, 149, 168, 160, 265, 182])
# ('19167', '<SOW>uuzaN') ('入山', ['ny', 'u', 'u', 'z', 'a', 'N'], [32, 6, 6, 43, 4, 14], [1968, 1129])
# ('19329', 'bebi:bbmu') ('ベビーブーム', ['b', 'e', 'b', 'i:', 'b', 'u:', 'm', 'u'], [16, 7, 16, 10, 16, 11, 29, 6], [199, 193, 265, 196, 265, 206])
# ('19409', 'baN') ('ブーン', ['b', 'u:', 'N'], [16, 11, 14], [196, 265, 221])
# ('19464', 'saaouba') ('作業場', ['s', 'a', 'gy', 'o', 'u', 'b', 'a'], [37, 4, 23, 8, 6, 16, 4], [1107, 806, 1404])
# ('19475', 'barikkdo') ('バリケード', ['b', 'a', 'r', 'i', 'k', 'e:', 'd', 'o'], [16, 4, 35, 5, 27, 12, 19, 8], [190, 213, 160, 265, 183])
# ('19577', 'mouga') ('氷河', ['hy', 'o', 'u', 'g', 'a'], [25, 8, 6, 22, 4], [2101, 526])
# ('19624', 'mouze') ('平瀬', ['by', 'o', 'u', 'z', 'e'], [17, 8, 6, 43, 7], [2173, 1486])
# ('19708', 'soiou') ('素描', ['s', 'o', 'by', 'o', 'u'], [37, 8, 17, 8, 6], [1592, 2111])
# ('19828', 'syuuchuuyaku') ('収入役', ['sy', 'u', 'u', 'ny', 'u', 'u', 'y', 'a', 'k', 'u'], [38, 6, 6, 32, 6, 6, 42, 4, 27, 6], [1267, 1968, 2341])
# ('19885', '<SOW>ou') ('妙', ['my', 'o', 'u'], [30, 8, 6], [2301])
# ('19965', 'supaN') ('スプーン', ['s', 'u', 'p', 'u:', 'N'], [37, 6, 33, 11, 14], [168, 197, 265, 221])
# ('19982', 'seisiNiou') ('精神病', ['s', 'e', 'i', 's', 'i', 'N', 'by', 'o', 'u'], [37, 7, 5, 37, 5, 14, 17, 8, 6], [1514, 1435, 2110])
# ('19988', 'chasusute:syoN') ('ニュースステーション', ['ny', 'u:', 's', 'u', 's', 'u', 't', 'e:', 'sy', 'o', 'N'], [32, 11, 37, 6, 37, 6, 39, 12, 38, 8, 14], [185, 237, 265, 168, 168, 180, 265, 166, 236, 221])
# ('19997', 'kurazu') ('クルーズ', ['k', 'u', 'r', 'u:', 'z', 'u'], [27, 6, 35, 11, 43, 6], [158, 214, 265, 169])
# ('20030', 'iiou') ('意表', ['i', 'hy', 'o', 'u'], [5, 25, 8, 6], [417, 2102])
# ('20032', 'chariQpu') ('チューリップ', ['ch', 'u:', 'r', 'i', 'Q', 'p', 'u'], [18, 11, 35, 5, 15, 33, 6], [176, 237, 265, 213, 234, 197])
# ('20086', 'sukuryj') ('スクリュー', ['s', 'u', 'k', 'u', 'ry', 'u:'], [37, 6, 27, 6, 36, 11], [168, 158, 213, 237, 265])
# ('20099', 'chana:') ('チューナー', ['ch', 'u:', 'n', 'a:'], [18, 11, 31, 9], [176, 237, 265, 184, 265])
# ('20108', 'syo:ramu') ('ショールーム', ['sy', 'o:', 'r', 'u:', 'm', 'u'], [38, 13, 35, 11, 29, 6], [166, 236, 265, 214, 265, 206])
# ('20165', 'maQkajiteN') ('百科事典', ['hy', 'a', 'Q', 'k', 'a', 'j', 'i', 't', 'e', 'N'], [25, 4, 15, 27, 4, 26, 5, 39, 7, 14], [2100, 528, 1198, 1857])
# ('20167', 'heikouyuchuu') ('並行輸入', ['h', 'e', 'i', 'k', 'o', 'u', 'y', 'u', 'ny', 'u', 'u'], [24, 7, 5, 27, 8, 6, 42, 6, 32, 6, 6], [2176, 987, 2352, 1968])
# ('20276', 'kuaNyy') ('クアンユー', ['k', 'u', 'a', 'N', 'y', 'u:'], [27, 6, 4, 14, 42, 11], [158, 149, 221, 210, 265])
# ('20396', 'wuma') ('デュマ', ['dy', 'u', 'm', 'a'], [20, 6, 29, 4], [181, 237, 204])
# ('20400', 'chatorino') ('ニュートリノ', ['ny', 'u:', 't', 'o', 'r', 'i', 'n', 'o'], [32, 11, 39, 8, 35, 5, 31, 8], [185, 237, 265, 182, 213, 188])
# ('20533', 'mituyuchuu') ('密輸入', ['m', 'i', 't', 'u', 'y', 'u', 'ny', 'u', 'u'], [29, 5, 39, 6, 42, 6, 32, 6, 6], [2298, 2352, 1968])
# ('20591', 'hoauurui') ('ほ乳類', ['h', 'o', 'ny', 'u', 'u', 'r', 'u', 'i'], [24, 8, 32, 6, 6, 35, 6, 5], [118, 1969, 2470])
# ('20657', 'kiNuaku') ('金脈', ['k', 'i', 'N', 'my', 'a', 'k', 'u'], [27, 5, 14, 30, 4, 27, 6], [816, 2300])
# ('20747', 'higasiuou') ('東名', ['h', 'i', 'g', 'a', 's', 'i', 'my', 'o', 'u'], [24, 5, 22, 4, 37, 5, 30, 8, 6], [1888, 2310])
# ('20792', 'bataN') ('ブータン', ['b', 'u:', 't', 'a', 'N'], [16, 11, 39, 4, 14], [196, 265, 174, 221])
# ('20804', 'mazu') ('ヒューズ', ['hy', 'u:', 'z', 'u'], [25, 11, 43, 6], [192, 237, 265, 169])
# ('20816', 'koNchaku') ('コンニャク', ['k', 'o', 'N', 'ny', 'a', 'k', 'u'], [27, 8, 14, 32, 4, 27, 6], [162, 221, 185, 235, 158])
# ('20979', 'birichusu') ('ビリニュス', ['b', 'i', 'r', 'i', 'ny', 'u', 's', 'u'], [16, 5, 35, 5, 32, 6, 37, 6], [193, 213, 185, 237, 168])
# ('21100', 'aroNcha') ('ウーロン茶', ['u:', 'r', 'o', 'N', 'ch', 'a'], [11, 35, 8, 14, 18, 4], [151, 265, 216, 221, 1757])
# ('21135', 'kapoN') ('クーポン', ['k', 'u:', 'p', 'o', 'N'], [27, 11, 33, 8, 14], [158, 265, 203, 221])
# ('21207', 'baka') ('バクー', ['b', 'a', 'k', 'u:'], [16, 4, 27, 11], [190, 158, 265])
# ('21213', 'seNchuu') ('潜入', ['s', 'e', 'N', 'ny', 'u', 'u'], [37, 7, 14, 32, 6, 6], [1573, 1968])
# ('21236', 'daiiouriji') ('代表理事', ['d', 'a', 'i', 'hy', 'o', 'u', 'r', 'i', 'j', 'i'], [19, 4, 5, 25, 8, 6, 35, 5, 26, 5], [1697, 2102, 2422, 1198])
# ('21267', 'siritumouiN') ('市立病院', ['s', 'i', 'r', 'i', 't', 'u', 'by', 'o', 'u', 'i', 'N'], [37, 5, 35, 5, 39, 6, 17, 8, 6, 5, 14], [1152, 2429, 2110, 436])
# ('21292', 'daiuou') ('大名', ['d', 'a', 'i', 'my', 'o', 'u'], [19, 4, 5, 30, 8, 6], [1696, 2310])
# ('21301', 'madi:zu') ('ムーディーズ', ['m', 'u:', 'd', 'i:', 'z', 'u'], [29, 11, 19, 10, 43, 6], [206, 265, 181, 228, 265, 169])
# ('21388', 'utumou') ('うつ病', ['u', 't', 'u', 'by', 'o', 'u'], [6, 39, 6, 17, 8, 6], [68, 95, 2110])
# ('21419', 'wupoN') ('デュポン', ['dy', 'u', 'p', 'o', 'N'], [20, 6, 33, 8, 14], [181, 237, 203, 221])
# ('21421', 'parasyato') ('パラシュート', ['p', 'a', 'r', 'a', 'sy', 'u:', 't', 'o'], [33, 4, 35, 4, 38, 11, 39, 8], [191, 212, 166, 237, 265, 182])
# ('21511', 'sutorasubaru') ('ストラスブール', ['s', 'u', 't', 'o', 'r', 'a', 's', 'u', 'b', 'u:', 'r', 'u'], [37, 6, 39, 8, 35, 4, 37, 6, 16, 11, 35, 6], [168, 182, 212, 168, 196, 265, 214])
# ('21536', 'chuukaNhou') ('入管法', ['ny', 'u', 'u', 'k', 'a', 'N', 'h', 'o', 'u'], [32, 6, 6, 27, 4, 14, 24, 8, 6], [1968, 662, 2221])
# ('21581', 'haaou') ('は行', ['h', 'a', 'gy', 'o', 'u'], [24, 4, 23, 8, 6], [106, 987])
# ('21728', 'chojitu') ('如実', ['ny', 'o', 'j', 'i', 't', 'u'], [32, 8, 26, 5, 39, 6], [1337, 1223])
# ('21801', 'perajiN') ('ペルー人', ['p', 'e', 'r', 'u:', 'j', 'i', 'N'], [33, 7, 35, 11, 26, 5, 14], [200, 214, 265, 1454])
# ('21828', 'jouuaku') ('静脈', ['j', 'o', 'u', 'my', 'a', 'k', 'u'], [26, 8, 6, 30, 4, 27, 6], [1517, 2300])
# ('21888', 'yyesue:') ('ＵＳＡ', ['y', 'u:', 'e', 's', 'u', 'e:'], [42, 11, 7, 37, 6, 12], [34, 32, 14])
# ('21937', 'moudeN') ('評伝', ['hy', 'o', 'u', 'd', 'e', 'N'], [25, 8, 6, 19, 7, 14], [2105, 1865])
# ('21966', 'mouyomi') ('秒読み', ['by', 'o', 'u', 'y', 'o', 'm', 'i'], [17, 8, 6, 42, 8, 29, 5], [2109, 1940, 122])
# ('21973', 'doiougiwa') ('土俵際', ['d', 'o', 'hy', 'o', 'u', 'g', 'i', 'w', 'a'], [19, 8, 25, 8, 6, 22, 5, 41, 4], [1877, 2103, 1099])
# ('22148', 'moQtositara') ('ひょっとしたら', ['hy', 'o', 'Q', 't', 'o', 's', 'i', 't', 'a', 'r', 'a'], [25, 8, 15, 39, 8, 37, 5, 39, 4, 35, 4], [109, 146, 143, 99, 83, 91, 129])
# ('22183', 'eouji') ('名字', ['my', 'o', 'u', 'j', 'i'], [30, 8, 6, 26, 5], [2310, 1191])
# ('22256', 'chchhofu') ('チェーホフ', ['ch', 'e:', 'h', 'o', 'f', 'u'], [18, 12, 24, 8, 21, 6], [176, 232, 265, 201, 195])
# ('22298', 'yyfo:') ('ＵＦＯ', ['y', 'u:', 'f', 'o:'], [42, 11, 21, 13], [34, 19, 28])
# ('22351', 'tarisuto') ('ツーリスト', ['t', 'u:', 'r', 'i', 's', 'u', 't', 'o'], [39, 11, 35, 5, 37, 6, 39, 8], [178, 265, 213, 168, 182])
# ('22353', 'basu') ('ブース', ['b', 'u:', 's', 'u'], [16, 11, 37, 6], [196, 265, 168])
# ('22358', 'yyesu') ('ＵＳ', ['y', 'u:', 'e', 's', 'u'], [42, 11, 7, 37, 6], [34, 32])
# ('22372', 'jikokuiou') ('時刻表', ['j', 'i', 'k', 'o', 'k', 'u', 'hy', 'o', 'u'], [26, 5, 27, 8, 27, 6, 25, 8, 6], [1202, 1044, 2102])
# ('22471', 'mou') ('廟', ['by', 'o', 'u'], [17, 8, 6], [2587])
# ('22515', 'toumoubako') ('投票箱', ['t', 'o', 'u', 'hy', 'o', 'u', 'b', 'a', 'k', 'o'], [39, 8, 6, 25, 8, 6, 16, 4, 27, 8], [1886, 2104, 2027])
# ('22530', 'ibuniNguchasu') ('イブニングニュース', ['i', 'b', 'u', 'n', 'i', 'N', 'g', 'u', 'ny', 'u:', 's', 'u'], [5, 16, 6, 31, 5, 14, 22, 6, 32, 11, 37, 6], [150, 196, 185, 221, 159, 185, 237, 265, 168])
# ('22534', 'mouri') ('表裏', ['hy', 'o', 'u', 'r', 'i'], [25, 8, 6, 35, 5], [2102, 2424])
# ('22557', 'fudoumou') ('浮動票', ['f', 'u', 'd', 'o', 'u', 'hy', 'o', 'u'], [21, 6, 19, 8, 6, 25, 8, 6], [2133, 1923, 2104])
# ('22591', 'seNkousiiou') ('先行指標', ['s', 'e', 'N', 'k', 'o', 'u', 's', 'i', 'hy', 'o', 'u'], [37, 7, 14, 27, 8, 6, 37, 5, 25, 8, 6], [1554, 987, 1170, 2107])
# ('22612', 'mougeNtai') ('病原体', ['by', 'o', 'u', 'g', 'e', 'N', 't', 'a', 'i'], [17, 8, 6, 22, 7, 14, 39, 4, 5], [2110, 935, 1679])
# ('22618', 'toumouseikatu') ('闘病生活', ['t', 'o', 'u', 'by', 'o', 'u', 's', 'e', 'i', 'k', 'a', 't', 'u'], [39, 8, 6, 17, 8, 6, 37, 7, 5, 27, 4, 39, 6], [1918, 2110, 1491, 618])
# ('22657', 'daburyjbi:si:') ('ＷＢＣ', ['d', 'a', 'b', 'u', 'ry', 'u:', 'b', 'i:', 's', 'i:'], [19, 4, 16, 6, 36, 11, 16, 10, 37, 10], [36, 15, 16])
# ('22676', 'gaaou') ('画業', ['g', 'a', 'gy', 'o', 'u'], [22, 4, 23, 8, 6], [551, 806])
# ('22708', 'juumou') ('重病', ['j', 'u', 'u', 'by', 'o', 'u'], [26, 6, 6, 17, 8, 6], [1296, 2110])
# ('22801', 'razuberuto') ('ルーズベルト', ['r', 'u:', 'z', 'u', 'b', 'e', 'r', 'u', 't', 'o'], [35, 11, 43, 6, 16, 7, 35, 6, 39, 8], [214, 265, 169, 199, 214, 182])
# ('22859', 'cha') ('ニュー', ['ny', 'u:'], [32, 11], [185, 237, 265])
# ('22883', 'uouaN') ('妙案', ['my', 'o', 'u', 'a', 'N'], [30, 8, 6, 4, 14], [2301, 397])
# ('22910', 'kyariaamaN') ('キャリアウーマン', ['ky', 'a', 'r', 'i', 'a', 'u:', 'm', 'a', 'N'], [28, 4, 35, 5, 4, 11, 29, 4, 14], [156, 235, 213, 149, 151, 265, 204, 221])
# ('22936', 'auugyuu') ('乳牛', ['ny', 'u', 'u', 'gy', 'u', 'u'], [32, 6, 6, 23, 6, 6], [1969, 765])
# ('22969', 'mousinuke') ('拍子抜け', ['hy', 'o', 'u', 's', 'i', 'n', 'u', 'k', 'e'], [25, 8, 6, 37, 5, 31, 6, 27, 7], [2016, 1144, 2036, 77])
# ('23067', 'mousou') ('表層', ['hy', 'o', 'u', 's', 'o', 'u'], [25, 8, 6, 37, 8, 6], [2102, 1628])
# ('23084', 'mouketu') ('表決', ['hy', 'o', 'u', 'k', 'e', 't', 'u'], [25, 8, 6, 27, 7, 39, 6], [2102, 893])
# ('23086', 'boryjmu') ('ボリューム', ['b', 'o', 'ry', 'u:', 'm', 'u'], [16, 8, 36, 11, 29, 6], [202, 213, 237, 265, 206])
# ('23101', 'kouunikksyoNzu') ('コミュニケーションズ', ['k', 'o', 'my', 'u', 'n', 'i', 'k', 'e:', 'sy', 'o', 'N', 'z', 'u'], [27, 8, 30, 6, 31, 5, 27, 12, 38, 8, 14, 43, 6], [162, 205, 237, 185, 160, 265, 166, 236, 221, 169])
# ('23197', 'rouchakunaNcho') ('老若男女', ['r', 'o', 'u', 'ny', 'a', 'k', 'u', 'n', 'a', 'N', 'ny', 'o'], [35, 8, 6, 32, 4, 27, 6, 31, 4, 14, 32, 8], [2499, 1244, 1732, 1336])
# ('23226', 'maeioubaN') ('前評判', ['m', 'a', 'e', 'hy', 'o', 'u', 'b', 'a', 'N'], [29, 4, 7, 25, 8, 6, 16, 4, 14], [1581, 2105, 2046])
# ('23254', 'raki:') ('ルーキー', ['r', 'u:', 'k', 'i:'], [35, 11, 27, 10], [214, 265, 156, 265])
# ('23263', 'arutuhaima:iou') ('アルツハイマー病', ['a', 'r', 'u', 't', 'u', 'h', 'a', 'i', 'm', 'a:', 'by', 'o', 'u'], [4, 35, 6, 39, 6, 24, 4, 5, 29, 9, 17, 8, 6], [149, 214, 178, 189, 150, 204, 265, 2110])
# ('23325', 'sichou') ('し尿', ['s', 'i', 'ny', 'o', 'u'], [37, 5, 32, 8, 6], [83, 1970])
# ('23385', 'hakuiou') ('白票', ['h', 'a', 'k', 'u', 'hy', 'o', 'u'], [24, 4, 27, 6, 25, 8, 6], [2014, 2104])
# ('23449', 'wueQto') ('デュエット', ['dy', 'u', 'e', 'Q', 't', 'o'], [20, 6, 7, 15, 39, 8], [181, 237, 152, 234, 182])
# ('23472', 'raburugoui') ('ルーブル合意', ['r', 'u:', 'b', 'u', 'r', 'u', 'g', 'o', 'u', 'i'], [35, 11, 16, 6, 35, 6, 22, 8, 6, 5], [214, 265, 196, 214, 1036, 417])
# ('23482', 'kasyoumouka') ('過小評価', ['k', 'a', 'sy', 'o', 'u', 'hy', 'o', 'u', 'k', 'a'], [27, 4, 38, 8, 6, 25, 8, 6, 27, 4], [537, 1343, 2105, 524])
# ('23561', 'kouiou') ('講評', ['k', 'o', 'u', 'hy', 'o', 'u'], [27, 8, 6, 25, 8, 6], [1032, 2105])
# ('23687', 'yytopia') ('ユートピア', ['y', 'u:', 't', 'o', 'p', 'i', 'a'], [42, 11, 39, 8, 33, 5, 4], [210, 265, 182, 194, 149])
# ('23773', 'aasukyasuta:') ('ニュースキャスター', ['ny', 'u:', 's', 'u', 'ky', 'a', 's', 'u', 't', 'a:'], [32, 11, 37, 6, 28, 4, 37, 6, 39, 9], [185, 237, 265, 168, 156, 235, 168, 174, 265])
# ('23776', 'kaiiou') ('戒名', ['k', 'a', 'i', 'my', 'o', 'u'], [27, 4, 5, 30, 8, 6], [561, 2310])
# ('23933', 'tuutiiou') ('通知表', ['t', 'u', 'u', 't', 'i', 'hy', 'o', 'u'], [39, 6, 6, 39, 5, 25, 8, 6], [1814, 1741, 2102])
# ('23950', 'mo:dorofu') ('フョードロフ', ['hy', 'o:', 'd', 'o', 'r', 'o', 'f', 'u'], [25, 13, 19, 8, 35, 8, 21, 6], [195, 236, 265, 183, 216, 195])
# ('23951', 'mourigaku') ('病理学', ['by', 'o', 'u', 'r', 'i', 'g', 'a', 'k', 'u'], [17, 8, 6, 35, 5, 22, 4, 27, 6], [2110, 2422, 610])
# ('24036', 'aakaredonia') ('ニューカレドニア', ['ny', 'u:', 'k', 'a', 'r', 'e', 'd', 'o', 'n', 'i', 'a'], [32, 11, 27, 4, 35, 7, 19, 8, 31, 5, 4], [185, 237, 265, 154, 215, 183, 185, 149])
# ('24087', 'futoumouji') ('不当表示', ['f', 'u', 't', 'o', 'u', 'hy', 'o', 'u', 'j', 'i'], [21, 6, 39, 8, 6, 25, 8, 6, 26, 5], [2120, 1885, 2102, 1190])
# ('24206', 'saaoufuku') ('作業服', ['s', 'a', 'gy', 'o', 'u', 'f', 'u', 'k', 'u'], [37, 4, 23, 8, 6, 21, 6, 27, 6], [1107, 806, 2150])
# ('24224', 'sysymaN') ('シューマン', ['sy', 'u:', 'm', 'a', 'N'], [38, 11, 29, 4, 14], [166, 237, 265, 204, 221])
# ('24254', 'doiouiri') ('土俵入り', ['d', 'o', 'hy', 'o', 'u', 'i', 'r', 'i'], [19, 8, 25, 8, 6, 5, 35, 5], [1877, 2103, 1968, 130])
# ('24255', 'satukksu') ('スーツケース', ['s', 'u:', 't', 'u', 'k', 'e:', 's', 'u'], [37, 11, 39, 6, 27, 12, 37, 6], [168, 265, 178, 160, 265, 168])
# ('24269', 'mouriiQtai') ('表裏一体', ['hy', 'o', 'u', 'r', 'i', 'i', 'Q', 't', 'a', 'i'], [25, 8, 6, 35, 5, 5, 15, 39, 4, 5], [2102, 2424, 425, 1679])
# ('24320', 'kataraaa') ('カタルーニャ', ['k', 'a', 't', 'a', 'r', 'u:', 'ny', 'a'], [27, 4, 39, 4, 35, 11, 32, 4], [154, 174, 214, 265, 185, 235])
# ('24350', 'kameraN') ('カメルーン', ['k', 'a', 'm', 'e', 'r', 'u:', 'N'], [27, 4, 29, 7, 35, 11, 14], [154, 207, 214, 265, 221])
# ('24424', 'fusei<EOW>aku') ('不整脈', ['f', 'u', 's', 'e', 'i', 'my', 'a', 'k', 'u'], [21, 6, 37, 7, 5, 30, 4, 27, 6], [2120, 1519, 2300])
# ('24580', 'kokuiou') ('酷評', ['k', 'o', 'k', 'u', 'hy', 'o', 'u'], [27, 8, 27, 6, 25, 8, 6], [1048, 2105])
# ('24671', 'kyuumou') ('急病', ['ky', 'u', 'u', 'by', 'o', 'u'], [28, 6, 6, 17, 8, 6], [756, 2110])
# ('24705', 'kouuou') ('光明', ['k', 'o', 'u', 'my', 'o', 'u'], [27, 8, 6, 30, 8, 6], [981, 2312])
# ('24721', 'boiou') ('墓標', ['b', 'o', 'hy', 'o', 'u'], [16, 8, 25, 8, 6], [2209, 2107])
# ('24816', 'makuniti') ('百日', ['hy', 'a', 'k', 'u', 'n', 'i', 't', 'i'], [25, 4, 27, 6, 31, 5, 39, 5], [2100, 1967])
# ('24894', 'pa:kiNsoNmou') ('パーキンソン病', ['p', 'a:', 'k', 'i', 'N', 's', 'o', 'N', 'by', 'o', 'u'], [33, 9, 27, 5, 14, 37, 8, 14, 17, 8, 6], [191, 265, 156, 221, 172, 221, 2110])
# ('24971', 'chabijinesu') ('ニュービジネス', ['ny', 'u:', 'b', 'i', 'j', 'i', 'n', 'e', 's', 'u'], [32, 11, 16, 5, 26, 5, 31, 7, 37, 6], [185, 237, 265, 193, 167, 187, 168])
# ('24977', 'garati') ('ガルーチ', ['g', 'a', 'r', 'u:', 't', 'i'], [22, 4, 35, 11, 39, 5], [155, 214, 265, 176])
# ('25008', 'moudou') ('兵藤', ['hy', 'o', 'u', 'd', 'o', 'u'], [25, 8, 6, 19, 8, 6], [2174, 1917])
# ('25063', 'hoQkk') ('ホッケー', ['h', 'o', 'Q', 'k', 'e:'], [24, 8, 15, 27, 12], [201, 234, 160, 265])
# ('25070', 'moaumeNto') ('モニュメント', ['m', 'o', 'ny', 'u', 'm', 'e', 'N', 't', 'o'], [29, 8, 32, 6, 29, 7, 14, 39, 8], [208, 185, 237, 207, 221, 182])
# ('25339', 'ramu') ('ルーム', ['r', 'u:', 'm', 'u'], [35, 11, 29, 6], [214, 265, 206])
# ('25380', 'irukatuku') ('イルクーツク', ['i', 'r', 'u', 'k', 'u:', 't', 'u', 'k', 'u'], [5, 35, 6, 27, 11, 39, 6, 27, 6], [150, 214, 158, 265, 178, 158])
# ('25514', 'moujuNgo') ('標準語', ['hy', 'o', 'u', 'j', 'u', 'N', 'g', 'o'], [25, 8, 6, 26, 6, 14, 22, 8], [2107, 1324, 968])
# ('25541', 'aaginia') ('ニューギニア', ['ny', 'u:', 'g', 'i', 'n', 'i', 'a'], [32, 11, 22, 5, 31, 5, 4], [185, 237, 265, 157, 185, 149])
# ('25589', 'mousatu') ('表札', ['hy', 'o', 'u', 's', 'a', 't', 'u'], [25, 8, 6, 37, 4, 39, 6], [2102, 1118])
# ('25608', 'syumou') ('種苗', ['sy', 'u', 'by', 'o', 'u'], [38, 6, 17, 8, 6], [1258, 2108])
# ('25665', 'koNchaku') ('こんにゃく', ['k', 'o', 'N', 'ny', 'a', 'k', 'u'], [27, 8, 14, 32, 4, 27, 6], [79, 138, 102, 144, 75])
# ('25669', 'guNmou') ('軍兵', ['g', 'u', 'N', 'by', 'o', 'u'], [22, 6, 14, 17, 8, 6], [850, 2174])
# ('25687', 'ichuu') ('移入', ['i', 'ny', 'u', 'u'], [5, 32, 6, 6], [412, 1968])
# ('25703', 'sousyuuchuu') ('総収入', ['s', 'o', 'u', 'sy', 'u', 'u', 'ny', 'u', 'u'], [37, 8, 6, 38, 6, 6, 32, 6, 6], [1629, 1267, 1968])
# ('25706', 'mougaki') ('氷河期', ['hy', 'o', 'u', 'g', 'a', 'k', 'i'], [25, 8, 6, 22, 4, 27, 5], [2101, 526, 712])
# ('25788', 'mma') ('ムーア', ['m', 'u:', 'a'], [29, 11, 4], [206, 265, 149])
# ('25912', 'kyuuchuu') ('吸入', ['ky', 'u', 'u', 'ny', 'u', 'u'], [28, 6, 6, 32, 6, 6], [750, 1968])
# ('25913', 'hichoukika') ('泌尿器科', ['h', 'i', 'ny', 'o', 'u', 'k', 'i', 'k', 'a'], [24, 5, 32, 8, 6, 27, 5, 27, 4], [2097, 1970, 718, 528])
# ('25914', 'mougai') ('病害', ['by', 'o', 'u', 'g', 'a', 'i'], [17, 8, 6, 22, 4, 5], [2110, 583])
# ('26012', 'uoureNji') ('妙蓮寺', ['my', 'o', 'u', 'r', 'e', 'N', 'j', 'i'], [30, 8, 6, 35, 7, 14, 26, 5], [2301, 2721, 1192])
# ('26046', 'hosutokoNsyata:') ('ホストコンピューター', ['h', 'o', 's', 'u', 't', 'o', 'k', 'o', 'N', 'py', 'u:', 't', 'a:'], [24, 8, 37, 6, 39, 8, 27, 8, 14, 34, 11, 39, 9], [201, 168, 182, 162, 221, 194, 237, 265, 174, 265])
# ('26073', 'yuchuukumiai') ('輸入組合', ['y', 'u', 'ny', 'u', 'u', 'k', 'u', 'm', 'i', 'a', 'i'], [42, 6, 32, 6, 6, 27, 6, 29, 5, 4, 5], [2352, 1968, 1595, 1036])
# ('26111', '<SOW>uubu') ('入部', ['ny', 'u', 'u', 'b', 'u'], [32, 6, 6, 16, 6], [1968, 2145])
# ('26113', 'aQpurukoNsyata') ('アップルコンピュータ', ['a', 'Q', 'p', 'u', 'r', 'u', 'k', 'o', 'N', 'py', 'u:', 't', 'a'], [4, 15, 33, 6, 35, 6, 27, 8, 14, 34, 11, 39, 4], [149, 234, 197, 214, 162, 221, 194, 237, 265, 174])
# ('26133', 'mousou') ('病巣', ['by', 'o', 'u', 's', 'o', 'u'], [17, 8, 6, 37, 8, 6], [2110, 1615])
# ('26148', 'hiNzjkyou') ('ヒンズー教', ['h', 'i', 'N', 'z', 'u:', 'ky', 'o', 'u'], [24, 5, 14, 43, 11, 28, 8, 6], [192, 221, 169, 265, 795])
# ('26277', 'maQka') ('百科', ['hy', 'a', 'Q', 'k', 'a'], [25, 4, 15, 27, 4], [2100, 528])
# ('26376', 'siata:kokaN') ('シアターコクーン', ['s', 'i', 'a', 't', 'a:', 'k', 'o', 'k', 'u:', 'N'], [37, 5, 4, 39, 9, 27, 8, 27, 11, 14], [166, 149, 174, 265, 162, 158, 265, 221])
# ('26447', 'nnbo:') ('ヌーボー', ['n', 'u:', 'b', 'o:'], [31, 11, 16, 13], [186, 265, 202, 265])
# ('26448', 'moudo') ('表土', ['hy', 'o', 'u', 'd', 'o'], [25, 8, 6, 19, 8], [2102, 1877])
# ('26715', 'moujou') ('氷上', ['hy', 'o', 'u', 'j', 'o', 'u'], [25, 8, 6, 26, 8, 6], [2101, 1393])
# ('26719', 'sapa:dorai') ('スーパードライ', ['s', 'u:', 'p', 'a:', 'd', 'o', 'r', 'a', 'i'], [37, 11, 33, 9, 19, 8, 35, 4, 5], [168, 265, 191, 265, 183, 212, 150])
# ('26743', 'kouuou') ('巧妙', ['k', 'o', 'u', 'my', 'o', 'u'], [27, 8, 6, 30, 8, 6], [977, 2301])
# ('26755', 'juchuu') ('授乳', ['j', 'u', 'ny', 'u', 'u'], [26, 6, 32, 6, 6], [1263, 1969])
# ('26796', 'sosikiiou') ('組織票', ['s', 'o', 's', 'i', 'k', 'i', 'hy', 'o', 'u'], [37, 8, 37, 5, 27, 5, 25, 8, 6], [1595, 1421, 2104])
# 総エラー数:510 正解率:98.102

# %% [markdown]
# # 3 理解モデル 音韻から意味

# %% [markdown]
# ## 3.1 モデルの定義

# %%
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
from torch.nn.utils.rnn import pad_sequence

class EncDec_p2s(nn.Module):
    def __init__(self,
                 sem_dim:int,
                 enc_vocab_size:int,
                 n_hid:int,
                 n_layers:int=2,
                 bidirectional:bool=False):
        super().__init__()
        self.encoder_emb = nn.Embedding(num_embeddings=enc_vocab_size,
                                        embedding_dim=n_hid,
                                        padding_idx=0)

        self.encoder = nn.LSTM(input_size=n_hid,
                               hidden_size=n_hid,
                               num_layers=n_layers,
                               batch_first=True,
                               bidirectional=bidirectional)

        bi_fact = 2 if bidirectional else 1
        self.out_layer = nn.Linear(in_features=n_hid * bi_fact,
                                   out_features=sem_dim)

    def forward(self, enc_inp):
        enc_emb = self.encoder_emb(enc_inp)
        enc_out, (hid, cel) = self.encoder(enc_emb)
        _sem = self.out_layer(hid)
        return _sem, enc_out


n_hid = 64
n_layers = 1
bidirectional=False
model = EncDec_p2s(sem_dim=_psylex71_ds.w2v.vector_size,
                   enc_vocab_size=len(_psylex71_ds.phoneme),
                   n_hid=n_hid,
                   n_layers=n_layers,
                   bidirectional=bidirectional)
model.eval()
# Out:
# EncDec_p2s(
#   (encoder_emb): Embedding(45, 64, padding_idx=0)
#   (encoder): LSTM(64, 64, batch_first=True)
#   (out_layer): Linear(in_features=64, out_features=200, bias=True)
# )

# %% [markdown]
# ## 3.2 訓練の実施

# %%
start_time = time.time()
n_hid = 64
n_layers = 1
epochs = 50
bidirectional=False
model = EncDec_p2s(sem_dim=_psylex71_ds.w2v.vector_size,
                   enc_vocab_size=len(_psylex71_ds.phoneme),
                   n_layers=n_layers,
                   bidirectional=bidirectional,
                   n_hid=n_hid).to(device)

optimizer = optim.Adam(model.parameters(),lr=0.001)
criterion_dec = nn.MSELoss()
criterion_enc = nn.CrossEntropyLoss(ignore_index=-1)

model.train()
interval = int(_psylex71_ds.__len__()/batch_size) >> 2
losses = []
for epoch in range(epochs):
    i = 0
    for x, y in dataloader:
        enc_inp = pad_sequence(y, batch_first=True).to(device)
        tch = torch.tensor([_x.detach().numpy() for _x in x]).to(device)

        out, enc_out = model(enc_inp)
        loss = criterion_dec(out, tch)

        for _x, _y in zip(enc_out[:,:-1], enc_inp[:,1:]):
            loss += criterion_enc(_x, _y)
        losses.append(loss.item()/len(x))
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        i += 1
        if (i % interval) == 0:
            print(f'epoch:{epoch:2d}, batch:{i:2d}, loss:{loss.item()/len(x):.3f}')

end_time = time.time()
total_time = end_time - start_time
total_time_str = str(datetime.timedelta(seconds=int(total_time)))
print(f'Training time {total_time_str}')

plt.plot(losses)
plt.title(f'epochs:{epochs}, batch_size:{batch_size}, n_hid:{n_hid}, n_layers:{n_layers}, time collapsed:{total_time_str}')
plt.show()

#outfile = "attnmt2-" + str(epoch) + ".model"
#torch.save(net.state_dict(),outfile)
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/loss.py:535: UserWarning: Using a target size (torch.Size([1024, 200])) that is different to the input size (torch.Size([1, 1024, 200])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# epoch: 0, batch: 6, loss:4.045
# epoch: 0, batch:12, loss:3.975
# epoch: 0, batch:18, loss:3.883
# epoch: 0, batch:24, loss:3.702
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/loss.py:535: UserWarning: Using a target size (torch.Size([253, 200])) that is different to the input size (torch.Size([1, 253, 200])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# epoch: 1, batch: 6, loss:3.378
# epoch: 1, batch:12, loss:3.263
# epoch: 1, batch:18, loss:3.105
# epoch: 1, batch:24, loss:3.036
# epoch: 2, batch: 6, loss:2.879
# epoch: 2, batch:12, loss:2.819
# epoch: 2, batch:18, loss:2.819
# epoch: 2, batch:24, loss:2.801
# epoch: 3, batch: 6, loss:2.795
# epoch: 3, batch:12, loss:2.673
# epoch: 3, batch:18, loss:2.643
# epoch: 3, batch:24, loss:2.766

# %% [markdown]
# ## 3.3 学結果の評価

# %%
model.eval()
isPrint = False
errors = []
#for N in tqdm(range(_psylex71_ds.__len__())):
for N in np.random.permutation(_psylex71_ds.__len__())[:2]:
    x, y = _psylex71_ds.__getitem__(N)
    enc_inp = y.to(device).unsqueeze(0)
    #tch = x.to(device)

    out, enc_out = model(enc_inp)
    # print(f'type(out):{type(out)}',
    #       f'len(out):{len(out)}'
    #       f'out.size():{out.size()}'
    #      )
    out = out.detach().squeeze().numpy()
    print(N)
    print(_psylex71_ds.getitem(N)[0])
    print(_psylex71_ds.w2v.similar_by_vector(out,topn=3))
    # print(f'type(out):{type(out)}',
    #       f'len(out):{len(out)}'
    #       f'out.shape:{out.shape}'
    #      )
    sys.exit()


    n_correct = np.array((y_ids[1:-1] == _psylex71_ds.getitem(N)[2]).sum())
    isOK = n_correct == len(_psylex71_ds.getitem(N)[2])
    color = 'grey' if isOK else 'red'

    if not isOK:
        errors.append((N,y_ids))
    if isPrint:
        print(colored((f'{N:05d}', #y_ids,
                       "".join(p for p in _psylex71_ds.phon_ids2phn(y_ids[1:-1]))),color,attrs=["bold"]), end=" ")
        print(_psylex71_ds.getitem(N))

cr = len(errors) / _psylex71_ds.__len__()
print(f'総エラー数:{len(errors)}',
      f'正解率:{(1.-cr)*100:.3f}')

# %%
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
from torch.nn.utils.rnn import pad_sequence

class EncDec_s2s(nn.Module):
    def __init__(self,
                 sem_dim:int,
                 n_hid:int):
        super().__init__()
        self.hidden_layer = nn.Linear(in_features=sem_dim,
                                      out_features=n_hid)
        self.out_layer = nn.Linear(in_features=n_hid,
                                   out_features=sem_dim)

    def forward(self, enc_inp):
        hid = self.hidden_layer(enc_inp)
        out = self.out_layer(hid)
        return out


n_hid = 128
#model = EncDec_s2s(sem_dim=_psylex71_ds.w2v.vector_size,
#                   n_hid=n_hid)

model = nn.Sequential(
    nn.Linear(_psylex71_ds.w2v.vector_size, n_hid),
    nn.ReLU(),
    nn.Linear(n_hid, n_hid),
    nn.ReLU(),
    nn.Linear(n_hid, _psylex71_ds.w2v.vector_size),
    nn.Tanh()
)


start_time = time.time()
epochs = 20
optimizer = optim.Adam(model.parameters(),lr=0.001)
criterion = nn.MSELoss()

model.train()
interval = int(_psylex71_ds.__len__()/batch_size) >> 2
losses = []
for epoch in range(epochs):
    i = 0
    for x, y in dataloader:
        tch = torch.tensor([_x.detach().numpy() for _x in x]).to(device)

        out = model(tch)
        loss = criterion_dec(out, tch)
        losses.append(loss.item())
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        i += 1
        if (i % interval) == 0:
            print(f'epoch:{epoch:2d}, batch:{i:2d}, loss:{loss.item():.3f}')

end_time = time.time()
total_time = end_time - start_time
total_time_str = str(datetime.timedelta(seconds=int(total_time)))
print(f'Training time {total_time_str}')

plt.plot(losses)
plt.title(f'epochs:{epochs}, batch_size:{batch_size}, n_hid:{n_hid}, n_layers:{n_layers}, time collapsed:{total_time_str}')
plt.show()

# %% [markdown]
# # 4) 書記から意味
# # 5) 意味から書記
# # 6) 書記から意味を解して音韻
#
# # 7) 書記から意味を介さず音韻
# # 8) 6 と 7 の比較

# %%
#help(RAM.chars_joyo)
j = RAM.chars_joyo()
#print(dir(j))
ch_list = ['<PAD>', '<SOW>', '<EOW>', '<UNK>'] + j.char_list
not_chlist = []
for N in range(_psylex71_ds.__len__()):
    wrd = _psylex71_ds.getitem(N)[0]
    for ch in wrd:
        if (ch not in ch_list) and (ch not in not_chlist):
            not_chlist.append(ch)
print(len(not_chlist))

# %%
print(sorted(not_chlist))

# %%
#help(RAM.chars_joyo)
print(len(grapheme))
#print(grapheme)
#print(chars_list + not_chars_list)
