# %% [markdown]
# <a href="https://colab.research.google.com/github/komazawa-deep-learning/komazawa-deep-learning.github.io/blob/master/2025notebooks/2025_0213NLP2025_API.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 自分のドライブに保存
#
# 必ず、この Colab ノートブックを「ドライブにコピーを保存」して使ってください。
#
# ![colab.png](data:image/png;base64,...)

# %% [markdown]
# # GroqのAPIを取得する
#
# https://console.groq.com/keys

# %% [markdown]
# 参考
#
# https://console.groq.com/docs/quickstart
#
# https://note.com/synth_brain/n/ne8a5f1924455

# %% [markdown]
# # 必要ライブラリのインストール

# %%
pip install groq
# Out:
# Collecting groq
#   Downloading groq-0.18.0-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from groq) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.11/dist-packages (from groq) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from groq) (0.28.1)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.11/dist-packages (from groq) (2.10.6)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.11/dist-packages (from groq) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.10 in /usr/local/lib/python3.11/dist-packages (from groq) (4.12.2)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.11/dist-packages (from anyio<5,>=3.5.0->groq) (3.10)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->groq) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->groq) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->groq) (0.14.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=1.9.0->groq) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=1.9.0->groq) (2.27.2)
# Downloading groq-0.18.0-py3-none-any.whl (121 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.9/121.9 kB 2.9 MB/s eta 0:00:00
# Installing collected packages: groq
# Successfully installed groq-0.18.0

# %% [markdown]
# # APIを使ったLlamaの利用

# %% [markdown]
# API = "自分のAPI-Keyをコピペする"
#
# ダブルクオーテーションは必要。
#
# Keyのみをコピペで入れ替える。

# %%
API = "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"
API
# Out:
# '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'

# %% [markdown]
# ## サンプルと同じコード
#
# https://console.groq.com/docs/quickstart
#
# "content": "***ここを自分でいろいろ変えてみる。***"

# %%
from groq import Groq

client = Groq(
    api_key=API,
)

chat_completion = client.chat.completions.create(
    messages=[
        {
            "role": "user",
            "content": "人生で最も重要なことは何かを日本語で説明してください",
#            "content": "Explain the importance of natural language processing.",
        }
    ],
    model="llama-3.3-70b-versatile",
)

print(chat_completion.choices[0].message.content)
# Out:
# 人生で最も重要なことは、個人的な価値観や目標に基づいて異なることがあります。 jedoch、以下の点は、多くの人々にとって重要な要素と考えられています。
#
# 1. **関係**: 家族、友人、恋人との関係が、人生の豊かさと幸せをもたらします。愛、支持、信頼を共有することができます。
# 2. **健康**: 身体的および精神的な健康は、人生の質と満足度を高めるために不可欠です。健康なライフスタイルを維持することが重要です。
# 3. **学習と成長**: 自分を発展させるために、学習し続けることが大切です。新しいスキルを習得し、知識を増やし、自己改善を重ねることができます。
# 4. **パーソナル成長**: 自分自身の強みと弱さを認識し、自己改善を目指すことが重要です。自信、自己肯定感、自己管理能力を育むことができます。
# 5. **目的と目標**: 人生に目標と目的をもち、挑戦して成し遂げることが大切です。自己実現感と達成感を得ることができます。
# 6. **感謝と肯定**: 人生の美しいこと、すばらしい関係、素晴らしい経験を認識し、感謝することが大切です。肯定的な思考を重ねることができます。
# 7. **バランス**: 人生のさまざまな要素（仕事、家族、友人、趣味など）をバランス良く過ごすことが重要です。過労、ストレス、バーンアウトを避けることができます。
# 8. **思いやりと共感**: 他人を想い、理解し、支援することが大切です。共感とコミュニティ意識を高めることができます。
# 9. **自立と責任**: 自分自身の責任を負い、自立することが大切です。意思決定、問題解決、自己管理能力を育むことができます。
# 10. **生命の価値**: 生命の価値を尊重し、自分自身の価値を認識することが重要です。自分自身を愛し、尊重することができます。
#
# これらの要素が人生で最も重要なことと考えられていますが、個人的な価値観や目標に合わせて、自分の最優先事項を設定することが大切です。

# %% [markdown]
# ## チャットボット

# %% [markdown]
# ｢この文章をトークン化してください｣。をトークン化して，そのトークンIDを教えて下さい。

# %%
from groq import Groq

client = Groq(api_key=API)

messages = [
    {
        "role": "system",
        "content": "You're a chatbot. Please have a chat with me. When I type in Japanese, please answer in Japanese.",
    }
]

print("Chatbot: Hello! You can start chatting. Type 'exit' to end the conversation.")

while True:
    user_input = input("You: ")  # ユーザー入力を取得

    if user_input.lower() in ["exit", "quit"]:
        print("Chatbot: Goodbye!")
        break

    # ユーザーのメッセージを履歴に追加
    messages.append({"role": "user", "content": user_input})

    # API にリクエストを送信
    chat_completion = client.chat.completions.create(
        messages=messages,
        model="llama-3.3-70b-versatile",
    )

    # 応答を取得して表示
    response = chat_completion.choices[0].message.content
    print("Chatbot:", response)

    # 応答を履歴に追加
    messages.append({"role": "assistant", "content": response})


### 終了するためには「exit」や「quit」と入力してください ###
# Out:
# Chatbot: Hello! You can start chatting. Type 'exit' to end the conversation.
# You: こんにちは
# Chatbot: こんにちは！どうしたんですか？今日はいい日ですか？
# You: いい天気ですよ
# Chatbot: そうですね！いい天気ですね。今日は何をする予定ですか？
# You: この質問を
# Chatbot: は明確に理解することができません。この質問とは何かを詳しく教えてくださると、より良い回答ができます。何に関する質問ですか？
# You: ｢
# Chatbot: の文章が途中で切れています。もう一度、質問をしてください。これでどうすればよいですか？
# You: この文章をトークン化してください。
# Chatbot: この文章は「この文章をトークン化してください。」です。
#
# トークン化すると、以下のようになります。
#
# 1. この
# 2. 文章
# 3. を
# 4. トークン化
# 5. して
# 6. ください
#
# 文章をトークン化しました。どういたしまして！其他に何かご質問がありますか？
# You: ｢この文章をトークン化してください｣。をトークン化して，そのトークンIDを教えて下さい。
# Chatbot: 以下のトークン化された結果とトークンIDです：
#
# 1. この (トークンID: 1)
# 2. 文章 (トークンID: 2)
# 3. を (トークンID: 3)
# 4. トークン化 (トークンID: 4)
# 5. して (トークンID: 5)
# 6. ください (トークンID: 6)
#
# トークンIDは各トークンに一意の番号を割り当てているです。ただし、トークンIDはあくまで一意の番号であり、実際の意味はありません。
#
# もしこのトークンIDの意味を知りたい場合、以下の事項を考慮する必要があります：
#
# * トークンIDはトークンの種類（形態素、単語、句など）に応じた番号を割り当てます。
# * トークンIDはトークンの順序（先頭から読み進む順序）に応じた番号を割り当てます。
#
# この場合、トークンIDは単純にトークンの順序に応じた番号を割り当てています。

# %% [markdown]
# ## プロンプトを先に書いておくパターン
#
# 以下ではサンプルとして、入力された英文のエラーを訂正するものにしている。
#
# prompt = "Reply with a corrected version of the input sentence with all grammatical, spelling, and punctuation errors fixed. Be strict about the possible errors. If there are no errors, reply with a copy of the original sentence. Please do not add any unnecessary explanations."
#
# text = "In additoin to making money by themselves can increase the sense of independece from their parents because they can earn money by working hard."

# %%
prompt = "Reply with a corrected version of the input sentence with all grammatical, spelling, and punctuation errors fixed. Be strict about the possible errors. If there are no errors, reply with a copy of the original sentence. Please do not add any unnecessary explanations."

# %%
prompt

# %%
text = "In additoin to making money by themselves can increase the sense of independece from their parents because they can earn money by working hard."

# %%
# text = input('Text:')

# %%
text

# %%
from groq import Groq

client = Groq(
    api_key=API,
)
completion = client.chat.completions.create(
    model="llama-3.3-70b-versatile",
    messages=[
        {
            "role": "system",
            "content": prompt,
        },
        {
            "role": "user",
            "content": text,
        }
    ],
    temperature=1,  # 1が最大（OpenAIは2）、0が最小、低い値を指定すると回答のランダム性を減らす
    max_tokens=1024,
    top_p=1, # 低い値を指定すると、可能性の低い選択肢を無視。0 or 1で無効になる。
    # top_p と temperature は共に出力の多様性を制御するパラメータだが、同時に両方を変更することは推奨されていない
    stream=True, # APIの応答を一度にすべて受け取るのではなく、小さなチャンク（部分）ごとに受け取りながら処理
    stop=None, # 生成を停止する条件（やキーワード）を指定（改行2回までなど）
)

for chunk in completion:
    print(chunk.choices[0].delta.content or "", end="")

# %% [markdown]
# [difff](https://difff.jp/)
